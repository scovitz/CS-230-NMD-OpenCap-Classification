# %%
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import pad_sequences
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Masking
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')  # May improve speed on some CPUs

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')  # May improve speed on some CPUs

# %%
def read_trc(fpath):
    # read metadata in file header
    df_meta = pd.read_csv(fpath, delimiter='\t', header=0, skiprows=1, nrows=1)
    meta = df_meta.iloc[0].to_dict()
    fps = meta['DataRate']

    # read marker location names
    markers_df = pd.read_csv(fpath, delimiter='\t', header=None, skiprows=3, nrows=1)
    markers = markers_df.iloc[0].dropna().to_numpy()[2:]

    # read marker XYZ locations
    df = pd.read_csv(fpath, delimiter='\t', header=0, skiprows=4)
    df.rename(columns=dict(zip(df.columns[:2], ('n', 't'))), inplace=True)
    df.dropna(how='all', axis=1, inplace=True)

    N = df.shape[0]
    M = len(markers)
    xyz = df.iloc[:,2:].to_numpy().reshape((N, M, 3))
    xyz[:,:,[0,1,2]] = xyz[:,:,[2,1,0]]

    return fps, markers, xyz


def read_mot(fpath):
    with open(fpath, 'r') as f:
        # count = 0
        line = f.readline().strip()
        # while line and line.strip() != 'endheader':
        while line.lower() != 'endheader':
            line = f.readline().strip()
            # count += 1

        # df = pd.read_csv(f, delimiter='\t', header=0, skiprows=count-3)
        df = pd.read_csv(f, delimiter='\t', header=0)

    return df

# %%
# # Define function to normalize joint angles across all data
# def normalize_data(data_list):
#     """
#     Normalizes a list of numpy arrays using MinMax scaling across all features.
#     Arguments:
#         data_list: List of numpy arrays where each array corresponds to one time series.
#     Returns:
#         normalized_data: List of normalized numpy arrays.
#     """
#     # Flatten all data for joint normalization across the dataset
#     all_data = np.array(data_list)
    
#     # Apply MinMaxScaler
#     scaler = MinMaxScaler()
#     scaler.fit(all_data)  # Fit scaler on all joint angles across the dataset
    
#     # Normalize each time series
#     normalized_data = [scaler.transform(data) for data in data_list]
#     return normalized_data, scaler

# # Define function to pad time series to the same length
# def pad_time_series(data_list, max_length=None):
#     """
#     Pads all time series in data_list to the same length.
#     Arguments:
#         data_list: List of numpy arrays where each array corresponds to one time series.
#         max_length: If None, pad to the longest time series. Otherwise, pad to max_length.
#     Returns:
#         padded_data: Numpy array of shape (num_samples, max_length, num_features).
#     """
#     if max_length is None:
#         max_length = max(len(data) for data in data_list)  # Find the longest time series
#     padded_data = pad_sequences(data_list, maxlen=max_length, padding="post", dtype="float32")
#     return padded_data

# %%
def z_score_normalize(data_list):
    """
    Applies z-score normalization to a list of time series arrays.
    Arguments:
        data_list: List of numpy arrays, each of shape (num_timesteps, num_features).
    Returns:
        normalized_data: List of z-score normalized arrays.
        mean: Mean of each feature across all time series.
        std: Standard deviation of each feature across all time series.
    """
    # Concatenate all data to compute global mean and std
    all_data = np.concatenate(data_list, axis=0)
    mean = np.mean(all_data, axis=0)
    std = np.std(all_data, axis=0)
    
    # Normalize each array
    normalized_data = [(data - mean) / (std + 1e-8) for data in data_list]
    return normalized_data, mean, std

def prepare_lstm_input(subject_dict):
    """
    Combines multiple time series for each subject along the time axis, applies z-score normalization,
    and pads them for LSTM input.
    Arguments:
        subject_dict: Dictionary where keys are subject IDs and values are lists of 6 numpy arrays.
                      Each numpy array corresponds to a time series with shape (num_timesteps, num_features).
    Returns:
        padded_input: A numpy array of shape (num_subjects, max_timesteps, num_features).
        subject_ids: List of subject IDs in the order they appear in the padded_input array.
        mean: Mean of features used for z-score normalization.
        std: Standard deviation of features used for z-score normalization.
    """
    # Sort the dictionary by keys to ensure consistent ordering
    subject_ids = sorted(subject_dict.keys())
    
    # Extract and concatenate the 6 time series for each subject along the time axis
    concatenated_series = [
        np.concatenate(subject_dict[subject_id], axis=0) for subject_id in subject_ids
    ]
    
    # Apply z-score normalization to the concatenated series
    normalized_series, mean, std = z_score_normalize(concatenated_series)
    
    # Determine the maximum length for padding
    max_length = max(series.shape[0] for series in normalized_series)
    
    # Pad all normalized time series to the same length
    padded_input = pad_sequences(normalized_series, maxlen=max_length, padding="post", dtype="float32")
    
    return padded_input, subject_ids, mean, std

# %%
def get_label_for_participant_trial(class_df, pid, trial):
    """
    Fetches the label for a given participant and trial based on class_info.csv.
    
    Parameters:
        participant_id (str): The ID of the participant.
        trial (str): The trial name or ID.
    
    Returns:
        int: Classification label (0 or 1).
    """
    label = class_df.loc[class_df['ID'] == pid, 'Class'].values[0]
    return label

# %%
# Directory containing .mot files
root_dir = '/Users/scovitz/datadir/opencap_data'  # path to root data dir 
labels_csv = '/Users/scovitz/datadir/class_info.csv'
class_df = pd.read_csv(labels_csv)

time_series_data = {}  # dictionary of pid, timeseries pairs 

expected_columns = [
        'pelvis_tilt', 'pelvis_list', 'pelvis_rotation', 'pelvis_tx',
        'pelvis_ty', 'pelvis_tz', 'hip_flexion_r', 'hip_adduction_r',
        'hip_rotation_r', 'knee_angle_r', 'ankle_angle_r',
        'subtalar_angle_r', 'mtp_angle_r', 'hip_flexion_l', 'hip_adduction_l',
        'hip_rotation_l', 'knee_angle_l', 'ankle_angle_l',
        'subtalar_angle_l', 'mtp_angle_l', 'lumbar_extension', 'lumbar_bending',
        'lumbar_rotation', 'arm_flex_r', 'arm_add_r', 'arm_rot_r',
        'elbow_flex_r', 'pro_sup_r', 'arm_flex_l', 'arm_add_l', 'arm_rot_l',
        'elbow_flex_l', 'pro_sup_l'
    ]

# Loop through all .mot files
for i in range(129):
        # ensure going in order!
        num = str(i+1).zfill(3)

        for path in Path(root_dir).rglob(f"P{num}*/**/*.mot"): 
            
            # remove upper extremity trials 
            if "brooke" in str(path) or "curls" in str(path) or "arm_rom" in str(path):
                continue 
            
            trial = str(path).split('/')[-3]
            pid = str(path).split('/')[-4]
            activity = str(path).split('/')[-2]
            #print(str(path))
            # Load the .mot file
            
            data = read_mot(str(path))
            data = data[200:]
            #print(data.shape)

            # Ensure the file has the expected columns
            if not all(col in data.columns for col in expected_columns + ['time']):
                raise ValueError(f"File {path} does not contain the expected columns.")
            
            # Drop the 'time' column and keep only relevant features
            data = np.array(data[expected_columns])
            
            if pid not in time_series_data:
                time_series_data[pid + '_' + trial] = []

            time_series_data[(pid + '_' + trial)].append(data) # value = list of timeseries arrays of num_timesteps x num_feats
            print(data.shape, pid, trial, str(path))
# Out:
# (635, 33) P001 0 /Users/scovitz/datadir/opencap_data/P001/0/walk/walk.mot
# (332, 33) P001 0 /Users/scovitz/datadir/opencap_data/P001/0/tug/tug.mot
# (1838, 33) P001 0 /Users/scovitz/datadir/opencap_data/P001/0/toe_stand/toe_stand.mot
# (652, 33) P001 0 /Users/scovitz/datadir/opencap_data/P001/0/5xsts/5xsts.mot
# (140, 33) P001 0 /Users/scovitz/datadir/opencap_data/P001/0/jump/jump.mot
# (273, 33) P001 0 /Users/scovitz/datadir/opencap_data/P001/0/run/run.mot
# (642, 33) P002 0 /Users/scovitz/datadir/opencap_data/P002/0/walk/walk.mot
# (1119, 33) P002 0 /Users/scovitz/datadir/opencap_data/P002/0/tug/tug.mot
# (1929, 33) P002 0 /Users/scovitz/datadir/opencap_data/P002/0/toe_stand/toe_stand.mot
# (875, 33) P002 0 /Users/scovitz/datadir/opencap_data/P002/0/5xsts/5xsts.mot
# (161, 33) P002 0 /Users/scovitz/datadir/opencap_data/P002/0/jump/jump.mot
# (456, 33) P002 0 /Users/scovitz/datadir/opencap_data/P002/0/run/run.mot
# (625, 33) P003 0 /Users/scovitz/datadir/opencap_data/P003/0/walk/walk.mot
# (948, 33) P003 0 /Users/scovitz/datadir/opencap_data/P003/0/tug/tug.mot
# (1879, 33) P003 0 /Users/scovitz/datadir/opencap_data/P003/0/toe_stand/toe_stand.mot
# (506, 33) P003 0 /Users/scovitz/datadir/opencap_data/P003/0/5xsts/5xsts.mot
# (145, 33) P003 0 /Users/scovitz/datadir/opencap_data/P003/0/jump/jump.mot
# (340, 33) P003 0 /Users/scovitz/datadir/opencap_data/P003/0/run/run.mot
# (695, 33) P004 0 /Users/scovitz/datadir/opencap_data/P004/0/walk/walk.mot
# (975, 33) P004 0 /Users/scovitz/datadir/opencap_data/P004/0/tug/tug.mot
# (1818, 33) P004 0 /Users/scovitz/datadir/opencap_data/P004/0/toe_stand/toe_stand.mot
# (580, 33) P004 0 /Users/scovitz/datadir/opencap_data/P004/0/5xsts/5xsts.mot
# (201, 33) P004 0 /Users/scovitz/datadir/opencap_data/P004/0/jump/jump.mot
# (469, 33) P004 0 /Users/scovitz/datadir/opencap_data/P004/0/run/run.mot
# (536, 33) P005 0 /Users/scovitz/datadir/opencap_data/P005/0/walk/walk.mot
# (979, 33) P005 0 /Users/scovitz/datadir/opencap_data/P005/0/tug/tug.mot
# (1933, 33) P005 0 /Users/scovitz/datadir/opencap_data/P005/0/toe_stand/toe_stand.mot
# (484, 33) P005 0 /Users/scovitz/datadir/opencap_data/P005/0/5xsts/5xsts.mot
# (251, 33) P005 0 /Users/scovitz/datadir/opencap_data/P005/0/jump/jump.mot
# (337, 33) P005 0 /Users/scovitz/datadir/opencap_data/P005/0/run/run.mot
# (706, 33) P006 0 /Users/scovitz/datadir/opencap_data/P006/0/walk/walk.mot
# (957, 33) P006 0 /Users/scovitz/datadir/opencap_data/P006/0/tug/tug.mot
# (1986, 33) P006 0 /Users/scovitz/datadir/opencap_data/P006/0/toe_stand/toe_stand.mot
# (278, 33) P006 0 /Users/scovitz/datadir/opencap_data/P006/0/5xsts/5xsts.mot
# (210, 33) P006 0 /Users/scovitz/datadir/opencap_data/P006/0/jump/jump.mot
# (363, 33) P006 0 /Users/scovitz/datadir/opencap_data/P006/0/run/run.mot
# (1447, 33) P007 407 /Users/scovitz/datadir/opencap_data/P007/407/walk/walk.mot
# (1470, 33) P007 407 /Users/scovitz/datadir/opencap_data/P007/407/tug/tug.mot
# (2022, 33) P007 407 /Users/scovitz/datadir/opencap_data/P007/407/toe_stand/toe_stand.mot
# (1623, 33) P007 407 /Users/scovitz/datadir/opencap_data/P007/407/5xsts/5xsts.mot
# (396, 33) P007 407 /Users/scovitz/datadir/opencap_data/P007/407/jump/jump.mot
# (586, 33) P007 407 /Users/scovitz/datadir/opencap_data/P007/407/run/run.mot
# (759, 33) P007 0 /Users/scovitz/datadir/opencap_data/P007/0/walk/walk.mot
# (958, 33) P007 0 /Users/scovitz/datadir/opencap_data/P007/0/tug/tug.mot
# (1854, 33) P007 0 /Users/scovitz/datadir/opencap_data/P007/0/toe_stand/toe_stand.mot
# (391, 33) P007 0 /Users/scovitz/datadir/opencap_data/P007/0/5xsts/5xsts.mot
# (157, 33) P007 0 /Users/scovitz/datadir/opencap_data/P007/0/jump/jump.mot
# (252, 33) P007 0 /Users/scovitz/datadir/opencap_data/P007/0/run/run.mot
# (717, 33) P008 0 /Users/scovitz/datadir/opencap_data/P008/0/walk/walk.mot
# (879, 33) P008 0 /Users/scovitz/datadir/opencap_data/P008/0/tug/tug.mot
# (2016, 33) P008 0 /Users/scovitz/datadir/opencap_data/P008/0/toe_stand/toe_stand.mot
# (460, 33) P008 0 /Users/scovitz/datadir/opencap_data/P008/0/5xsts/5xsts.mot
# (189, 33) P008 0 /Users/scovitz/datadir/opencap_data/P008/0/jump/jump.mot
# (228, 33) P008 0 /Users/scovitz/datadir/opencap_data/P008/0/run/run.mot
# (806, 33) P009 453 /Users/scovitz/datadir/opencap_data/P009/453/walk/walk.mot
# (986, 33) P009 453 /Users/scovitz/datadir/opencap_data/P009/453/tug/tug.mot
# (1900, 33) P009 453 /Users/scovitz/datadir/opencap_data/P009/453/toe_stand/toe_stand.mot
# (1098, 33) P009 453 /Users/scovitz/datadir/opencap_data/P009/453/5xsts/5xsts.mot
# (133, 33) P009 453 /Users/scovitz/datadir/opencap_data/P009/453/jump/jump.mot
# (392, 33) P009 453 /Users/scovitz/datadir/opencap_data/P009/453/run/run.mot
# (735, 33) P009 0 /Users/scovitz/datadir/opencap_data/P009/0/walk/walk.mot
# (981, 33) P009 0 /Users/scovitz/datadir/opencap_data/P009/0/tug/tug.mot
# (1987, 33) P009 0 /Users/scovitz/datadir/opencap_data/P009/0/toe_stand/toe_stand.mot
# (757, 33) P009 0 /Users/scovitz/datadir/opencap_data/P009/0/5xsts/5xsts.mot
# (151, 33) P009 0 /Users/scovitz/datadir/opencap_data/P009/0/jump/jump.mot
# (484, 33) P009 0 /Users/scovitz/datadir/opencap_data/P009/0/run/run.mot
# (1280, 33) P010 407 /Users/scovitz/datadir/opencap_data/P010/407/walk/walk.mot
# (1355, 33) P010 407 /Users/scovitz/datadir/opencap_data/P010/407/tug/tug.mot
# (2058, 33) P010 407 /Users/scovitz/datadir/opencap_data/P010/407/toe_stand/toe_stand.mot
# (1843, 33) P010 407 /Users/scovitz/datadir/opencap_data/P010/407/5xsts/5xsts.mot
# (249, 33) P010 407 /Users/scovitz/datadir/opencap_data/P010/407/jump/jump.mot
# (811, 33) P010 407 /Users/scovitz/datadir/opencap_data/P010/407/run/run.mot
# (813, 33) P010 0 /Users/scovitz/datadir/opencap_data/P010/0/walk/walk.mot
# (979, 33) P010 0 /Users/scovitz/datadir/opencap_data/P010/0/tug/tug.mot
# (1912, 33) P010 0 /Users/scovitz/datadir/opencap_data/P010/0/toe_stand/toe_stand.mot
# (676, 33) P010 0 /Users/scovitz/datadir/opencap_data/P010/0/5xsts/5xsts.mot
# (156, 33) P010 0 /Users/scovitz/datadir/opencap_data/P010/0/jump/jump.mot
# (308, 33) P010 0 /Users/scovitz/datadir/opencap_data/P010/0/run/run.mot
# (541, 33) P011 0 /Users/scovitz/datadir/opencap_data/P011/0/walk/walk.mot
# (335, 33) P011 0 /Users/scovitz/datadir/opencap_data/P011/0/tug/tug.mot
# (1838, 33) P011 0 /Users/scovitz/datadir/opencap_data/P011/0/toe_stand/toe_stand.mot
# (738, 33) P011 0 /Users/scovitz/datadir/opencap_data/P011/0/5xsts/5xsts.mot
# (160, 33) P011 0 /Users/scovitz/datadir/opencap_data/P011/0/jump/jump.mot
# (360, 33) P011 0 /Users/scovitz/datadir/opencap_data/P011/0/run/run.mot
# (580, 33) P012 0 /Users/scovitz/datadir/opencap_data/P012/0/walk/walk.mot
# (1071, 33) P012 0 /Users/scovitz/datadir/opencap_data/P012/0/tug/tug.mot
# (2022, 33) P012 0 /Users/scovitz/datadir/opencap_data/P012/0/toe_stand/toe_stand.mot
# (457, 33) P012 0 /Users/scovitz/datadir/opencap_data/P012/0/5xsts/5xsts.mot
# (313, 33) P012 0 /Users/scovitz/datadir/opencap_data/P012/0/jump/jump.mot
# (314, 33) P012 0 /Users/scovitz/datadir/opencap_data/P012/0/run/run.mot
# (1149, 33) P013 0 /Users/scovitz/datadir/opencap_data/P013/0/walk/walk.mot
# (1366, 33) P013 0 /Users/scovitz/datadir/opencap_data/P013/0/tug/tug.mot
# (1840, 33) P013 0 /Users/scovitz/datadir/opencap_data/P013/0/toe_stand/toe_stand.mot
# (758, 33) P013 0 /Users/scovitz/datadir/opencap_data/P013/0/5xsts/5xsts.mot
# (612, 33) P013 0 /Users/scovitz/datadir/opencap_data/P013/0/run/run.mot
# (710, 33) P014 0 /Users/scovitz/datadir/opencap_data/P014/0/walk/walk.mot
# (865, 33) P014 0 /Users/scovitz/datadir/opencap_data/P014/0/tug/tug.mot
# (2076, 33) P014 0 /Users/scovitz/datadir/opencap_data/P014/0/toe_stand/toe_stand.mot
# (578, 33) P014 0 /Users/scovitz/datadir/opencap_data/P014/0/5xsts/5xsts.mot
# (313, 33) P014 0 /Users/scovitz/datadir/opencap_data/P014/0/jump/jump.mot
# (273, 33) P014 0 /Users/scovitz/datadir/opencap_data/P014/0/run/run.mot
# (323, 33) P015 0 /Users/scovitz/datadir/opencap_data/P015/0/walk/walk.mot
# (546, 33) P015 0 /Users/scovitz/datadir/opencap_data/P015/0/tug/tug.mot
# (2315, 33) P015 0 /Users/scovitz/datadir/opencap_data/P015/0/toe_stand/toe_stand.mot
# (819, 33) P015 0 /Users/scovitz/datadir/opencap_data/P015/0/5xsts/5xsts.mot
# (433, 33) P015 0 /Users/scovitz/datadir/opencap_data/P015/0/jump/jump.mot
# (184, 33) P015 0 /Users/scovitz/datadir/opencap_data/P015/0/run/run.mot
# (727, 33) P016 0 /Users/scovitz/datadir/opencap_data/P016/0/walk/walk.mot
# (1051, 33) P016 0 /Users/scovitz/datadir/opencap_data/P016/0/tug/tug.mot
# (1960, 33) P016 0 /Users/scovitz/datadir/opencap_data/P016/0/toe_stand/toe_stand.mot
# (742, 33) P016 0 /Users/scovitz/datadir/opencap_data/P016/0/5xsts/5xsts.mot
# (161, 33) P016 0 /Users/scovitz/datadir/opencap_data/P016/0/jump/jump.mot
# (310, 33) P016 0 /Users/scovitz/datadir/opencap_data/P016/0/run/run.mot
# (861, 33) P017 455 /Users/scovitz/datadir/opencap_data/P017/455/walk/walk.mot
# (878, 33) P017 455 /Users/scovitz/datadir/opencap_data/P017/455/tug/tug.mot
# (2064, 33) P017 455 /Users/scovitz/datadir/opencap_data/P017/455/toe_stand/toe_stand.mot
# (1330, 33) P017 455 /Users/scovitz/datadir/opencap_data/P017/455/5xsts/5xsts.mot
# (270, 33) P017 455 /Users/scovitz/datadir/opencap_data/P017/455/jump/jump.mot
# (374, 33) P017 455 /Users/scovitz/datadir/opencap_data/P017/455/run/run.mot
# (783, 33) P017 0 /Users/scovitz/datadir/opencap_data/P017/0/walk/walk.mot
# (1002, 33) P017 0 /Users/scovitz/datadir/opencap_data/P017/0/tug/tug.mot
# (2020, 33) P017 0 /Users/scovitz/datadir/opencap_data/P017/0/toe_stand/toe_stand.mot
# (589, 33) P017 0 /Users/scovitz/datadir/opencap_data/P017/0/5xsts/5xsts.mot
# (264, 33) P017 0 /Users/scovitz/datadir/opencap_data/P017/0/jump/jump.mot
# (374, 33) P017 0 /Users/scovitz/datadir/opencap_data/P017/0/run/run.mot
# (908, 33) P018 0 /Users/scovitz/datadir/opencap_data/P018/0/walk/walk.mot
# (1318, 33) P018 0 /Users/scovitz/datadir/opencap_data/P018/0/tug/tug.mot
# (1896, 33) P018 0 /Users/scovitz/datadir/opencap_data/P018/0/toe_stand/toe_stand.mot
# (920, 33) P018 0 /Users/scovitz/datadir/opencap_data/P018/0/5xsts/5xsts.mot
# (260, 33) P018 0 /Users/scovitz/datadir/opencap_data/P018/0/jump/jump.mot
# (147, 33) P018 0 /Users/scovitz/datadir/opencap_data/P018/0/run/run.mot
# (866, 33) P019 7 /Users/scovitz/datadir/opencap_data/P019/7/walk/walk.mot
# (1452, 33) P019 7 /Users/scovitz/datadir/opencap_data/P019/7/tug/tug.mot
# (1781, 33) P019 7 /Users/scovitz/datadir/opencap_data/P019/7/toe_stand/toe_stand.mot
# (611, 33) P019 7 /Users/scovitz/datadir/opencap_data/P019/7/5xsts/5xsts.mot
# (160, 33) P019 7 /Users/scovitz/datadir/opencap_data/P019/7/jump/jump.mot
# (461, 33) P019 7 /Users/scovitz/datadir/opencap_data/P019/7/run/run.mot
# (1002, 33) P019 118 /Users/scovitz/datadir/opencap_data/P019/118/walk/walk.mot
# (1350, 33) P019 118 /Users/scovitz/datadir/opencap_data/P019/118/tug/tug.mot
# (1908, 33) P019 118 /Users/scovitz/datadir/opencap_data/P019/118/toe_stand/toe_stand.mot
# (1931, 33) P019 118 /Users/scovitz/datadir/opencap_data/P019/118/5xsts/5xsts.mot
# (34, 33) P019 118 /Users/scovitz/datadir/opencap_data/P019/118/jump/jump.mot
# (355, 33) P019 118 /Users/scovitz/datadir/opencap_data/P019/118/run/run.mot
# (668, 33) P019 119 /Users/scovitz/datadir/opencap_data/P019/119/walk/walk.mot
# (1330, 33) P019 119 /Users/scovitz/datadir/opencap_data/P019/119/tug/tug.mot
# (1938, 33) P019 119 /Users/scovitz/datadir/opencap_data/P019/119/toe_stand/toe_stand.mot
# (1363, 33) P019 119 /Users/scovitz/datadir/opencap_data/P019/119/5xsts/5xsts.mot
# (0, 33) P019 119 /Users/scovitz/datadir/opencap_data/P019/119/jump/jump.mot
# (236, 33) P019 119 /Users/scovitz/datadir/opencap_data/P019/119/run/run.mot
# (800, 33) P020 7 /Users/scovitz/datadir/opencap_data/P020/7/walk/walk.mot
# (832, 33) P020 7 /Users/scovitz/datadir/opencap_data/P020/7/tug/tug.mot
# (1813, 33) P020 7 /Users/scovitz/datadir/opencap_data/P020/7/toe_stand/toe_stand.mot
# (868, 33) P020 7 /Users/scovitz/datadir/opencap_data/P020/7/5xsts/5xsts.mot
# (196, 33) P020 7 /Users/scovitz/datadir/opencap_data/P020/7/jump/jump.mot
# (489, 33) P020 7 /Users/scovitz/datadir/opencap_data/P020/7/run/run.mot
# (1271, 33) P021 7 /Users/scovitz/datadir/opencap_data/P021/7/walk/walk.mot
# (1599, 33) P021 7 /Users/scovitz/datadir/opencap_data/P021/7/tug/tug.mot
# (1909, 33) P021 7 /Users/scovitz/datadir/opencap_data/P021/7/toe_stand/toe_stand.mot
# (1172, 33) P021 7 /Users/scovitz/datadir/opencap_data/P021/7/5xsts/5xsts.mot
# (99, 33) P021 7 /Users/scovitz/datadir/opencap_data/P021/7/jump/jump.mot
# (1088, 33) P021 7 /Users/scovitz/datadir/opencap_data/P021/7/run/run.mot
# (1016, 33) P022 407 /Users/scovitz/datadir/opencap_data/P022/407/walk/walk.mot
# (1324, 33) P022 407 /Users/scovitz/datadir/opencap_data/P022/407/tug/tug.mot
# (2042, 33) P022 407 /Users/scovitz/datadir/opencap_data/P022/407/toe_stand/toe_stand.mot
# (2415, 33) P022 407 /Users/scovitz/datadir/opencap_data/P022/407/5xsts/5xsts.mot
# (285, 33) P022 407 /Users/scovitz/datadir/opencap_data/P022/407/jump/jump.mot
# (560, 33) P022 407 /Users/scovitz/datadir/opencap_data/P022/407/run/run.mot
# (617, 33) P022 7 /Users/scovitz/datadir/opencap_data/P022/7/walk/walk.mot
# (966, 33) P022 7 /Users/scovitz/datadir/opencap_data/P022/7/tug/tug.mot
# (1901, 33) P022 7 /Users/scovitz/datadir/opencap_data/P022/7/toe_stand/toe_stand.mot
# (1265, 33) P022 7 /Users/scovitz/datadir/opencap_data/P022/7/5xsts/5xsts.mot
# (256, 33) P022 7 /Users/scovitz/datadir/opencap_data/P022/7/jump/jump.mot
# (509, 33) P022 7 /Users/scovitz/datadir/opencap_data/P022/7/run/run.mot
# (717, 33) P023 7 /Users/scovitz/datadir/opencap_data/P023/7/walk/walk.mot
# (937, 33) P023 7 /Users/scovitz/datadir/opencap_data/P023/7/tug/tug.mot
# (1691, 33) P023 7 /Users/scovitz/datadir/opencap_data/P023/7/toe_stand/toe_stand.mot
# (683, 33) P023 7 /Users/scovitz/datadir/opencap_data/P023/7/5xsts/5xsts.mot
# (0, 33) P023 7 /Users/scovitz/datadir/opencap_data/P023/7/jump/jump.mot
# (252, 33) P023 7 /Users/scovitz/datadir/opencap_data/P023/7/run/run.mot
# (606, 33) P024 7 /Users/scovitz/datadir/opencap_data/P024/7/walk/walk.mot
# (982, 33) P024 7 /Users/scovitz/datadir/opencap_data/P024/7/tug/tug.mot
# (1835, 33) P024 7 /Users/scovitz/datadir/opencap_data/P024/7/toe_stand/toe_stand.mot
# (669, 33) P024 7 /Users/scovitz/datadir/opencap_data/P024/7/5xsts/5xsts.mot
# (57, 33) P024 7 /Users/scovitz/datadir/opencap_data/P024/7/jump/jump.mot
# (228, 33) P024 7 /Users/scovitz/datadir/opencap_data/P024/7/run/run.mot
# (671, 33) P025 7 /Users/scovitz/datadir/opencap_data/P025/7/walk/walk.mot
# (638, 33) P025 7 /Users/scovitz/datadir/opencap_data/P025/7/tug/tug.mot
# (1844, 33) P025 7 /Users/scovitz/datadir/opencap_data/P025/7/toe_stand/toe_stand.mot
# (519, 33) P025 7 /Users/scovitz/datadir/opencap_data/P025/7/5xsts/5xsts.mot
# (474, 33) P025 7 /Users/scovitz/datadir/opencap_data/P025/7/jump/jump.mot
# (220, 33) P025 7 /Users/scovitz/datadir/opencap_data/P025/7/run/run.mot
# (398, 33) P026 406 /Users/scovitz/datadir/opencap_data/P026/406/walk/walk.mot
# (565, 33) P026 406 /Users/scovitz/datadir/opencap_data/P026/406/tug/tug.mot
# (2086, 33) P026 406 /Users/scovitz/datadir/opencap_data/P026/406/toe_stand/toe_stand.mot
# (1039, 33) P026 406 /Users/scovitz/datadir/opencap_data/P026/406/5xsts/5xsts.mot
# (454, 33) P026 406 /Users/scovitz/datadir/opencap_data/P026/406/jump/jump.mot
# (196, 33) P026 406 /Users/scovitz/datadir/opencap_data/P026/406/run/run.mot
# (495, 33) P026 7 /Users/scovitz/datadir/opencap_data/P026/7/walk/walk.mot
# (1119, 33) P026 7 /Users/scovitz/datadir/opencap_data/P026/7/tug/tug.mot
# (1826, 33) P026 7 /Users/scovitz/datadir/opencap_data/P026/7/toe_stand/toe_stand.mot
# (671, 33) P026 7 /Users/scovitz/datadir/opencap_data/P026/7/5xsts/5xsts.mot
# (40, 33) P026 7 /Users/scovitz/datadir/opencap_data/P026/7/jump/jump.mot
# (244, 33) P026 7 /Users/scovitz/datadir/opencap_data/P026/7/run/run.mot
# (453, 33) P027 7 /Users/scovitz/datadir/opencap_data/P027/7/walk/walk.mot
# (769, 33) P027 7 /Users/scovitz/datadir/opencap_data/P027/7/tug/tug.mot
# (1876, 33) P027 7 /Users/scovitz/datadir/opencap_data/P027/7/toe_stand/toe_stand.mot
# (577, 33) P027 7 /Users/scovitz/datadir/opencap_data/P027/7/5xsts/5xsts.mot
# (240, 33) P027 7 /Users/scovitz/datadir/opencap_data/P027/7/jump/jump.mot
# (386, 33) P027 7 /Users/scovitz/datadir/opencap_data/P027/7/run/run.mot
# (759, 33) P028 7 /Users/scovitz/datadir/opencap_data/P028/7/walk/walk.mot
# (863, 33) P028 7 /Users/scovitz/datadir/opencap_data/P028/7/tug/tug.mot
# (1760, 33) P028 7 /Users/scovitz/datadir/opencap_data/P028/7/toe_stand/toe_stand.mot
# (572, 33) P028 7 /Users/scovitz/datadir/opencap_data/P028/7/5xsts/5xsts.mot
# (131, 33) P028 7 /Users/scovitz/datadir/opencap_data/P028/7/jump/jump.mot
# (283, 33) P028 7 /Users/scovitz/datadir/opencap_data/P028/7/run/run.mot
# (749, 33) P029 7 /Users/scovitz/datadir/opencap_data/P029/7/walk/walk.mot
# (914, 33) P029 7 /Users/scovitz/datadir/opencap_data/P029/7/tug/tug.mot
# (1956, 33) P029 7 /Users/scovitz/datadir/opencap_data/P029/7/toe_stand/toe_stand.mot
# (748, 33) P029 7 /Users/scovitz/datadir/opencap_data/P029/7/5xsts/5xsts.mot
# (218, 33) P029 7 /Users/scovitz/datadir/opencap_data/P029/7/jump/jump.mot
# (374, 33) P029 7 /Users/scovitz/datadir/opencap_data/P029/7/run/run.mot
# (617, 33) P030 7 /Users/scovitz/datadir/opencap_data/P030/7/walk/walk.mot
# (722, 33) P030 7 /Users/scovitz/datadir/opencap_data/P030/7/tug/tug.mot
# (1899, 33) P030 7 /Users/scovitz/datadir/opencap_data/P030/7/toe_stand/toe_stand.mot
# (435, 33) P030 7 /Users/scovitz/datadir/opencap_data/P030/7/5xsts/5xsts.mot
# (184, 33) P030 7 /Users/scovitz/datadir/opencap_data/P030/7/jump/jump.mot
# (638, 33) P030 7 /Users/scovitz/datadir/opencap_data/P030/7/run/run.mot
# (524, 33) P031 7 /Users/scovitz/datadir/opencap_data/P031/7/walk/walk.mot
# (640, 33) P031 7 /Users/scovitz/datadir/opencap_data/P031/7/tug/tug.mot
# (1829, 33) P031 7 /Users/scovitz/datadir/opencap_data/P031/7/toe_stand/toe_stand.mot
# (563, 33) P031 7 /Users/scovitz/datadir/opencap_data/P031/7/5xsts/5xsts.mot
# (324, 33) P031 7 /Users/scovitz/datadir/opencap_data/P031/7/jump/jump.mot
# (513, 33) P031 7 /Users/scovitz/datadir/opencap_data/P031/7/run/run.mot
# (869, 33) P032 7 /Users/scovitz/datadir/opencap_data/P032/7/walk/walk.mot
# (661, 33) P032 7 /Users/scovitz/datadir/opencap_data/P032/7/tug/tug.mot
# (1980, 33) P032 7 /Users/scovitz/datadir/opencap_data/P032/7/toe_stand/toe_stand.mot
# (785, 33) P032 7 /Users/scovitz/datadir/opencap_data/P032/7/5xsts/5xsts.mot
# (129, 33) P032 7 /Users/scovitz/datadir/opencap_data/P032/7/jump/jump.mot
# (636, 33) P032 7 /Users/scovitz/datadir/opencap_data/P032/7/run/run.mot
# (686, 33) P033 7 /Users/scovitz/datadir/opencap_data/P033/7/walk/walk.mot
# (1218, 33) P033 7 /Users/scovitz/datadir/opencap_data/P033/7/tug/tug.mot
# (2043, 33) P033 7 /Users/scovitz/datadir/opencap_data/P033/7/toe_stand/toe_stand.mot
# (456, 33) P033 7 /Users/scovitz/datadir/opencap_data/P033/7/5xsts/5xsts.mot
# (117, 33) P033 7 /Users/scovitz/datadir/opencap_data/P033/7/jump/jump.mot
# (372, 33) P033 7 /Users/scovitz/datadir/opencap_data/P033/7/run/run.mot
# (961, 33) P034 7 /Users/scovitz/datadir/opencap_data/P034/7/walk/walk.mot
# (1720, 33) P034 7 /Users/scovitz/datadir/opencap_data/P034/7/tug/tug.mot
# (1132, 33) P034 7 /Users/scovitz/datadir/opencap_data/P034/7/5xsts/5xsts.mot
# (164, 33) P034 7 /Users/scovitz/datadir/opencap_data/P034/7/jump/jump.mot
# (778, 33) P034 7 /Users/scovitz/datadir/opencap_data/P034/7/run/run.mot
# (1069, 33) P035 406 /Users/scovitz/datadir/opencap_data/P035/406/walk/walk.mot
# (1249, 33) P035 406 /Users/scovitz/datadir/opencap_data/P035/406/tug/tug.mot
# (2060, 33) P035 406 /Users/scovitz/datadir/opencap_data/P035/406/toe_stand/toe_stand.mot
# (1638, 33) P035 406 /Users/scovitz/datadir/opencap_data/P035/406/5xsts/5xsts.mot
# (381, 33) P035 406 /Users/scovitz/datadir/opencap_data/P035/406/jump/jump.mot
# (639, 33) P035 406 /Users/scovitz/datadir/opencap_data/P035/406/run/run.mot
# (584, 33) P035 7 /Users/scovitz/datadir/opencap_data/P035/7/walk/walk.mot
# (713, 33) P035 7 /Users/scovitz/datadir/opencap_data/P035/7/tug/tug.mot
# (1901, 33) P035 7 /Users/scovitz/datadir/opencap_data/P035/7/toe_stand/toe_stand.mot
# (400, 33) P035 7 /Users/scovitz/datadir/opencap_data/P035/7/5xsts/5xsts.mot
# (109, 33) P035 7 /Users/scovitz/datadir/opencap_data/P035/7/jump/jump.mot
# (272, 33) P035 7 /Users/scovitz/datadir/opencap_data/P035/7/run/run.mot
# (890, 33) P036 7 /Users/scovitz/datadir/opencap_data/P036/7/walk/walk.mot
# (965, 33) P036 7 /Users/scovitz/datadir/opencap_data/P036/7/tug/tug.mot
# (1896, 33) P036 7 /Users/scovitz/datadir/opencap_data/P036/7/toe_stand/toe_stand.mot
# (638, 33) P036 7 /Users/scovitz/datadir/opencap_data/P036/7/5xsts/5xsts.mot
# (91, 33) P036 7 /Users/scovitz/datadir/opencap_data/P036/7/jump/jump.mot
# (505, 33) P036 7 /Users/scovitz/datadir/opencap_data/P036/7/run/run.mot
# (1043, 33) P037 7 /Users/scovitz/datadir/opencap_data/P037/7/walk/walk.mot
# (1827, 33) P037 7 /Users/scovitz/datadir/opencap_data/P037/7/tug/tug.mot
# (991, 33) P037 7 /Users/scovitz/datadir/opencap_data/P037/7/5xsts/5xsts.mot
# (171, 33) P037 7 /Users/scovitz/datadir/opencap_data/P037/7/jump/jump.mot
# (772, 33) P037 7 /Users/scovitz/datadir/opencap_data/P037/7/run/run.mot
# (1237, 33) P038 406 /Users/scovitz/datadir/opencap_data/P038/406/walk/walk.mot
# (1581, 33) P038 406 /Users/scovitz/datadir/opencap_data/P038/406/tug/tug.mot
# (2079, 33) P038 406 /Users/scovitz/datadir/opencap_data/P038/406/toe_stand/toe_stand.mot
# (2559, 33) P038 406 /Users/scovitz/datadir/opencap_data/P038/406/5xsts/5xsts.mot
# (280, 33) P038 406 /Users/scovitz/datadir/opencap_data/P038/406/jump/jump.mot
# (833, 33) P038 406 /Users/scovitz/datadir/opencap_data/P038/406/run/run.mot
# (1328, 33) P038 7 /Users/scovitz/datadir/opencap_data/P038/7/walk/walk.mot
# (2081, 33) P038 7 /Users/scovitz/datadir/opencap_data/P038/7/tug/tug.mot
# (1122, 33) P038 7 /Users/scovitz/datadir/opencap_data/P038/7/5xsts/5xsts.mot
# (192, 33) P038 7 /Users/scovitz/datadir/opencap_data/P038/7/jump/jump.mot
# (466, 33) P038 7 /Users/scovitz/datadir/opencap_data/P038/7/run/run.mot
# (1477, 33) P039 7 /Users/scovitz/datadir/opencap_data/P039/7/walk/walk.mot
# (2303, 33) P039 7 /Users/scovitz/datadir/opencap_data/P039/7/tug/tug.mot
# (1908, 33) P039 7 /Users/scovitz/datadir/opencap_data/P039/7/toe_stand/toe_stand.mot
# (1892, 33) P039 7 /Users/scovitz/datadir/opencap_data/P039/7/5xsts/5xsts.mot
# (133, 33) P039 7 /Users/scovitz/datadir/opencap_data/P039/7/jump/jump.mot
# (1116, 33) P039 7 /Users/scovitz/datadir/opencap_data/P039/7/run/run.mot
# (1530, 33) P040 7 /Users/scovitz/datadir/opencap_data/P040/7/walk/walk.mot
# (2270, 33) P040 7 /Users/scovitz/datadir/opencap_data/P040/7/tug/tug.mot
# (1809, 33) P040 7 /Users/scovitz/datadir/opencap_data/P040/7/toe_stand/toe_stand.mot
# (1538, 33) P040 7 /Users/scovitz/datadir/opencap_data/P040/7/5xsts/5xsts.mot
# (506, 33) P040 7 /Users/scovitz/datadir/opencap_data/P040/7/jump/jump.mot
# (1309, 33) P040 7 /Users/scovitz/datadir/opencap_data/P040/7/run/run.mot
# (1060, 33) P041 407 /Users/scovitz/datadir/opencap_data/P041/407/walk/walk.mot
# (1472, 33) P041 407 /Users/scovitz/datadir/opencap_data/P041/407/tug/tug.mot
# (2012, 33) P041 407 /Users/scovitz/datadir/opencap_data/P041/407/toe_stand/toe_stand.mot
# (1955, 33) P041 407 /Users/scovitz/datadir/opencap_data/P041/407/5xsts/5xsts.mot
# (116, 33) P041 407 /Users/scovitz/datadir/opencap_data/P041/407/jump/jump.mot
# (722, 33) P041 407 /Users/scovitz/datadir/opencap_data/P041/407/run/run.mot
# (769, 33) P041 7 /Users/scovitz/datadir/opencap_data/P041/7/walk/walk.mot
# (1502, 33) P041 7 /Users/scovitz/datadir/opencap_data/P041/7/tug/tug.mot
# (2054, 33) P041 7 /Users/scovitz/datadir/opencap_data/P041/7/toe_stand/toe_stand.mot
# (646, 33) P041 7 /Users/scovitz/datadir/opencap_data/P041/7/5xsts/5xsts.mot
# (315, 33) P041 7 /Users/scovitz/datadir/opencap_data/P041/7/jump/jump.mot
# (380, 33) P041 7 /Users/scovitz/datadir/opencap_data/P041/7/run/run.mot
# (782, 33) P042 7 /Users/scovitz/datadir/opencap_data/P042/7/walk/walk.mot
# (879, 33) P042 7 /Users/scovitz/datadir/opencap_data/P042/7/tug/tug.mot
# (2067, 33) P042 7 /Users/scovitz/datadir/opencap_data/P042/7/toe_stand/toe_stand.mot
# (1330, 33) P042 7 /Users/scovitz/datadir/opencap_data/P042/7/5xsts/5xsts.mot
# (121, 33) P042 7 /Users/scovitz/datadir/opencap_data/P042/7/jump/jump.mot
# (265, 33) P042 7 /Users/scovitz/datadir/opencap_data/P042/7/run/run.mot
# (1354, 33) P043 406 /Users/scovitz/datadir/opencap_data/P043/406/walk/walk.mot
# (1764, 33) P043 406 /Users/scovitz/datadir/opencap_data/P043/406/tug/tug.mot
# (2094, 33) P043 406 /Users/scovitz/datadir/opencap_data/P043/406/toe_stand/toe_stand.mot
# (2496, 33) P043 406 /Users/scovitz/datadir/opencap_data/P043/406/5xsts/5xsts.mot
# (280, 33) P043 406 /Users/scovitz/datadir/opencap_data/P043/406/jump/jump.mot
# (1109, 33) P043 406 /Users/scovitz/datadir/opencap_data/P043/406/run/run.mot
# (269, 33) P043 7 /Users/scovitz/datadir/opencap_data/P043/7/walk/walk.mot
# (755, 33) P043 7 /Users/scovitz/datadir/opencap_data/P043/7/tug/tug.mot
# (1894, 33) P043 7 /Users/scovitz/datadir/opencap_data/P043/7/toe_stand/toe_stand.mot
# (1344, 33) P043 7 /Users/scovitz/datadir/opencap_data/P043/7/5xsts/5xsts.mot
# (39, 33) P043 7 /Users/scovitz/datadir/opencap_data/P043/7/jump/jump.mot
# (181, 33) P043 7 /Users/scovitz/datadir/opencap_data/P043/7/run/run.mot
# (1104, 33) P044 406 /Users/scovitz/datadir/opencap_data/P044/406/walk/walk.mot
# (1219, 33) P044 406 /Users/scovitz/datadir/opencap_data/P044/406/tug/tug.mot
# (2133, 33) P044 406 /Users/scovitz/datadir/opencap_data/P044/406/toe_stand/toe_stand.mot
# (1231, 33) P044 406 /Users/scovitz/datadir/opencap_data/P044/406/5xsts/5xsts.mot
# (280, 33) P044 406 /Users/scovitz/datadir/opencap_data/P044/406/jump/jump.mot
# (623, 33) P044 406 /Users/scovitz/datadir/opencap_data/P044/406/run/run.mot
# (757, 33) P044 7 /Users/scovitz/datadir/opencap_data/P044/7/walk/walk.mot
# (1126, 33) P044 7 /Users/scovitz/datadir/opencap_data/P044/7/tug/tug.mot
# (1882, 33) P044 7 /Users/scovitz/datadir/opencap_data/P044/7/toe_stand/toe_stand.mot
# (430, 33) P044 7 /Users/scovitz/datadir/opencap_data/P044/7/5xsts/5xsts.mot
# (57, 33) P044 7 /Users/scovitz/datadir/opencap_data/P044/7/jump/jump.mot
# (424, 33) P044 7 /Users/scovitz/datadir/opencap_data/P044/7/run/run.mot
# (729, 33) P045 7 /Users/scovitz/datadir/opencap_data/P045/7/walk/walk.mot
# (865, 33) P045 7 /Users/scovitz/datadir/opencap_data/P045/7/tug/tug.mot
# (1952, 33) P045 7 /Users/scovitz/datadir/opencap_data/P045/7/toe_stand/toe_stand.mot
# (489, 33) P045 7 /Users/scovitz/datadir/opencap_data/P045/7/5xsts/5xsts.mot
# (252, 33) P045 7 /Users/scovitz/datadir/opencap_data/P045/7/jump/jump.mot
# (554, 33) P045 7 /Users/scovitz/datadir/opencap_data/P045/7/run/run.mot
# (512, 33) P046 406 /Users/scovitz/datadir/opencap_data/P046/406/walk/walk.mot
# (874, 33) P046 406 /Users/scovitz/datadir/opencap_data/P046/406/tug/tug.mot
# (1962, 33) P046 406 /Users/scovitz/datadir/opencap_data/P046/406/toe_stand/toe_stand.mot
# (1343, 33) P046 406 /Users/scovitz/datadir/opencap_data/P046/406/5xsts/5xsts.mot
# (427, 33) P046 406 /Users/scovitz/datadir/opencap_data/P046/406/jump/jump.mot
# (495, 33) P046 406 /Users/scovitz/datadir/opencap_data/P046/406/run/run.mot
# (1983, 33) P046 7 /Users/scovitz/datadir/opencap_data/P046/7/walk/walk.mot
# (1352, 33) P046 7 /Users/scovitz/datadir/opencap_data/P046/7/tug/tug.mot
# (1923, 33) P046 7 /Users/scovitz/datadir/opencap_data/P046/7/toe_stand/toe_stand.mot
# (1292, 33) P046 7 /Users/scovitz/datadir/opencap_data/P046/7/5xsts/5xsts.mot
# (420, 33) P046 7 /Users/scovitz/datadir/opencap_data/P046/7/jump/jump.mot
# (807, 33) P046 7 /Users/scovitz/datadir/opencap_data/P046/7/run/run.mot
# (706, 33) P047 8 /Users/scovitz/datadir/opencap_data/P047/8/walk/walk.mot
# (1029, 33) P047 8 /Users/scovitz/datadir/opencap_data/P047/8/tug/tug.mot
# (1868, 33) P047 8 /Users/scovitz/datadir/opencap_data/P047/8/toe_stand/toe_stand.mot
# (558, 33) P047 8 /Users/scovitz/datadir/opencap_data/P047/8/5xsts/5xsts.mot
# (161, 33) P047 8 /Users/scovitz/datadir/opencap_data/P047/8/jump/jump.mot
# (311, 33) P047 8 /Users/scovitz/datadir/opencap_data/P047/8/run/run.mot
# (1518, 33) P048 8 /Users/scovitz/datadir/opencap_data/P048/8/walk/walk.mot
# (1480, 33) P048 8 /Users/scovitz/datadir/opencap_data/P048/8/tug/tug.mot
# (1960, 33) P048 8 /Users/scovitz/datadir/opencap_data/P048/8/5xsts/5xsts.mot
# (720, 33) P048 8 /Users/scovitz/datadir/opencap_data/P048/8/run/run.mot
# (135, 33) P049 8 /Users/scovitz/datadir/opencap_data/P049/8/walk/walk.mot
# (255, 33) P049 8 /Users/scovitz/datadir/opencap_data/P049/8/tug/tug.mot
# (1867, 33) P049 8 /Users/scovitz/datadir/opencap_data/P049/8/toe_stand/toe_stand.mot
# (512, 33) P049 8 /Users/scovitz/datadir/opencap_data/P049/8/5xsts/5xsts.mot
# (155, 33) P049 8 /Users/scovitz/datadir/opencap_data/P049/8/jump/jump.mot
# (69, 33) P049 8 /Users/scovitz/datadir/opencap_data/P049/8/run/run.mot
# (2095, 33) P050 8 /Users/scovitz/datadir/opencap_data/P050/8/walk/walk.mot
# (1506, 33) P050 8 /Users/scovitz/datadir/opencap_data/P050/8/tug/tug.mot
# (1642, 33) P050 8 /Users/scovitz/datadir/opencap_data/P050/8/toe_stand/toe_stand.mot
# (1238, 33) P050 8 /Users/scovitz/datadir/opencap_data/P050/8/5xsts/5xsts.mot
# (1182, 33) P050 8 /Users/scovitz/datadir/opencap_data/P050/8/jump/jump.mot
# (1112, 33) P050 8 /Users/scovitz/datadir/opencap_data/P050/8/run/run.mot
# (668, 33) P051 8 /Users/scovitz/datadir/opencap_data/P051/8/walk/walk.mot
# (996, 33) P051 8 /Users/scovitz/datadir/opencap_data/P051/8/tug/tug.mot
# (1841, 33) P051 8 /Users/scovitz/datadir/opencap_data/P051/8/toe_stand/toe_stand.mot
# (394, 33) P051 8 /Users/scovitz/datadir/opencap_data/P051/8/5xsts/5xsts.mot
# (251, 33) P051 8 /Users/scovitz/datadir/opencap_data/P051/8/jump/jump.mot
# (398, 33) P051 8 /Users/scovitz/datadir/opencap_data/P051/8/run/run.mot
# (692, 33) P052 8 /Users/scovitz/datadir/opencap_data/P052/8/walk/walk.mot
# (1212, 33) P052 8 /Users/scovitz/datadir/opencap_data/P052/8/tug/tug.mot
# (1974, 33) P052 8 /Users/scovitz/datadir/opencap_data/P052/8/toe_stand/toe_stand.mot
# (435, 33) P052 8 /Users/scovitz/datadir/opencap_data/P052/8/5xsts/5xsts.mot
# (143, 33) P052 8 /Users/scovitz/datadir/opencap_data/P052/8/jump/jump.mot
# (337, 33) P052 8 /Users/scovitz/datadir/opencap_data/P052/8/run/run.mot
# (715, 33) P053 8 /Users/scovitz/datadir/opencap_data/P053/8/walk/walk.mot
# (1163, 33) P053 8 /Users/scovitz/datadir/opencap_data/P053/8/tug/tug.mot
# (1881, 33) P053 8 /Users/scovitz/datadir/opencap_data/P053/8/toe_stand/toe_stand.mot
# (524, 33) P053 8 /Users/scovitz/datadir/opencap_data/P053/8/5xsts/5xsts.mot
# (143, 33) P053 8 /Users/scovitz/datadir/opencap_data/P053/8/jump/jump.mot
# (296, 33) P053 8 /Users/scovitz/datadir/opencap_data/P053/8/run/run.mot
# (700, 33) P054 8 /Users/scovitz/datadir/opencap_data/P054/8/walk/walk.mot
# (693, 33) P054 8 /Users/scovitz/datadir/opencap_data/P054/8/tug/tug.mot
# (1938, 33) P054 8 /Users/scovitz/datadir/opencap_data/P054/8/toe_stand/toe_stand.mot
# (776, 33) P054 8 /Users/scovitz/datadir/opencap_data/P054/8/5xsts/5xsts.mot
# (95, 33) P054 8 /Users/scovitz/datadir/opencap_data/P054/8/jump/jump.mot
# (396, 33) P054 8 /Users/scovitz/datadir/opencap_data/P054/8/run/run.mot
# (1461, 33) P055 406 /Users/scovitz/datadir/opencap_data/P055/406/walk/walk.mot
# (1435, 33) P055 406 /Users/scovitz/datadir/opencap_data/P055/406/tug/tug.mot
# (2166, 33) P055 406 /Users/scovitz/datadir/opencap_data/P055/406/toe_stand/toe_stand.mot
# (1718, 33) P055 406 /Users/scovitz/datadir/opencap_data/P055/406/5xsts/5xsts.mot
# (233, 33) P055 406 /Users/scovitz/datadir/opencap_data/P055/406/jump/jump.mot
# (653, 33) P055 406 /Users/scovitz/datadir/opencap_data/P055/406/run/run.mot
# (480, 33) P055 8 /Users/scovitz/datadir/opencap_data/P055/8/walk/walk.mot
# (1187, 33) P055 8 /Users/scovitz/datadir/opencap_data/P055/8/tug/tug.mot
# (1965, 33) P055 8 /Users/scovitz/datadir/opencap_data/P055/8/toe_stand/toe_stand.mot
# (811, 33) P055 8 /Users/scovitz/datadir/opencap_data/P055/8/5xsts/5xsts.mot
# (193, 33) P055 8 /Users/scovitz/datadir/opencap_data/P055/8/jump/jump.mot
# (585, 33) P055 8 /Users/scovitz/datadir/opencap_data/P055/8/run/run.mot
# (330, 33) P056 8 /Users/scovitz/datadir/opencap_data/P056/8/walk/walk.mot
# (533, 33) P056 8 /Users/scovitz/datadir/opencap_data/P056/8/tug/tug.mot
# (1890, 33) P056 8 /Users/scovitz/datadir/opencap_data/P056/8/toe_stand/toe_stand.mot
# (1688, 33) P056 8 /Users/scovitz/datadir/opencap_data/P056/8/5xsts/5xsts.mot
# (318, 33) P056 8 /Users/scovitz/datadir/opencap_data/P056/8/jump/jump.mot
# (182, 33) P056 8 /Users/scovitz/datadir/opencap_data/P056/8/run/run.mot
# (1186, 33) P057 406 /Users/scovitz/datadir/opencap_data/P057/406/walk/walk.mot
# (1451, 33) P057 406 /Users/scovitz/datadir/opencap_data/P057/406/tug/tug.mot
# (2140, 33) P057 406 /Users/scovitz/datadir/opencap_data/P057/406/toe_stand/toe_stand.mot
# (2053, 33) P057 406 /Users/scovitz/datadir/opencap_data/P057/406/5xsts/5xsts.mot
# (274, 33) P057 406 /Users/scovitz/datadir/opencap_data/P057/406/jump/jump.mot
# (879, 33) P057 406 /Users/scovitz/datadir/opencap_data/P057/406/run/run.mot
# (580, 33) P057 8 /Users/scovitz/datadir/opencap_data/P057/8/walk/walk.mot
# (967, 33) P057 8 /Users/scovitz/datadir/opencap_data/P057/8/tug/tug.mot
# (2008, 33) P057 8 /Users/scovitz/datadir/opencap_data/P057/8/toe_stand/toe_stand.mot
# (981, 33) P057 8 /Users/scovitz/datadir/opencap_data/P057/8/5xsts/5xsts.mot
# (161, 33) P057 8 /Users/scovitz/datadir/opencap_data/P057/8/jump/jump.mot
# (357, 33) P057 8 /Users/scovitz/datadir/opencap_data/P057/8/run/run.mot
# (96, 33) P058 8 /Users/scovitz/datadir/opencap_data/P058/8/walk/walk.mot
# (227, 33) P058 8 /Users/scovitz/datadir/opencap_data/P058/8/tug/tug.mot
# (1824, 33) P058 8 /Users/scovitz/datadir/opencap_data/P058/8/toe_stand/toe_stand.mot
# (1229, 33) P058 8 /Users/scovitz/datadir/opencap_data/P058/8/5xsts/5xsts.mot
# (158, 33) P058 8 /Users/scovitz/datadir/opencap_data/P058/8/jump/jump.mot
# (0, 33) P058 8 /Users/scovitz/datadir/opencap_data/P058/8/run/run.mot
# (574, 33) P059 8 /Users/scovitz/datadir/opencap_data/P059/8/walk/walk.mot
# (936, 33) P059 8 /Users/scovitz/datadir/opencap_data/P059/8/tug/tug.mot
# (1868, 33) P059 8 /Users/scovitz/datadir/opencap_data/P059/8/toe_stand/toe_stand.mot
# (471, 33) P059 8 /Users/scovitz/datadir/opencap_data/P059/8/5xsts/5xsts.mot
# (203, 33) P059 8 /Users/scovitz/datadir/opencap_data/P059/8/jump/jump.mot
# (341, 33) P059 8 /Users/scovitz/datadir/opencap_data/P059/8/run/run.mot
# (520, 33) P060 8 /Users/scovitz/datadir/opencap_data/P060/8/walk/walk.mot
# (684, 33) P060 8 /Users/scovitz/datadir/opencap_data/P060/8/tug/tug.mot
# (1866, 33) P060 8 /Users/scovitz/datadir/opencap_data/P060/8/toe_stand/toe_stand.mot
# (536, 33) P060 8 /Users/scovitz/datadir/opencap_data/P060/8/5xsts/5xsts.mot
# (119, 33) P060 8 /Users/scovitz/datadir/opencap_data/P060/8/jump/jump.mot
# (496, 33) P060 8 /Users/scovitz/datadir/opencap_data/P060/8/run/run.mot
# (491, 33) P061 8 /Users/scovitz/datadir/opencap_data/P061/8/walk/walk.mot
# (989, 33) P061 8 /Users/scovitz/datadir/opencap_data/P061/8/tug/tug.mot
# (1959, 33) P061 8 /Users/scovitz/datadir/opencap_data/P061/8/toe_stand/toe_stand.mot
# (459, 33) P061 8 /Users/scovitz/datadir/opencap_data/P061/8/5xsts/5xsts.mot
# (246, 33) P061 8 /Users/scovitz/datadir/opencap_data/P061/8/jump/jump.mot
# (876, 33) P061 8 /Users/scovitz/datadir/opencap_data/P061/8/run/run.mot
# (831, 33) P062 8 /Users/scovitz/datadir/opencap_data/P062/8/walk/walk.mot
# (540, 33) P062 8 /Users/scovitz/datadir/opencap_data/P062/8/tug/tug.mot
# (1793, 33) P062 8 /Users/scovitz/datadir/opencap_data/P062/8/toe_stand/toe_stand.mot
# (545, 33) P062 8 /Users/scovitz/datadir/opencap_data/P062/8/5xsts/5xsts.mot
# (221, 33) P062 8 /Users/scovitz/datadir/opencap_data/P062/8/jump/jump.mot
# (250, 33) P062 8 /Users/scovitz/datadir/opencap_data/P062/8/run/run.mot
# (1291, 33) P063 8 /Users/scovitz/datadir/opencap_data/P063/8/walk/walk.mot
# (1650, 33) P063 8 /Users/scovitz/datadir/opencap_data/P063/8/tug/tug.mot
# (1861, 33) P063 8 /Users/scovitz/datadir/opencap_data/P063/8/toe_stand/toe_stand.mot
# (649, 33) P063 8 /Users/scovitz/datadir/opencap_data/P063/8/5xsts/5xsts.mot
# (400, 33) P063 8 /Users/scovitz/datadir/opencap_data/P063/8/jump/jump.mot
# (187, 33) P063 8 /Users/scovitz/datadir/opencap_data/P063/8/run/run.mot
# (675, 33) P064 406 /Users/scovitz/datadir/opencap_data/P064/406/walk/walk.mot
# (976, 33) P064 406 /Users/scovitz/datadir/opencap_data/P064/406/tug/tug.mot
# (2006, 33) P064 406 /Users/scovitz/datadir/opencap_data/P064/406/toe_stand/toe_stand.mot
# (1462, 33) P064 406 /Users/scovitz/datadir/opencap_data/P064/406/5xsts/5xsts.mot
# (206, 33) P064 406 /Users/scovitz/datadir/opencap_data/P064/406/jump/jump.mot
# (618, 33) P064 406 /Users/scovitz/datadir/opencap_data/P064/406/run/run.mot
# (527, 33) P064 8 /Users/scovitz/datadir/opencap_data/P064/8/walk/walk.mot
# (927, 33) P064 8 /Users/scovitz/datadir/opencap_data/P064/8/tug/tug.mot
# (1815, 33) P064 8 /Users/scovitz/datadir/opencap_data/P064/8/toe_stand/toe_stand.mot
# (531, 33) P064 8 /Users/scovitz/datadir/opencap_data/P064/8/5xsts/5xsts.mot
# (120, 33) P064 8 /Users/scovitz/datadir/opencap_data/P064/8/jump/jump.mot
# (317, 33) P064 8 /Users/scovitz/datadir/opencap_data/P064/8/run/run.mot
# (812, 33) P065 8 /Users/scovitz/datadir/opencap_data/P065/8/walk/walk.mot
# (1004, 33) P065 8 /Users/scovitz/datadir/opencap_data/P065/8/tug/tug.mot
# (1899, 33) P065 8 /Users/scovitz/datadir/opencap_data/P065/8/toe_stand/toe_stand.mot
# (552, 33) P065 8 /Users/scovitz/datadir/opencap_data/P065/8/5xsts/5xsts.mot
# (158, 33) P065 8 /Users/scovitz/datadir/opencap_data/P065/8/jump/jump.mot
# (443, 33) P065 8 /Users/scovitz/datadir/opencap_data/P065/8/run/run.mot
# (383, 33) P066 8 /Users/scovitz/datadir/opencap_data/P066/8/walk/walk.mot
# (814, 33) P066 8 /Users/scovitz/datadir/opencap_data/P066/8/tug/tug.mot
# (1848, 33) P066 8 /Users/scovitz/datadir/opencap_data/P066/8/toe_stand/toe_stand.mot
# (320, 33) P066 8 /Users/scovitz/datadir/opencap_data/P066/8/5xsts/5xsts.mot
# (36, 33) P066 8 /Users/scovitz/datadir/opencap_data/P066/8/jump/jump.mot
# (296, 33) P066 8 /Users/scovitz/datadir/opencap_data/P066/8/run/run.mot
# (824, 33) P067 8 /Users/scovitz/datadir/opencap_data/P067/8/walk/walk.mot
# (1106, 33) P067 8 /Users/scovitz/datadir/opencap_data/P067/8/tug/tug.mot
# (1776, 33) P067 8 /Users/scovitz/datadir/opencap_data/P067/8/toe_stand/toe_stand.mot
# (2764, 33) P067 8 /Users/scovitz/datadir/opencap_data/P067/8/5xsts/5xsts.mot
# (305, 33) P067 8 /Users/scovitz/datadir/opencap_data/P067/8/jump/jump.mot
# (675, 33) P067 8 /Users/scovitz/datadir/opencap_data/P067/8/run/run.mot
# (644, 33) P068 8 /Users/scovitz/datadir/opencap_data/P068/8/walk/walk.mot
# (792, 33) P068 8 /Users/scovitz/datadir/opencap_data/P068/8/tug/tug.mot
# (1881, 33) P068 8 /Users/scovitz/datadir/opencap_data/P068/8/toe_stand/toe_stand.mot
# (441, 33) P068 8 /Users/scovitz/datadir/opencap_data/P068/8/5xsts/5xsts.mot
# (158, 33) P068 8 /Users/scovitz/datadir/opencap_data/P068/8/jump/jump.mot
# (230, 33) P068 8 /Users/scovitz/datadir/opencap_data/P068/8/run/run.mot
# (1127, 33) P069 8 /Users/scovitz/datadir/opencap_data/P069/8/walk/walk.mot
# (1178, 33) P069 8 /Users/scovitz/datadir/opencap_data/P069/8/tug/tug.mot
# (1927, 33) P069 8 /Users/scovitz/datadir/opencap_data/P069/8/toe_stand/toe_stand.mot
# (539, 33) P069 8 /Users/scovitz/datadir/opencap_data/P069/8/5xsts/5xsts.mot
# (363, 33) P069 8 /Users/scovitz/datadir/opencap_data/P069/8/jump/jump.mot
# (202, 33) P069 8 /Users/scovitz/datadir/opencap_data/P069/8/run/run.mot
# (1052, 33) P070 407 /Users/scovitz/datadir/opencap_data/P070/407/walk/walk.mot
# (1612, 33) P070 407 /Users/scovitz/datadir/opencap_data/P070/407/tug/tug.mot
# (2287, 33) P070 407 /Users/scovitz/datadir/opencap_data/P070/407/toe_stand/toe_stand.mot
# (1819, 33) P070 407 /Users/scovitz/datadir/opencap_data/P070/407/5xsts/5xsts.mot
# (220, 33) P070 407 /Users/scovitz/datadir/opencap_data/P070/407/jump/jump.mot
# (808, 33) P070 407 /Users/scovitz/datadir/opencap_data/P070/407/run/run.mot
# (680, 33) P070 8 /Users/scovitz/datadir/opencap_data/P070/8/walk/walk.mot
# (743, 33) P070 8 /Users/scovitz/datadir/opencap_data/P070/8/tug/tug.mot
# (1841, 33) P070 8 /Users/scovitz/datadir/opencap_data/P070/8/toe_stand/toe_stand.mot
# (624, 33) P070 8 /Users/scovitz/datadir/opencap_data/P070/8/5xsts/5xsts.mot
# (119, 33) P070 8 /Users/scovitz/datadir/opencap_data/P070/8/jump/jump.mot
# (430, 33) P070 8 /Users/scovitz/datadir/opencap_data/P070/8/run/run.mot
# (525, 33) P071 8 /Users/scovitz/datadir/opencap_data/P071/8/walk/walk.mot
# (1022, 33) P071 8 /Users/scovitz/datadir/opencap_data/P071/8/tug/tug.mot
# (1747, 33) P071 8 /Users/scovitz/datadir/opencap_data/P071/8/toe_stand/toe_stand.mot
# (411, 33) P071 8 /Users/scovitz/datadir/opencap_data/P071/8/5xsts/5xsts.mot
# (193, 33) P071 8 /Users/scovitz/datadir/opencap_data/P071/8/jump/jump.mot
# (345, 33) P071 8 /Users/scovitz/datadir/opencap_data/P071/8/run/run.mot
# (773, 33) P072 8 /Users/scovitz/datadir/opencap_data/P072/8/walk/walk.mot
# (1196, 33) P072 8 /Users/scovitz/datadir/opencap_data/P072/8/tug/tug.mot
# (2124, 33) P072 8 /Users/scovitz/datadir/opencap_data/P072/8/toe_stand/toe_stand.mot
# (1050, 33) P072 8 /Users/scovitz/datadir/opencap_data/P072/8/5xsts/5xsts.mot
# (296, 33) P072 8 /Users/scovitz/datadir/opencap_data/P072/8/jump/jump.mot
# (686, 33) P072 8 /Users/scovitz/datadir/opencap_data/P072/8/run/run.mot
# (1131, 33) P073 406 /Users/scovitz/datadir/opencap_data/P073/406/walk/walk.mot
# (1706, 33) P073 406 /Users/scovitz/datadir/opencap_data/P073/406/tug/tug.mot
# (2161, 33) P073 406 /Users/scovitz/datadir/opencap_data/P073/406/toe_stand/toe_stand.mot
# (1965, 33) P073 406 /Users/scovitz/datadir/opencap_data/P073/406/5xsts/5xsts.mot
# (294, 33) P073 406 /Users/scovitz/datadir/opencap_data/P073/406/jump/jump.mot
# (803, 33) P073 406 /Users/scovitz/datadir/opencap_data/P073/406/run/run.mot
# (321, 33) P073 29 /Users/scovitz/datadir/opencap_data/P073/29/walk/walk.mot
# (517, 33) P073 29 /Users/scovitz/datadir/opencap_data/P073/29/tug/tug.mot
# (1939, 33) P073 29 /Users/scovitz/datadir/opencap_data/P073/29/toe_stand/toe_stand.mot
# (750, 33) P073 29 /Users/scovitz/datadir/opencap_data/P073/29/5xsts/5xsts.mot
# (94, 33) P073 29 /Users/scovitz/datadir/opencap_data/P073/29/jump/jump.mot
# (248, 33) P073 29 /Users/scovitz/datadir/opencap_data/P073/29/run/run.mot
# (937, 33) P073 8 /Users/scovitz/datadir/opencap_data/P073/8/walk/walk.mot
# (1916, 33) P073 8 /Users/scovitz/datadir/opencap_data/P073/8/tug/tug.mot
# (1908, 33) P073 8 /Users/scovitz/datadir/opencap_data/P073/8/toe_stand/toe_stand.mot
# (930, 33) P073 8 /Users/scovitz/datadir/opencap_data/P073/8/5xsts/5xsts.mot
# (147, 33) P073 8 /Users/scovitz/datadir/opencap_data/P073/8/jump/jump.mot
# (194, 33) P073 8 /Users/scovitz/datadir/opencap_data/P073/8/run/run.mot
# (1123, 33) P074 8 /Users/scovitz/datadir/opencap_data/P074/8/walk/walk.mot
# (1193, 33) P074 8 /Users/scovitz/datadir/opencap_data/P074/8/tug/tug.mot
# (1871, 33) P074 8 /Users/scovitz/datadir/opencap_data/P074/8/toe_stand/toe_stand.mot
# (738, 33) P074 8 /Users/scovitz/datadir/opencap_data/P074/8/5xsts/5xsts.mot
# (185, 33) P074 8 /Users/scovitz/datadir/opencap_data/P074/8/jump/jump.mot
# (1014, 33) P074 8 /Users/scovitz/datadir/opencap_data/P074/8/run/run.mot
# (1649, 33) P075 8 /Users/scovitz/datadir/opencap_data/P075/8/walk/walk.mot
# (1805, 33) P075 8 /Users/scovitz/datadir/opencap_data/P075/8/tug/tug.mot
# (2023, 33) P075 8 /Users/scovitz/datadir/opencap_data/P075/8/toe_stand/toe_stand.mot
# (2049, 33) P075 8 /Users/scovitz/datadir/opencap_data/P075/8/5xsts/5xsts.mot
# (126, 33) P075 8 /Users/scovitz/datadir/opencap_data/P075/8/jump/jump.mot
# (1489, 33) P075 8 /Users/scovitz/datadir/opencap_data/P075/8/run/run.mot
# (209, 33) P076 8 /Users/scovitz/datadir/opencap_data/P076/8/walk/walk.mot
# (300, 33) P076 8 /Users/scovitz/datadir/opencap_data/P076/8/tug/tug.mot
# (1904, 33) P076 8 /Users/scovitz/datadir/opencap_data/P076/8/toe_stand/toe_stand.mot
# (449, 33) P076 8 /Users/scovitz/datadir/opencap_data/P076/8/5xsts/5xsts.mot
# (99, 33) P076 8 /Users/scovitz/datadir/opencap_data/P076/8/jump/jump.mot
# (34, 33) P076 8 /Users/scovitz/datadir/opencap_data/P076/8/run/run.mot
# (734, 33) P077 8 /Users/scovitz/datadir/opencap_data/P077/8/walk/walk.mot
# (1347, 33) P077 8 /Users/scovitz/datadir/opencap_data/P077/8/tug/tug.mot
# (1847, 33) P077 8 /Users/scovitz/datadir/opencap_data/P077/8/toe_stand/toe_stand.mot
# (726, 33) P077 8 /Users/scovitz/datadir/opencap_data/P077/8/5xsts/5xsts.mot
# (154, 33) P077 8 /Users/scovitz/datadir/opencap_data/P077/8/jump/jump.mot
# (441, 33) P077 8 /Users/scovitz/datadir/opencap_data/P077/8/run/run.mot
# (534, 33) P078 8 /Users/scovitz/datadir/opencap_data/P078/8/walk/walk.mot
# (1001, 33) P078 8 /Users/scovitz/datadir/opencap_data/P078/8/tug/tug.mot
# (1840, 33) P078 8 /Users/scovitz/datadir/opencap_data/P078/8/toe_stand/toe_stand.mot
# (727, 33) P078 8 /Users/scovitz/datadir/opencap_data/P078/8/5xsts/5xsts.mot
# (184, 33) P078 8 /Users/scovitz/datadir/opencap_data/P078/8/jump/jump.mot
# (831, 33) P078 8 /Users/scovitz/datadir/opencap_data/P078/8/run/run.mot
# (780, 33) P079 8 /Users/scovitz/datadir/opencap_data/P079/8/walk/walk.mot
# (1478, 33) P079 8 /Users/scovitz/datadir/opencap_data/P079/8/tug/tug.mot
# (1960, 33) P079 8 /Users/scovitz/datadir/opencap_data/P079/8/toe_stand/toe_stand.mot
# (1349, 33) P079 8 /Users/scovitz/datadir/opencap_data/P079/8/5xsts/5xsts.mot
# (218, 33) P079 8 /Users/scovitz/datadir/opencap_data/P079/8/jump/jump.mot
# (762, 33) P079 8 /Users/scovitz/datadir/opencap_data/P079/8/run/run.mot
# (644, 33) P080 11 /Users/scovitz/datadir/opencap_data/P080/11/walk/walk.mot
# (1066, 33) P080 11 /Users/scovitz/datadir/opencap_data/P080/11/tug/tug.mot
# (2004, 33) P080 11 /Users/scovitz/datadir/opencap_data/P080/11/toe_stand/toe_stand.mot
# (509, 33) P080 11 /Users/scovitz/datadir/opencap_data/P080/11/5xsts/5xsts.mot
# (223, 33) P080 11 /Users/scovitz/datadir/opencap_data/P080/11/jump/jump.mot
# (366, 33) P080 11 /Users/scovitz/datadir/opencap_data/P080/11/run/run.mot
# (738, 33) P081 17 /Users/scovitz/datadir/opencap_data/P081/17/walk/walk.mot
# (1123, 33) P081 17 /Users/scovitz/datadir/opencap_data/P081/17/tug/tug.mot
# (2036, 33) P081 17 /Users/scovitz/datadir/opencap_data/P081/17/toe_stand/toe_stand.mot
# (862, 33) P081 17 /Users/scovitz/datadir/opencap_data/P081/17/5xsts/5xsts.mot
# (305, 33) P081 17 /Users/scovitz/datadir/opencap_data/P081/17/jump/jump.mot
# (553, 33) P081 17 /Users/scovitz/datadir/opencap_data/P081/17/run/run.mot
# (472, 33) P082 29 /Users/scovitz/datadir/opencap_data/P082/29/walk/walk.mot
# (756, 33) P082 29 /Users/scovitz/datadir/opencap_data/P082/29/tug/tug.mot
# (2147, 33) P082 29 /Users/scovitz/datadir/opencap_data/P082/29/toe_stand/toe_stand.mot
# (862, 33) P082 29 /Users/scovitz/datadir/opencap_data/P082/29/5xsts/5xsts.mot
# (163, 33) P082 29 /Users/scovitz/datadir/opencap_data/P082/29/jump/jump.mot
# (366, 33) P082 29 /Users/scovitz/datadir/opencap_data/P082/29/run/run.mot
# (702, 33) P083 30 /Users/scovitz/datadir/opencap_data/P083/30/walk/walk.mot
# (1112, 33) P083 30 /Users/scovitz/datadir/opencap_data/P083/30/tug/tug.mot
# (1927, 33) P083 30 /Users/scovitz/datadir/opencap_data/P083/30/toe_stand/toe_stand.mot
# (814, 33) P083 30 /Users/scovitz/datadir/opencap_data/P083/30/5xsts/5xsts.mot
# (151, 33) P083 30 /Users/scovitz/datadir/opencap_data/P083/30/jump/jump.mot
# (506, 33) P083 30 /Users/scovitz/datadir/opencap_data/P083/30/run/run.mot
# (764, 33) P084 31 /Users/scovitz/datadir/opencap_data/P084/31/walk/walk.mot
# (940, 33) P084 31 /Users/scovitz/datadir/opencap_data/P084/31/tug/tug.mot
# (1938, 33) P084 31 /Users/scovitz/datadir/opencap_data/P084/31/toe_stand/toe_stand.mot
# (498, 33) P084 31 /Users/scovitz/datadir/opencap_data/P084/31/5xsts/5xsts.mot
# (164, 33) P084 31 /Users/scovitz/datadir/opencap_data/P084/31/jump/jump.mot
# (423, 33) P084 31 /Users/scovitz/datadir/opencap_data/P084/31/run/run.mot
# (330, 33) P085 32 /Users/scovitz/datadir/opencap_data/P085/32/walk/walk.mot
# (280, 33) P085 32 /Users/scovitz/datadir/opencap_data/P085/32/tug/tug.mot
# (1882, 33) P085 32 /Users/scovitz/datadir/opencap_data/P085/32/toe_stand/toe_stand.mot
# (499, 33) P085 32 /Users/scovitz/datadir/opencap_data/P085/32/5xsts/5xsts.mot
# (226, 33) P085 32 /Users/scovitz/datadir/opencap_data/P085/32/jump/jump.mot
# (0, 33) P085 32 /Users/scovitz/datadir/opencap_data/P085/32/run/run.mot
# (961, 33) P085 407 /Users/scovitz/datadir/opencap_data/P085/407/walk/walk.mot
# (1227, 33) P085 407 /Users/scovitz/datadir/opencap_data/P085/407/tug/tug.mot
# (2026, 33) P085 407 /Users/scovitz/datadir/opencap_data/P085/407/toe_stand/toe_stand.mot
# ...
# (648, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/walk/walk.mot
# (658, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/tug/tug.mot
# (2024, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/toe_stand/toe_stand.mot
# (968, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/5xsts/5xsts.mot
# (83, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/jump/jump.mot
# (290, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/run/run.mot
# (951, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/walk/walk.mot
# (1238, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/tug/tug.mot
# (1673, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/toe_stand/toe_stand.mot
# (2696, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/5xsts/5xsts.mot
# (156, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/jump/jump.mot
# (464, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/run/run.mot
# (623, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/walk/walk.mot
# (1574, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/tug/tug.mot
# (2319, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/toe_stand/toe_stand.mot
# (2787, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/5xsts/5xsts.mot
# (18, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/jump/jump.mot
# (577, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/run/run.mot
# (518, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/walk/walk.mot
# (852, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/tug/tug.mot
# (1920, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/toe_stand/toe_stand.mot
# (1237, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/5xsts/5xsts.mot
# (102, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/jump/jump.mot
# (54, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/run/run.mot
# (638, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/walk/walk.mot
# (1040, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/tug/tug.mot
# (2007, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/toe_stand/toe_stand.mot
# (1703, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/5xsts/5xsts.mot
# (42, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/jump/jump.mot
# (233, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/run/run.mot
# (778, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/walk/walk.mot
# (1233, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/tug/tug.mot
# (1828, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/toe_stand/toe_stand.mot
# (1818, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/5xsts/5xsts.mot
# (22, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/jump/jump.mot
# (53, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/run/run.mot
# (800, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/walk/walk.mot
# (996, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/tug/tug.mot
# (1883, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/toe_stand/toe_stand.mot
# (1336, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/5xsts/5xsts.mot
# (34, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/jump/jump.mot
# (282, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/run/run.mot
# (740, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/walk/walk.mot
# (1668, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/tug/tug.mot
# (2019, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/toe_stand/toe_stand.mot
# (1798, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/5xsts/5xsts.mot
# (40, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/jump/jump.mot
# (108, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/run/run.mot
# (877, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/walk/walk.mot
# (1609, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/tug/tug.mot
# (2400, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/5xsts/5xsts.mot
# (71, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/jump/jump.mot
# (692, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/run/run.mot
# (655, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/walk/walk.mot
# (697, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/tug/tug.mot
# (1932, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/toe_stand/toe_stand.mot
# (1567, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/5xsts/5xsts.mot
# (69, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/jump/jump.mot
# (125, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/run/run.mot
# (652, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/walk/walk.mot
# (780, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/tug/tug.mot
# (2090, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/toe_stand/toe_stand.mot
# (841, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/5xsts/5xsts.mot
# (0, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/jump/jump.mot
# (291, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/run/run.mot
# (636, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/walk/walk.mot
# (1114, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/tug/tug.mot
# (2026, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/toe_stand/toe_stand.mot
# (1816, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/5xsts/5xsts.mot
# (46, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/jump/jump.mot
# (279, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/run/run.mot
# (486, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/walk/walk.mot
# (983, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/tug/tug.mot
# (1748, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/toe_stand/toe_stand.mot
# (2182, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/5xsts/5xsts.mot
# (9, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/jump/jump.mot
# (330, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/run/run.mot
# (704, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/walk/walk.mot
# (877, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/tug/tug.mot
# (1932, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/toe_stand/toe_stand.mot
# (1204, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/5xsts/5xsts.mot
# (0, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/jump/jump.mot
# (332, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/run/run.mot
# (383, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/walk/walk.mot
# (976, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/tug/tug.mot
# (1847, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/toe_stand/toe_stand.mot
# (1353, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/5xsts/5xsts.mot
# (12, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/jump/jump.mot
# (602, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/run/run.mot
# (810, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/walk/walk.mot
# (980, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/tug/tug.mot
# (974, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/5xsts/5xsts.mot
# (9, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/jump/jump.mot
# (504, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/run/run.mot
# (532, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/walk/walk.mot
# (997, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/tug/tug.mot
# (1926, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/toe_stand/toe_stand.mot
# (1438, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/5xsts/5xsts.mot
# (0, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/jump/jump.mot
# (225, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/run/run.mot
# (555, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/walk/walk.mot
# (868, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/tug/tug.mot
# (2176, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/toe_stand/toe_stand.mot
# (1707, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/5xsts/5xsts.mot
# (258, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/jump/jump.mot
# (392, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/run/run.mot
# (1119, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/walk/walk.mot
# (1697, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/tug/tug.mot
# (2054, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/toe_stand/toe_stand.mot
# (2297, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/5xsts/5xsts.mot
# (331, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/jump/jump.mot
# (952, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/run/run.mot
# (1633, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/walk/walk.mot
# (1648, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/tug/tug.mot
# (2196, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/toe_stand/toe_stand.mot
# (2486, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/5xsts/5xsts.mot
# (361, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/jump/jump.mot
# (611, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/run/run.mot
# (465, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/walk/walk.mot
# (781, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/tug/tug.mot
# (2101, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/toe_stand/toe_stand.mot
# (1337, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/5xsts/5xsts.mot
# (335, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/jump/jump.mot
# (329, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/run/run.mot
# (1142, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/walk/walk.mot
# (1343, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/tug/tug.mot
# (1984, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/toe_stand/toe_stand.mot
# (2068, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/5xsts/5xsts.mot
# (277, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/jump/jump.mot
# (622, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/run/run.mot
# (902, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/walk/walk.mot
# (1178, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/tug/tug.mot
# (2019, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/toe_stand/toe_stand.mot
# (1280, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/5xsts/5xsts.mot
# (204, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/jump/jump.mot
# (557, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/run/run.mot
# (1032, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/walk/walk.mot
# (1341, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/tug/tug.mot
# (2070, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/toe_stand/toe_stand.mot
# (1614, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/5xsts/5xsts.mot
# (184, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/jump/jump.mot
# (697, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/run/run.mot
# (971, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/walk/walk.mot
# (1340, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/tug/tug.mot
# (2020, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/toe_stand/toe_stand.mot
# (1836, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/5xsts/5xsts.mot
# (217, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/jump/jump.mot
# (605, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/run/run.mot
# (1974, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/walk/walk.mot
# (2042, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/tug/tug.mot
# (2111, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/toe_stand/toe_stand.mot
# (1483, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/5xsts/5xsts.mot
# (385, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/jump/jump.mot
# (1547, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/run/run.mot
# (381, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/walk/walk.mot
# (668, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/tug/tug.mot
# (2198, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/toe_stand/toe_stand.mot
# (882, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/5xsts/5xsts.mot
# (279, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/jump/jump.mot
# (247, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/run/run.mot
# (199, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/walk/walk.mot
# (397, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/tug/tug.mot
# (2006, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/toe_stand/toe_stand.mot
# (517, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/5xsts/5xsts.mot
# (321, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/jump/jump.mot
# (149, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/run/run.mot
# (1548, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/walk/walk.mot
# (1798, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/tug/tug.mot
# (3331, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/5xsts/5xsts.mot
# (153, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/jump/jump.mot
# (1176, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/run/run.mot
# (853, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/walk/walk.mot
# (994, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/tug/tug.mot
# (1951, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/toe_stand/toe_stand.mot
# (969, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/5xsts/5xsts.mot
# (206, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/jump/jump.mot
# (365, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/run/run.mot
# (802, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/walk/walk.mot
# (776, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/tug/tug.mot
# (2000, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/toe_stand/toe_stand.mot
# (960, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/5xsts/5xsts.mot
# (265, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/jump/jump.mot
# (287, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/run/run.mot
# (792, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/walk/walk.mot
# (999, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/tug/tug.mot
# (1840, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/toe_stand/toe_stand.mot
# (1229, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/5xsts/5xsts.mot
# (39, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/jump/jump.mot
# (279, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/run/run.mot
# (630, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/walk/walk.mot
# (1462, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/tug/tug.mot
# (1886, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/toe_stand/toe_stand.mot
# (1162, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/5xsts/5xsts.mot
# (83, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/jump/jump.mot
# (477, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/run/run.mot
# (610, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/walk/walk.mot
# (760, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/tug/tug.mot
# (1815, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/toe_stand/toe_stand.mot
# (1178, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/5xsts/5xsts.mot
# (21, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/jump/jump.mot
# (284, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/run/run.mot

# %%
len(time_series_data)
time_series_data

# %%
# Prepare the LSTM input
lstm_input, subject_ids, mean, std = prepare_lstm_input(time_series_data)

# Check the results
print("LSTM Input Shape:", lstm_input.shape)  # (162, max_timesteps, 35)
print("Subject IDs:", subject_ids[:5])  # subject ID ordering, should be in order! 
print("Mean Shape:", mean.shape)  # shape of mean: (35,)
print("Std Shape:", std.shape)  # shape of std: (35,)

# %%
# Convert labels to a numpy array
labels = []
for sid in subject_ids:
    pid = sid.split('_')[0]
    trial = sid.split('_')[1]
    label = get_label_for_participant_trial(class_df, pid, trial)
    labels.append(label)

# %%
# convert to numpy array
labels = np.array(labels)

# %%
# Define LSTM model
# def build_lstm_model_1(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking for padded values
#         LSTM(64, return_sequences=True),  # First LSTM layer
#         Dropout(0.3),  # Dropout for regularization
#         LSTM(32),  # Second LSTM layer
#         Dropout(0.3),
#         Dense(16, activation='relu'),  # Fully connected layer
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# %%
# def build_lstm_model_2(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking for padded values
#         LSTM(128, return_sequences=True),  # First LSTM layer with increased units
#         BatchNormalization(),  # Batch normalization to stabilize training
#         Dropout(0.2),  # Reduced dropout rate
#         LSTM(64, return_sequences=False),  # Second LSTM layer
#         BatchNormalization(),  # Batch normalization after second LSTM layer
#         Dropout(0.2),
#         Dense(32, activation='relu'),  # Increased fully connected layer size
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# %%
# data loader
def data_generator(X, y, batch_size):
    num_samples = len(X)
    while True:
        for offset in range(0, num_samples, batch_size):
            X_batch = X[offset:offset+batch_size]
            y_batch = y[offset:offset+batch_size]
            yield np.array(X_batch), np.array(y_batch)

# %%
# # Ensure consistent shuffling for reproducibility
# np.random.seed(42)

# def manual_train_val_test_split(data, labels, train_ratio=0.8, val_ratio=0.1):
#     """
#     Manually splits data and labels into training, validation, and testing sets with the given ratios.
#     Arguments:
#         data: Preprocessed time series data (numpy array).
#         labels: Corresponding labels (numpy array).
#         train_ratio: Proportion of data to use for training (default 0.7).
#         val_ratio: Proportion of data to use for validation (default 0.2).
#     Returns:
#         X_train, X_val, X_test, y_train, y_val, y_test: Split data and labels.
#     """
#     # Ensure train_ratio + val_ratio < 1
#     assert train_ratio + val_ratio < 1, "Train and validation ratios must sum to less than 1."
    
#     # Shuffle the indices
#     indices = np.arange(len(data))
#     np.random.shuffle(indices)
    
#     # Calculate the split points
#     train_split = int(len(data) * train_ratio)
#     val_split = int(len(data) * (train_ratio + val_ratio))
    
#     # Split the data and labels
#     train_indices = indices[:train_split]
#     val_indices = indices[train_split:val_split]
#     test_indices = indices[val_split:]
    
#     X_train = data[train_indices]
#     X_val = data[val_indices]
#     X_test = data[test_indices]
#     y_train = labels[train_indices]
#     y_val = labels[val_indices]
#     y_test = labels[test_indices]
    
#     return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# ### Perform the manual train-test split
# # Call the function
# X_train, X_val, X_test, y_train, y_val, y_test = manual_train_val_test_split(
#     np.array(lstm_input), np.array(labels), train_ratio=0.8, val_ratio=0.1)
# # Check the shapes of the resulting datasets
# print("Training data shape:", X_train.shape)
# print("Training labels shape:", y_train.shape)
# print("Testing data shape:", X_test.shape)
# print("Testing labels shape:", y_test.shape)


# # Convert to numpy arrays
# X_train = np.array(X_train)
# X_val = np.array(X_val)
# X_test = np.array(X_test)
# y_train = np.array(y_train)
# y_val = np.array(y_val)
# y_test = np.array(y_test)

# # Define input shape (timepoints, features)
# input_shape = (X_train.shape[1], X_train.shape[2])

# # # Build model
# # model = build_lstm_model(input_shape)

# # # Train the model
# # history = model.fit(
# #     X_train, y_train,
# #     validation_data=(X_val, y_val),
# #     epochs=50,
# #     batch_size=16,
# #     verbose=1
# # )

# %%
# TRY 3 
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Masking, LSTM, Dropout, Dense, BatchNormalization
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping
# from sklearn.utils.class_weight import compute_class_weight
# import numpy as np

# # Define LSTM model with improvements
# def build_lstm_model(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking for padded values
#         LSTM(128, return_sequences=True),  # Increased units in the first LSTM layer
#         BatchNormalization(),  # Batch Normalization
#         Dropout(0.4),  # Increased Dropout for regularization
#         LSTM(64),  # Second LSTM layer with reduced units
#         BatchNormalization(),  # Batch Normalization
#         Dropout(0.4),
#         Dense(32, activation='relu'),  # Increased units in fully connected layer
#         Dropout(0.4),  # Additional dropout
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# # Build the model
# input_shape = (X_train.shape[1], X_train.shape[2])  # Define input shape based on your data
# model = build_lstm_model(input_shape)

# # Compute class weights for handling class imbalance
# class_weights = compute_class_weight(
#     'balanced',
#     classes=np.unique(y_train),
#     y=y_train
# )
# class_weights = dict(enumerate(class_weights))

# # Add EarlyStopping for regularization
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # Train the model with validation and early stopping
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_val, y_val),
#     epochs=50,
#     batch_size=16,
#     class_weight=class_weights,
#     callbacks=[early_stopping],
#     verbose=1
# )

# # Evaluate the model on test data
# test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
# print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# %%
# # THE LATEST LSTM

# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Masking, LSTM, Dense, Dropout, BatchNormalization, Input
from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

# # Define the LSTM model
# def build_lstm_model(input_shape):
#     model = Sequential([
#         Input(shape=input_shape),
#         LSTM(256, return_sequences=True),  # Increase units
#         Dense(128, activation='relu'),  # Add a dense layer
#         LSTM(128, return_sequences=True),  # Second LSTM layer
#         Dense(64, activation='relu'),  # Add another dense layer
#         LSTM(64),  # Final LSTM layer
#         Dense(32, activation='relu'),  # Fully connected layer
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Higher LR
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model




# Split data into train, validation, and test sets - 80, 10, 10
def split_data(X, y, test_size=0.1, val_size=0.1):
    """
    Splits the data into training, validation, and testing sets.
    Arguments:
        X: Input features (numpy array).
        y: Labels (numpy array).
        test_size: Proportion of data for the test set.
        val_size: Proportion of data for the validation set from the training set.
    Returns:
        X_train, X_val, X_test, y_train, y_val, y_test3
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_size, random_state=42)
    return X_train, X_val, X_test, y_train, y_val, y_test


# Split data
X_train, X_val, X_test, y_train, y_val, y_test = split_data(lstm_input, labels)

# # Build the model
# input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
# model = build_lstm_model(input_shape)

# # Increase batch size and train
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_val, y_val),
#     epochs=500,
#     batch_size=32,  # Increased batch size
#     verbose=1
# )


# final_train_accuracy = history.history['accuracy'][-1]
# final_val_accuracy = history.history['val_accuracy'][-1]

# print(f"Final Training Accuracy: {final_train_accuracy}")
# print(f"Final Validation Accuracy: {final_val_accuracy}")

# # Evaluate the model on the test set
# test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
# print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# # Classification report
# y_pred = (model.predict(X_test) > 0.5).astype(int)
# # print(classification_report(y_test, y_pred))

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Input
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import LearningRateScheduler

# def build_lstm_model(input_shape):
#     model = Sequential([
#         Input(shape=input_shape),
#         LSTM(256, return_sequences=True),  # Larger capacity
#         LSTM(128, return_sequences=True),
#         LSTM(128, return_sequences=True),
#         LSTM(64),
#         Dense(32, activation='relu'),
#         Dense(1, activation='sigmoid')
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.0001),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model


# # Build model
# input_shape = (X_train.shape[1], X_train.shape[2])  # Define input shape from the training data
# model = build_lstm_model(input_shape)


# # Train the model with class weights
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_test, y_test),
#     epochs=500,
#     batch_size=16,
#     verbose=1
# )

# %%
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Masking, LSTM, Dense, Dropout, BatchNormalization
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

# # Build an LSTM model optimized for overfitting to the training set
# def build_overfitting_lstm(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking padded values
#         LSTM(128, return_sequences=True, activation='relu'),  # First LSTM layer
#         LSTM(64, return_sequences=True, activation='relu'),   # Second LSTM layer
#         LSTM(32, activation='relu'),                         # Third LSTM layer
#         Dense(1, activation='sigmoid')                       # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.001),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# # Train the model on training data only
# input_shape = (X_train.shape[1], X_train.shape[2])  # Define input shape from the training data
# model = build_overfitting_lstm(input_shape)

# # Train the model for an extended number of epochs
# history = model.fit(
#     X_train, y_train,
#     epochs=100,  # Increase epochs for training
#     batch_size=16,
#     verbose=1
# )

# # Plot training loss over epochs
# plt.plot(history.history['loss'], label='Train Loss')
# plt.title('Training Loss Over Epochs')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# import matplotlib.pyplot as plt

# # Extract the loss values from the history object
# train_loss = history.history['loss']
# val_loss = history.history['val_loss']

# # Print loss values for each epoch
# print("Training Loss per Epoch:")
# for epoch, loss in enumerate(train_loss):
#     print(f"Epoch {epoch+1}: Training Loss = {loss:.4f}, Validation Loss = {val_loss[epoch]:.4f}")

# # Plot the training and validation loss
# plt.figure(figsize=(8, 6))
# plt.plot(train_loss, label='Training Loss', marker='o')
# plt.plot(val_loss, label='Validation Loss', marker='o')
# plt.title('Training and Validation Loss Over Epochs')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.grid()
# plt.show()

# %%
# QUESTIONS
# - scope of project/priorities? one model? multiple? for 3 ppl?
# - AWS GPU credits? need? way to do local or sherlock? 
# - can we do 80/20 split with data we have train/test? do we need dev? 
#

# %%
# ADVICE
# spend a lot of time on analysis portion - why did this occur if we were moving forward what would we change 
# try predicting TFT time

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LayerNormalization, Dropout, Input, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, regularizer=None):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.projection_dim = embed_dim // num_heads
        self.query_dense = Dense(embed_dim, kernel_regularizer=regularizer)
        self.key_dense = Dense(embed_dim, kernel_regularizer=regularizer)
        self.value_dense = Dense(embed_dim, kernel_regularizer=regularizer)
        self.combine_heads = Dense(embed_dim, kernel_regularizer=regularizer)

    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b=True) / tf.sqrt(tf.cast(self.projection_dim, query.dtype))
        weights = tf.nn.softmax(score, axis=-1)
        return tf.matmul(weights, value), weights

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)

        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)

        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        attention, _ = self.attention(query, key, value)
        attention = tf.transpose(attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        return self.combine_heads(concat_attention)

class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, regularizer=None):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadSelfAttention(embed_dim, num_heads, regularizer)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation='relu', kernel_regularizer=regularizer),
            Dense(embed_dim, kernel_regularizer=regularizer)
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def build_transformer_model(input_shape, num_heads=4, embed_dim=64, ff_dim=128, num_blocks=2, l2_reg=1e-3):
    inputs = Input(shape=input_shape)
    
    # Embedding layer with regularization
    x = Dense(embed_dim, kernel_regularizer=l2(l2_reg))(inputs)
    
    # Add Transformer blocks with regularization
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, rate=0.3, regularizer=l2(l2_reg))(x, training=True)

    # Global pooling and output layer
    x = GlobalAveragePooling1D()(x)
    x = Dropout(0.5)(x) # INCREASED FROM 0.3
    outputs = Dense(1, activation="sigmoid", kernel_regularizer=l2(l2_reg))(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Build the Transformer model
input_shape = (lstm_input.shape[1], lstm_input.shape[2])  # timesteps, features
transformer_model = build_transformer_model(input_shape)

# Summary of the model
transformer_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 labels
#
# NameError: name 'labels' is not defined

# %%
# Train the Transformer model
# from tensorflow.keras.callbacks import EarlyStopping

#early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

## MAYBE TRY BRINGING BACK EARLY STOPPING BUT WITH A DIFFERENT PATIENCE 
## MAYBE TRY CLASS WEIGHTS 

# Compute class weights to balance the dataset
class_weights = compute_class_weight(
    class_weight='balanced', 
    classes=np.unique(y_train), 
    y=y_train
)
class_weight_dict = dict(enumerate(class_weights))

history = transformer_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=16,
    #callbacks=[early_stopping],
    class_weight=class_weight_dict,
    verbose=1
)

train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Print final training and validation accuracy
print(f"Final Training Accuracy: {train_accuracy[-1]:.4f}")
print(f"Final Validation Accuracy: {val_accuracy[-1]:.4f}")

# Evaluate the model on test data
test_loss, test_accuracy = transformer_model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 lstm_input.shape
#
# NameError: name 'lstm_input' is not defined

# %%
import matplotlib.pyplot as plt

# Plot Training Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
