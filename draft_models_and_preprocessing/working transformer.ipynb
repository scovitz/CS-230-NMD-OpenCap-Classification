# %%
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import pad_sequences
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Masking
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense, LayerNormalization, Dropout, Input, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')  # May improve speed on some CPUs

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')  # May improve speed on some CPUs

# %%
def read_trc(fpath):
    # read metadata in file header
    df_meta = pd.read_csv(fpath, delimiter='\t', header=0, skiprows=1, nrows=1)
    meta = df_meta.iloc[0].to_dict()
    fps = meta['DataRate']

    # read marker location names
    markers_df = pd.read_csv(fpath, delimiter='\t', header=None, skiprows=3, nrows=1)
    markers = markers_df.iloc[0].dropna().to_numpy()[2:]

    # read marker XYZ locations
    df = pd.read_csv(fpath, delimiter='\t', header=0, skiprows=4)
    df.rename(columns=dict(zip(df.columns[:2], ('n', 't'))), inplace=True)
    df.dropna(how='all', axis=1, inplace=True)

    N = df.shape[0]
    M = len(markers)
    xyz = df.iloc[:,2:].to_numpy().reshape((N, M, 3))
    xyz[:,:,[0,1,2]] = xyz[:,:,[2,1,0]]

    return fps, markers, xyz


def read_mot(fpath):
    with open(fpath, 'r') as f:
        # count = 0
        line = f.readline().strip()
        # while line and line.strip() != 'endheader':
        while line.lower() != 'endheader':
            line = f.readline().strip()
            # count += 1

        # df = pd.read_csv(f, delimiter='\t', header=0, skiprows=count-3)
        df = pd.read_csv(f, delimiter='\t', header=0)

    return df

# %%
def z_score_normalize(data_list):
    """
    Applies z-score normalization to a list of time series arrays.
    Arguments:
        data_list: List of numpy arrays, each of shape (num_timesteps, num_features).
    Returns:
        normalized_data: List of z-score normalized arrays.
        mean: Mean of each feature across all time series.
        std: Standard deviation of each feature across all time series.
    """
    # Concatenate all data to compute global mean and std
    all_data = np.concatenate(data_list, axis=0)
    mean = np.mean(all_data, axis=0)
    std = np.std(all_data, axis=0)
    
    # Normalize each array
    normalized_data = [(data - mean) / (std + 1e-8) for data in data_list]
    return normalized_data, mean, std

def prepare_lstm_input(subject_dict):
    """
    Combines multiple time series for each subject along the time axis, applies z-score normalization,
    and pads them for LSTM input.
    Arguments:
        subject_dict: Dictionary where keys are subject IDs and values are lists of 6 numpy arrays.
                      Each numpy array corresponds to a time series with shape (num_timesteps, num_features).
    Returns:
        padded_input: A numpy array of shape (num_subjects, max_timesteps, num_features).
        subject_ids: List of subject IDs in the order they appear in the padded_input array.
        mean: Mean of features used for z-score normalization.
        std: Standard deviation of features used for z-score normalization.
    """
    # Sort the dictionary by keys to ensure consistent ordering
    subject_ids = sorted(subject_dict.keys())
    
    # Extract and concatenate the 6 time series for each subject along the time axis
    concatenated_series = [
        np.concatenate(subject_dict[subject_id], axis=0) for subject_id in subject_ids
    ]
    
    # Apply z-score normalization to the concatenated series
    normalized_series, mean, std = z_score_normalize(concatenated_series)
    
    # Determine the maximum length for padding
    max_length = max(series.shape[0] for series in normalized_series)
    
    # Pad all normalized time series to the same length
    padded_input = pad_sequences(normalized_series, maxlen=max_length, padding="post", dtype="float32")
    
    return padded_input, subject_ids, mean, std

# %%
def get_label_for_participant_trial(class_df, pid, trial):
    """
    Fetches the label for a given participant and trial based on class_info.csv.
    
    Parameters:
        participant_id (str): The ID of the participant.
        trial (str): The trial name or ID.
    
    Returns:
        int: Classification label (0 or 1).
    """
    label = class_df.loc[class_df['ID'] == pid, 'Class'].values[0]
    return label

# %%
# Directory containing .mot files
#root_dir = '/Users/scovitz/datadir/opencap_data'  # path to root data dir 
#labels_csv = '/Users/scovitz/datadir/class_info.csv'
root_dir = '/Users/kristensteudel/Documents/datadir/opencap_data'  # path to root data dir 
labels_csv = '/Users/kristensteudel/Documents/datadir/class_info.csv'
class_df = pd.read_csv(labels_csv)

time_series_data = {}  # dictionary of pid, timeseries pairs 

expected_columns = [
        'pelvis_tilt', 'pelvis_list', 'pelvis_rotation', 'pelvis_tx',
        'pelvis_ty', 'pelvis_tz', 'hip_flexion_r', 'hip_adduction_r',
        'hip_rotation_r', 'knee_angle_r', 'ankle_angle_r',
        'subtalar_angle_r', 'mtp_angle_r', 'hip_flexion_l', 'hip_adduction_l',
        'hip_rotation_l', 'knee_angle_l', 'ankle_angle_l',
        'subtalar_angle_l', 'mtp_angle_l', 'lumbar_extension', 'lumbar_bending',
        'lumbar_rotation', 'arm_flex_r', 'arm_add_r', 'arm_rot_r',
        'elbow_flex_r', 'pro_sup_r', 'arm_flex_l', 'arm_add_l', 'arm_rot_l',
        'elbow_flex_l', 'pro_sup_l'
    ]

# Loop through all .mot files
for i in range(129):
        # ensure going in order!
        num = str(i+1).zfill(3)

        for path in Path(root_dir).rglob(f"P{num}*/**/*.mot"): 
            
            # remove upper extremity trials 
            if "brooke" in str(path) or "curls" in str(path) or "arm_rom" in str(path):
                continue 
            
            trial = str(path).split('/')[-3]
            pid = str(path).split('/')[-4]
            activity = str(path).split('/')[-2]
            #print(str(path))
            # Load the .mot file
            
            data = read_mot(str(path))
            data = data[200:]
            #print(data.shape)

            # Ensure the file has the expected columns
            if not all(col in data.columns for col in expected_columns + ['time']):
                raise ValueError(f"File {path} does not contain the expected columns.")
            
            # Drop the 'time' column and keep only relevant features
            data = np.array(data[expected_columns])
            
            if pid not in time_series_data:
                time_series_data[pid + '_' + trial] = []

            time_series_data[(pid + '_' + trial)].append(data) # value = list of timeseries arrays of num_timesteps x num_feats
            print(data.shape, pid, trial, str(path))
# Out:
# (635, 33) P001 0 /Users/kristensteudel/Documents/datadir/opencap_data/P001/0/walk/walk.mot
# (332, 33) P001 0 /Users/kristensteudel/Documents/datadir/opencap_data/P001/0/tug/tug.mot
# (1838, 33) P001 0 /Users/kristensteudel/Documents/datadir/opencap_data/P001/0/toe_stand/toe_stand.mot
# (652, 33) P001 0 /Users/kristensteudel/Documents/datadir/opencap_data/P001/0/5xsts/5xsts.mot
# (140, 33) P001 0 /Users/kristensteudel/Documents/datadir/opencap_data/P001/0/jump/jump.mot
# (273, 33) P001 0 /Users/kristensteudel/Documents/datadir/opencap_data/P001/0/run/run.mot
# (642, 33) P002 0 /Users/kristensteudel/Documents/datadir/opencap_data/P002/0/walk/walk.mot
# (1119, 33) P002 0 /Users/kristensteudel/Documents/datadir/opencap_data/P002/0/tug/tug.mot
# (1929, 33) P002 0 /Users/kristensteudel/Documents/datadir/opencap_data/P002/0/toe_stand/toe_stand.mot
# (875, 33) P002 0 /Users/kristensteudel/Documents/datadir/opencap_data/P002/0/5xsts/5xsts.mot
# (161, 33) P002 0 /Users/kristensteudel/Documents/datadir/opencap_data/P002/0/jump/jump.mot
# (456, 33) P002 0 /Users/kristensteudel/Documents/datadir/opencap_data/P002/0/run/run.mot
# (625, 33) P003 0 /Users/kristensteudel/Documents/datadir/opencap_data/P003/0/walk/walk.mot
# (948, 33) P003 0 /Users/kristensteudel/Documents/datadir/opencap_data/P003/0/tug/tug.mot
# (1879, 33) P003 0 /Users/kristensteudel/Documents/datadir/opencap_data/P003/0/toe_stand/toe_stand.mot
# (506, 33) P003 0 /Users/kristensteudel/Documents/datadir/opencap_data/P003/0/5xsts/5xsts.mot
# (145, 33) P003 0 /Users/kristensteudel/Documents/datadir/opencap_data/P003/0/jump/jump.mot
# (340, 33) P003 0 /Users/kristensteudel/Documents/datadir/opencap_data/P003/0/run/run.mot
# (695, 33) P004 0 /Users/kristensteudel/Documents/datadir/opencap_data/P004/0/walk/walk.mot
# (975, 33) P004 0 /Users/kristensteudel/Documents/datadir/opencap_data/P004/0/tug/tug.mot
# (1818, 33) P004 0 /Users/kristensteudel/Documents/datadir/opencap_data/P004/0/toe_stand/toe_stand.mot
# (580, 33) P004 0 /Users/kristensteudel/Documents/datadir/opencap_data/P004/0/5xsts/5xsts.mot
# (201, 33) P004 0 /Users/kristensteudel/Documents/datadir/opencap_data/P004/0/jump/jump.mot
# (469, 33) P004 0 /Users/kristensteudel/Documents/datadir/opencap_data/P004/0/run/run.mot
# (536, 33) P005 0 /Users/kristensteudel/Documents/datadir/opencap_data/P005/0/walk/walk.mot
# (979, 33) P005 0 /Users/kristensteudel/Documents/datadir/opencap_data/P005/0/tug/tug.mot
# (1933, 33) P005 0 /Users/kristensteudel/Documents/datadir/opencap_data/P005/0/toe_stand/toe_stand.mot
# (484, 33) P005 0 /Users/kristensteudel/Documents/datadir/opencap_data/P005/0/5xsts/5xsts.mot
# (251, 33) P005 0 /Users/kristensteudel/Documents/datadir/opencap_data/P005/0/jump/jump.mot
# (337, 33) P005 0 /Users/kristensteudel/Documents/datadir/opencap_data/P005/0/run/run.mot
# (706, 33) P006 0 /Users/kristensteudel/Documents/datadir/opencap_data/P006/0/walk/walk.mot
# (957, 33) P006 0 /Users/kristensteudel/Documents/datadir/opencap_data/P006/0/tug/tug.mot
# (1986, 33) P006 0 /Users/kristensteudel/Documents/datadir/opencap_data/P006/0/toe_stand/toe_stand.mot
# (278, 33) P006 0 /Users/kristensteudel/Documents/datadir/opencap_data/P006/0/5xsts/5xsts.mot
# (210, 33) P006 0 /Users/kristensteudel/Documents/datadir/opencap_data/P006/0/jump/jump.mot
# (363, 33) P006 0 /Users/kristensteudel/Documents/datadir/opencap_data/P006/0/run/run.mot
# (1447, 33) P007 407 /Users/kristensteudel/Documents/datadir/opencap_data/P007/407/walk/walk.mot
# (1470, 33) P007 407 /Users/kristensteudel/Documents/datadir/opencap_data/P007/407/tug/tug.mot
# (2022, 33) P007 407 /Users/kristensteudel/Documents/datadir/opencap_data/P007/407/toe_stand/toe_stand.mot
# (1623, 33) P007 407 /Users/kristensteudel/Documents/datadir/opencap_data/P007/407/5xsts/5xsts.mot
# (396, 33) P007 407 /Users/kristensteudel/Documents/datadir/opencap_data/P007/407/jump/jump.mot
# (586, 33) P007 407 /Users/kristensteudel/Documents/datadir/opencap_data/P007/407/run/run.mot
# (759, 33) P007 0 /Users/kristensteudel/Documents/datadir/opencap_data/P007/0/walk/walk.mot
# (958, 33) P007 0 /Users/kristensteudel/Documents/datadir/opencap_data/P007/0/tug/tug.mot
# (1854, 33) P007 0 /Users/kristensteudel/Documents/datadir/opencap_data/P007/0/toe_stand/toe_stand.mot
# (391, 33) P007 0 /Users/kristensteudel/Documents/datadir/opencap_data/P007/0/5xsts/5xsts.mot
# (157, 33) P007 0 /Users/kristensteudel/Documents/datadir/opencap_data/P007/0/jump/jump.mot
# (252, 33) P007 0 /Users/kristensteudel/Documents/datadir/opencap_data/P007/0/run/run.mot
# (717, 33) P008 0 /Users/kristensteudel/Documents/datadir/opencap_data/P008/0/walk/walk.mot
# (879, 33) P008 0 /Users/kristensteudel/Documents/datadir/opencap_data/P008/0/tug/tug.mot
# (2016, 33) P008 0 /Users/kristensteudel/Documents/datadir/opencap_data/P008/0/toe_stand/toe_stand.mot
# (460, 33) P008 0 /Users/kristensteudel/Documents/datadir/opencap_data/P008/0/5xsts/5xsts.mot
# (189, 33) P008 0 /Users/kristensteudel/Documents/datadir/opencap_data/P008/0/jump/jump.mot
# (228, 33) P008 0 /Users/kristensteudel/Documents/datadir/opencap_data/P008/0/run/run.mot
# (806, 33) P009 453 /Users/kristensteudel/Documents/datadir/opencap_data/P009/453/walk/walk.mot
# (986, 33) P009 453 /Users/kristensteudel/Documents/datadir/opencap_data/P009/453/tug/tug.mot
# (1900, 33) P009 453 /Users/kristensteudel/Documents/datadir/opencap_data/P009/453/toe_stand/toe_stand.mot
# (1098, 33) P009 453 /Users/kristensteudel/Documents/datadir/opencap_data/P009/453/5xsts/5xsts.mot
# (133, 33) P009 453 /Users/kristensteudel/Documents/datadir/opencap_data/P009/453/jump/jump.mot
# (392, 33) P009 453 /Users/kristensteudel/Documents/datadir/opencap_data/P009/453/run/run.mot
# (735, 33) P009 0 /Users/kristensteudel/Documents/datadir/opencap_data/P009/0/walk/walk.mot
# (981, 33) P009 0 /Users/kristensteudel/Documents/datadir/opencap_data/P009/0/tug/tug.mot
# (1987, 33) P009 0 /Users/kristensteudel/Documents/datadir/opencap_data/P009/0/toe_stand/toe_stand.mot
# (757, 33) P009 0 /Users/kristensteudel/Documents/datadir/opencap_data/P009/0/5xsts/5xsts.mot
# (151, 33) P009 0 /Users/kristensteudel/Documents/datadir/opencap_data/P009/0/jump/jump.mot
# (484, 33) P009 0 /Users/kristensteudel/Documents/datadir/opencap_data/P009/0/run/run.mot
# (1280, 33) P010 407 /Users/kristensteudel/Documents/datadir/opencap_data/P010/407/walk/walk.mot
# (1355, 33) P010 407 /Users/kristensteudel/Documents/datadir/opencap_data/P010/407/tug/tug.mot
# (2058, 33) P010 407 /Users/kristensteudel/Documents/datadir/opencap_data/P010/407/toe_stand/toe_stand.mot
# (1843, 33) P010 407 /Users/kristensteudel/Documents/datadir/opencap_data/P010/407/5xsts/5xsts.mot
# (249, 33) P010 407 /Users/kristensteudel/Documents/datadir/opencap_data/P010/407/jump/jump.mot
# (811, 33) P010 407 /Users/kristensteudel/Documents/datadir/opencap_data/P010/407/run/run.mot
# (813, 33) P010 0 /Users/kristensteudel/Documents/datadir/opencap_data/P010/0/walk/walk.mot
# (979, 33) P010 0 /Users/kristensteudel/Documents/datadir/opencap_data/P010/0/tug/tug.mot
# (1912, 33) P010 0 /Users/kristensteudel/Documents/datadir/opencap_data/P010/0/toe_stand/toe_stand.mot
# (676, 33) P010 0 /Users/kristensteudel/Documents/datadir/opencap_data/P010/0/5xsts/5xsts.mot
# (156, 33) P010 0 /Users/kristensteudel/Documents/datadir/opencap_data/P010/0/jump/jump.mot
# (308, 33) P010 0 /Users/kristensteudel/Documents/datadir/opencap_data/P010/0/run/run.mot
# (541, 33) P011 0 /Users/kristensteudel/Documents/datadir/opencap_data/P011/0/walk/walk.mot
# (335, 33) P011 0 /Users/kristensteudel/Documents/datadir/opencap_data/P011/0/tug/tug.mot
# (1838, 33) P011 0 /Users/kristensteudel/Documents/datadir/opencap_data/P011/0/toe_stand/toe_stand.mot
# (738, 33) P011 0 /Users/kristensteudel/Documents/datadir/opencap_data/P011/0/5xsts/5xsts.mot
# (160, 33) P011 0 /Users/kristensteudel/Documents/datadir/opencap_data/P011/0/jump/jump.mot
# (360, 33) P011 0 /Users/kristensteudel/Documents/datadir/opencap_data/P011/0/run/run.mot
# (580, 33) P012 0 /Users/kristensteudel/Documents/datadir/opencap_data/P012/0/walk/walk.mot
# (1071, 33) P012 0 /Users/kristensteudel/Documents/datadir/opencap_data/P012/0/tug/tug.mot
# (2022, 33) P012 0 /Users/kristensteudel/Documents/datadir/opencap_data/P012/0/toe_stand/toe_stand.mot
# (457, 33) P012 0 /Users/kristensteudel/Documents/datadir/opencap_data/P012/0/5xsts/5xsts.mot
# (313, 33) P012 0 /Users/kristensteudel/Documents/datadir/opencap_data/P012/0/jump/jump.mot
# (314, 33) P012 0 /Users/kristensteudel/Documents/datadir/opencap_data/P012/0/run/run.mot
# (1149, 33) P013 0 /Users/kristensteudel/Documents/datadir/opencap_data/P013/0/walk/walk.mot
# (1366, 33) P013 0 /Users/kristensteudel/Documents/datadir/opencap_data/P013/0/tug/tug.mot
# (1840, 33) P013 0 /Users/kristensteudel/Documents/datadir/opencap_data/P013/0/toe_stand/toe_stand.mot
# (758, 33) P013 0 /Users/kristensteudel/Documents/datadir/opencap_data/P013/0/5xsts/5xsts.mot
# (612, 33) P013 0 /Users/kristensteudel/Documents/datadir/opencap_data/P013/0/run/run.mot
# (710, 33) P014 0 /Users/kristensteudel/Documents/datadir/opencap_data/P014/0/walk/walk.mot
# (865, 33) P014 0 /Users/kristensteudel/Documents/datadir/opencap_data/P014/0/tug/tug.mot
# (2076, 33) P014 0 /Users/kristensteudel/Documents/datadir/opencap_data/P014/0/toe_stand/toe_stand.mot
# (578, 33) P014 0 /Users/kristensteudel/Documents/datadir/opencap_data/P014/0/5xsts/5xsts.mot
# (313, 33) P014 0 /Users/kristensteudel/Documents/datadir/opencap_data/P014/0/jump/jump.mot
# (273, 33) P014 0 /Users/kristensteudel/Documents/datadir/opencap_data/P014/0/run/run.mot
# (323, 33) P015 0 /Users/kristensteudel/Documents/datadir/opencap_data/P015/0/walk/walk.mot
# (546, 33) P015 0 /Users/kristensteudel/Documents/datadir/opencap_data/P015/0/tug/tug.mot
# (2315, 33) P015 0 /Users/kristensteudel/Documents/datadir/opencap_data/P015/0/toe_stand/toe_stand.mot
# (819, 33) P015 0 /Users/kristensteudel/Documents/datadir/opencap_data/P015/0/5xsts/5xsts.mot
# (433, 33) P015 0 /Users/kristensteudel/Documents/datadir/opencap_data/P015/0/jump/jump.mot
# (184, 33) P015 0 /Users/kristensteudel/Documents/datadir/opencap_data/P015/0/run/run.mot
# (727, 33) P016 0 /Users/kristensteudel/Documents/datadir/opencap_data/P016/0/walk/walk.mot
# (1051, 33) P016 0 /Users/kristensteudel/Documents/datadir/opencap_data/P016/0/tug/tug.mot
# (1960, 33) P016 0 /Users/kristensteudel/Documents/datadir/opencap_data/P016/0/toe_stand/toe_stand.mot
# (742, 33) P016 0 /Users/kristensteudel/Documents/datadir/opencap_data/P016/0/5xsts/5xsts.mot
# (161, 33) P016 0 /Users/kristensteudel/Documents/datadir/opencap_data/P016/0/jump/jump.mot
# (310, 33) P016 0 /Users/kristensteudel/Documents/datadir/opencap_data/P016/0/run/run.mot
# (861, 33) P017 455 /Users/kristensteudel/Documents/datadir/opencap_data/P017/455/walk/walk.mot
# (878, 33) P017 455 /Users/kristensteudel/Documents/datadir/opencap_data/P017/455/tug/tug.mot
# (2064, 33) P017 455 /Users/kristensteudel/Documents/datadir/opencap_data/P017/455/toe_stand/toe_stand.mot
# (1330, 33) P017 455 /Users/kristensteudel/Documents/datadir/opencap_data/P017/455/5xsts/5xsts.mot
# (270, 33) P017 455 /Users/kristensteudel/Documents/datadir/opencap_data/P017/455/jump/jump.mot
# (374, 33) P017 455 /Users/kristensteudel/Documents/datadir/opencap_data/P017/455/run/run.mot
# (783, 33) P017 0 /Users/kristensteudel/Documents/datadir/opencap_data/P017/0/walk/walk.mot
# (1002, 33) P017 0 /Users/kristensteudel/Documents/datadir/opencap_data/P017/0/tug/tug.mot
# (2020, 33) P017 0 /Users/kristensteudel/Documents/datadir/opencap_data/P017/0/toe_stand/toe_stand.mot
# (589, 33) P017 0 /Users/kristensteudel/Documents/datadir/opencap_data/P017/0/5xsts/5xsts.mot
# (264, 33) P017 0 /Users/kristensteudel/Documents/datadir/opencap_data/P017/0/jump/jump.mot
# (374, 33) P017 0 /Users/kristensteudel/Documents/datadir/opencap_data/P017/0/run/run.mot
# (908, 33) P018 0 /Users/kristensteudel/Documents/datadir/opencap_data/P018/0/walk/walk.mot
# (1318, 33) P018 0 /Users/kristensteudel/Documents/datadir/opencap_data/P018/0/tug/tug.mot
# (1896, 33) P018 0 /Users/kristensteudel/Documents/datadir/opencap_data/P018/0/toe_stand/toe_stand.mot
# (920, 33) P018 0 /Users/kristensteudel/Documents/datadir/opencap_data/P018/0/5xsts/5xsts.mot
# (260, 33) P018 0 /Users/kristensteudel/Documents/datadir/opencap_data/P018/0/jump/jump.mot
# (147, 33) P018 0 /Users/kristensteudel/Documents/datadir/opencap_data/P018/0/run/run.mot
# (866, 33) P019 7 /Users/kristensteudel/Documents/datadir/opencap_data/P019/7/walk/walk.mot
# (1452, 33) P019 7 /Users/kristensteudel/Documents/datadir/opencap_data/P019/7/tug/tug.mot
# (1781, 33) P019 7 /Users/kristensteudel/Documents/datadir/opencap_data/P019/7/toe_stand/toe_stand.mot
# (611, 33) P019 7 /Users/kristensteudel/Documents/datadir/opencap_data/P019/7/5xsts/5xsts.mot
# (160, 33) P019 7 /Users/kristensteudel/Documents/datadir/opencap_data/P019/7/jump/jump.mot
# (461, 33) P019 7 /Users/kristensteudel/Documents/datadir/opencap_data/P019/7/run/run.mot
# (1002, 33) P019 118 /Users/kristensteudel/Documents/datadir/opencap_data/P019/118/walk/walk.mot
# (1350, 33) P019 118 /Users/kristensteudel/Documents/datadir/opencap_data/P019/118/tug/tug.mot
# (1908, 33) P019 118 /Users/kristensteudel/Documents/datadir/opencap_data/P019/118/toe_stand/toe_stand.mot
# (1931, 33) P019 118 /Users/kristensteudel/Documents/datadir/opencap_data/P019/118/5xsts/5xsts.mot
# (34, 33) P019 118 /Users/kristensteudel/Documents/datadir/opencap_data/P019/118/jump/jump.mot
# (355, 33) P019 118 /Users/kristensteudel/Documents/datadir/opencap_data/P019/118/run/run.mot
# (668, 33) P019 119 /Users/kristensteudel/Documents/datadir/opencap_data/P019/119/walk/walk.mot
# (1330, 33) P019 119 /Users/kristensteudel/Documents/datadir/opencap_data/P019/119/tug/tug.mot
# (1938, 33) P019 119 /Users/kristensteudel/Documents/datadir/opencap_data/P019/119/toe_stand/toe_stand.mot
# (1363, 33) P019 119 /Users/kristensteudel/Documents/datadir/opencap_data/P019/119/5xsts/5xsts.mot
# (0, 33) P019 119 /Users/kristensteudel/Documents/datadir/opencap_data/P019/119/jump/jump.mot
# (236, 33) P019 119 /Users/kristensteudel/Documents/datadir/opencap_data/P019/119/run/run.mot
# (800, 33) P020 7 /Users/kristensteudel/Documents/datadir/opencap_data/P020/7/walk/walk.mot
# (832, 33) P020 7 /Users/kristensteudel/Documents/datadir/opencap_data/P020/7/tug/tug.mot
# (1813, 33) P020 7 /Users/kristensteudel/Documents/datadir/opencap_data/P020/7/toe_stand/toe_stand.mot
# (868, 33) P020 7 /Users/kristensteudel/Documents/datadir/opencap_data/P020/7/5xsts/5xsts.mot
# (196, 33) P020 7 /Users/kristensteudel/Documents/datadir/opencap_data/P020/7/jump/jump.mot
# (489, 33) P020 7 /Users/kristensteudel/Documents/datadir/opencap_data/P020/7/run/run.mot
# (1271, 33) P021 7 /Users/kristensteudel/Documents/datadir/opencap_data/P021/7/walk/walk.mot
# (1599, 33) P021 7 /Users/kristensteudel/Documents/datadir/opencap_data/P021/7/tug/tug.mot
# (1909, 33) P021 7 /Users/kristensteudel/Documents/datadir/opencap_data/P021/7/toe_stand/toe_stand.mot
# (1172, 33) P021 7 /Users/kristensteudel/Documents/datadir/opencap_data/P021/7/5xsts/5xsts.mot
# (99, 33) P021 7 /Users/kristensteudel/Documents/datadir/opencap_data/P021/7/jump/jump.mot
# (1088, 33) P021 7 /Users/kristensteudel/Documents/datadir/opencap_data/P021/7/run/run.mot
# (1016, 33) P022 407 /Users/kristensteudel/Documents/datadir/opencap_data/P022/407/walk/walk.mot
# (1324, 33) P022 407 /Users/kristensteudel/Documents/datadir/opencap_data/P022/407/tug/tug.mot
# (2042, 33) P022 407 /Users/kristensteudel/Documents/datadir/opencap_data/P022/407/toe_stand/toe_stand.mot
# (2415, 33) P022 407 /Users/kristensteudel/Documents/datadir/opencap_data/P022/407/5xsts/5xsts.mot
# (285, 33) P022 407 /Users/kristensteudel/Documents/datadir/opencap_data/P022/407/jump/jump.mot
# (560, 33) P022 407 /Users/kristensteudel/Documents/datadir/opencap_data/P022/407/run/run.mot
# (617, 33) P022 7 /Users/kristensteudel/Documents/datadir/opencap_data/P022/7/walk/walk.mot
# (966, 33) P022 7 /Users/kristensteudel/Documents/datadir/opencap_data/P022/7/tug/tug.mot
# (1901, 33) P022 7 /Users/kristensteudel/Documents/datadir/opencap_data/P022/7/toe_stand/toe_stand.mot
# (1265, 33) P022 7 /Users/kristensteudel/Documents/datadir/opencap_data/P022/7/5xsts/5xsts.mot
# (256, 33) P022 7 /Users/kristensteudel/Documents/datadir/opencap_data/P022/7/jump/jump.mot
# (509, 33) P022 7 /Users/kristensteudel/Documents/datadir/opencap_data/P022/7/run/run.mot
# (717, 33) P023 7 /Users/kristensteudel/Documents/datadir/opencap_data/P023/7/walk/walk.mot
# (937, 33) P023 7 /Users/kristensteudel/Documents/datadir/opencap_data/P023/7/tug/tug.mot
# (1691, 33) P023 7 /Users/kristensteudel/Documents/datadir/opencap_data/P023/7/toe_stand/toe_stand.mot
# (683, 33) P023 7 /Users/kristensteudel/Documents/datadir/opencap_data/P023/7/5xsts/5xsts.mot
# (0, 33) P023 7 /Users/kristensteudel/Documents/datadir/opencap_data/P023/7/jump/jump.mot
# (252, 33) P023 7 /Users/kristensteudel/Documents/datadir/opencap_data/P023/7/run/run.mot
# (606, 33) P024 7 /Users/kristensteudel/Documents/datadir/opencap_data/P024/7/walk/walk.mot
# (982, 33) P024 7 /Users/kristensteudel/Documents/datadir/opencap_data/P024/7/tug/tug.mot
# (1835, 33) P024 7 /Users/kristensteudel/Documents/datadir/opencap_data/P024/7/toe_stand/toe_stand.mot
# (669, 33) P024 7 /Users/kristensteudel/Documents/datadir/opencap_data/P024/7/5xsts/5xsts.mot
# (57, 33) P024 7 /Users/kristensteudel/Documents/datadir/opencap_data/P024/7/jump/jump.mot
# (228, 33) P024 7 /Users/kristensteudel/Documents/datadir/opencap_data/P024/7/run/run.mot
# (671, 33) P025 7 /Users/kristensteudel/Documents/datadir/opencap_data/P025/7/walk/walk.mot
# (638, 33) P025 7 /Users/kristensteudel/Documents/datadir/opencap_data/P025/7/tug/tug.mot
# (1844, 33) P025 7 /Users/kristensteudel/Documents/datadir/opencap_data/P025/7/toe_stand/toe_stand.mot
# (519, 33) P025 7 /Users/kristensteudel/Documents/datadir/opencap_data/P025/7/5xsts/5xsts.mot
# (474, 33) P025 7 /Users/kristensteudel/Documents/datadir/opencap_data/P025/7/jump/jump.mot
# (220, 33) P025 7 /Users/kristensteudel/Documents/datadir/opencap_data/P025/7/run/run.mot
# (398, 33) P026 406 /Users/kristensteudel/Documents/datadir/opencap_data/P026/406/walk/walk.mot
# (565, 33) P026 406 /Users/kristensteudel/Documents/datadir/opencap_data/P026/406/tug/tug.mot
# (2086, 33) P026 406 /Users/kristensteudel/Documents/datadir/opencap_data/P026/406/toe_stand/toe_stand.mot
# (1039, 33) P026 406 /Users/kristensteudel/Documents/datadir/opencap_data/P026/406/5xsts/5xsts.mot
# (454, 33) P026 406 /Users/kristensteudel/Documents/datadir/opencap_data/P026/406/jump/jump.mot
# (196, 33) P026 406 /Users/kristensteudel/Documents/datadir/opencap_data/P026/406/run/run.mot
# (495, 33) P026 7 /Users/kristensteudel/Documents/datadir/opencap_data/P026/7/walk/walk.mot
# (1119, 33) P026 7 /Users/kristensteudel/Documents/datadir/opencap_data/P026/7/tug/tug.mot
# (1826, 33) P026 7 /Users/kristensteudel/Documents/datadir/opencap_data/P026/7/toe_stand/toe_stand.mot
# (671, 33) P026 7 /Users/kristensteudel/Documents/datadir/opencap_data/P026/7/5xsts/5xsts.mot
# (40, 33) P026 7 /Users/kristensteudel/Documents/datadir/opencap_data/P026/7/jump/jump.mot
# (244, 33) P026 7 /Users/kristensteudel/Documents/datadir/opencap_data/P026/7/run/run.mot
# (453, 33) P027 7 /Users/kristensteudel/Documents/datadir/opencap_data/P027/7/walk/walk.mot
# (769, 33) P027 7 /Users/kristensteudel/Documents/datadir/opencap_data/P027/7/tug/tug.mot
# (1876, 33) P027 7 /Users/kristensteudel/Documents/datadir/opencap_data/P027/7/toe_stand/toe_stand.mot
# (577, 33) P027 7 /Users/kristensteudel/Documents/datadir/opencap_data/P027/7/5xsts/5xsts.mot
# (240, 33) P027 7 /Users/kristensteudel/Documents/datadir/opencap_data/P027/7/jump/jump.mot
# (386, 33) P027 7 /Users/kristensteudel/Documents/datadir/opencap_data/P027/7/run/run.mot
# (759, 33) P028 7 /Users/kristensteudel/Documents/datadir/opencap_data/P028/7/walk/walk.mot
# (863, 33) P028 7 /Users/kristensteudel/Documents/datadir/opencap_data/P028/7/tug/tug.mot
# (1760, 33) P028 7 /Users/kristensteudel/Documents/datadir/opencap_data/P028/7/toe_stand/toe_stand.mot
# (572, 33) P028 7 /Users/kristensteudel/Documents/datadir/opencap_data/P028/7/5xsts/5xsts.mot
# (131, 33) P028 7 /Users/kristensteudel/Documents/datadir/opencap_data/P028/7/jump/jump.mot
# (283, 33) P028 7 /Users/kristensteudel/Documents/datadir/opencap_data/P028/7/run/run.mot
# (749, 33) P029 7 /Users/kristensteudel/Documents/datadir/opencap_data/P029/7/walk/walk.mot
# (914, 33) P029 7 /Users/kristensteudel/Documents/datadir/opencap_data/P029/7/tug/tug.mot
# (1956, 33) P029 7 /Users/kristensteudel/Documents/datadir/opencap_data/P029/7/toe_stand/toe_stand.mot
# (748, 33) P029 7 /Users/kristensteudel/Documents/datadir/opencap_data/P029/7/5xsts/5xsts.mot
# (218, 33) P029 7 /Users/kristensteudel/Documents/datadir/opencap_data/P029/7/jump/jump.mot
# (374, 33) P029 7 /Users/kristensteudel/Documents/datadir/opencap_data/P029/7/run/run.mot
# (617, 33) P030 7 /Users/kristensteudel/Documents/datadir/opencap_data/P030/7/walk/walk.mot
# (722, 33) P030 7 /Users/kristensteudel/Documents/datadir/opencap_data/P030/7/tug/tug.mot
# (1899, 33) P030 7 /Users/kristensteudel/Documents/datadir/opencap_data/P030/7/toe_stand/toe_stand.mot
# (435, 33) P030 7 /Users/kristensteudel/Documents/datadir/opencap_data/P030/7/5xsts/5xsts.mot
# (184, 33) P030 7 /Users/kristensteudel/Documents/datadir/opencap_data/P030/7/jump/jump.mot
# (638, 33) P030 7 /Users/kristensteudel/Documents/datadir/opencap_data/P030/7/run/run.mot
# (524, 33) P031 7 /Users/kristensteudel/Documents/datadir/opencap_data/P031/7/walk/walk.mot
# (640, 33) P031 7 /Users/kristensteudel/Documents/datadir/opencap_data/P031/7/tug/tug.mot
# (1829, 33) P031 7 /Users/kristensteudel/Documents/datadir/opencap_data/P031/7/toe_stand/toe_stand.mot
# (563, 33) P031 7 /Users/kristensteudel/Documents/datadir/opencap_data/P031/7/5xsts/5xsts.mot
# (324, 33) P031 7 /Users/kristensteudel/Documents/datadir/opencap_data/P031/7/jump/jump.mot
# (513, 33) P031 7 /Users/kristensteudel/Documents/datadir/opencap_data/P031/7/run/run.mot
# (869, 33) P032 7 /Users/kristensteudel/Documents/datadir/opencap_data/P032/7/walk/walk.mot
# (661, 33) P032 7 /Users/kristensteudel/Documents/datadir/opencap_data/P032/7/tug/tug.mot
# (1980, 33) P032 7 /Users/kristensteudel/Documents/datadir/opencap_data/P032/7/toe_stand/toe_stand.mot
# (785, 33) P032 7 /Users/kristensteudel/Documents/datadir/opencap_data/P032/7/5xsts/5xsts.mot
# (129, 33) P032 7 /Users/kristensteudel/Documents/datadir/opencap_data/P032/7/jump/jump.mot
# (636, 33) P032 7 /Users/kristensteudel/Documents/datadir/opencap_data/P032/7/run/run.mot
# (686, 33) P033 7 /Users/kristensteudel/Documents/datadir/opencap_data/P033/7/walk/walk.mot
# (1218, 33) P033 7 /Users/kristensteudel/Documents/datadir/opencap_data/P033/7/tug/tug.mot
# (2043, 33) P033 7 /Users/kristensteudel/Documents/datadir/opencap_data/P033/7/toe_stand/toe_stand.mot
# (171, 33) P037 7 /Users/kristensteudel/Documents/datadir/opencap_data/P037/7/jump/jump.mot
# (772, 33) P037 7 /Users/kristensteudel/Documents/datadir/opencap_data/P037/7/run/run.mot
# (1237, 33) P038 406 /Users/kristensteudel/Documents/datadir/opencap_data/P038/406/walk/walk.mot
# (1581, 33) P038 406 /Users/kristensteudel/Documents/datadir/opencap_data/P038/406/tug/tug.mot
# (2079, 33) P038 406 /Users/kristensteudel/Documents/datadir/opencap_data/P038/406/toe_stand/toe_stand.mot
# (2559, 33) P038 406 /Users/kristensteudel/Documents/datadir/opencap_data/P038/406/5xsts/5xsts.mot
# (280, 33) P038 406 /Users/kristensteudel/Documents/datadir/opencap_data/P038/406/jump/jump.mot
# (833, 33) P038 406 /Users/kristensteudel/Documents/datadir/opencap_data/P038/406/run/run.mot
# (1328, 33) P038 7 /Users/kristensteudel/Documents/datadir/opencap_data/P038/7/walk/walk.mot
# (2081, 33) P038 7 /Users/kristensteudel/Documents/datadir/opencap_data/P038/7/tug/tug.mot
# (1122, 33) P038 7 /Users/kristensteudel/Documents/datadir/opencap_data/P038/7/5xsts/5xsts.mot
# (192, 33) P038 7 /Users/kristensteudel/Documents/datadir/opencap_data/P038/7/jump/jump.mot
# (466, 33) P038 7 /Users/kristensteudel/Documents/datadir/opencap_data/P038/7/run/run.mot
# (1477, 33) P039 7 /Users/kristensteudel/Documents/datadir/opencap_data/P039/7/walk/walk.mot
# (2303, 33) P039 7 /Users/kristensteudel/Documents/datadir/opencap_data/P039/7/tug/tug.mot
# (1908, 33) P039 7 /Users/kristensteudel/Documents/datadir/opencap_data/P039/7/toe_stand/toe_stand.mot
# (1892, 33) P039 7 /Users/kristensteudel/Documents/datadir/opencap_data/P039/7/5xsts/5xsts.mot
# (133, 33) P039 7 /Users/kristensteudel/Documents/datadir/opencap_data/P039/7/jump/jump.mot
# (1116, 33) P039 7 /Users/kristensteudel/Documents/datadir/opencap_data/P039/7/run/run.mot
# (1530, 33) P040 7 /Users/kristensteudel/Documents/datadir/opencap_data/P040/7/walk/walk.mot
# (2270, 33) P040 7 /Users/kristensteudel/Documents/datadir/opencap_data/P040/7/tug/tug.mot
# (1809, 33) P040 7 /Users/kristensteudel/Documents/datadir/opencap_data/P040/7/toe_stand/toe_stand.mot
# (1538, 33) P040 7 /Users/kristensteudel/Documents/datadir/opencap_data/P040/7/5xsts/5xsts.mot
# (506, 33) P040 7 /Users/kristensteudel/Documents/datadir/opencap_data/P040/7/jump/jump.mot
# (1309, 33) P040 7 /Users/kristensteudel/Documents/datadir/opencap_data/P040/7/run/run.mot
# (1060, 33) P041 407 /Users/kristensteudel/Documents/datadir/opencap_data/P041/407/walk/walk.mot
# (1472, 33) P041 407 /Users/kristensteudel/Documents/datadir/opencap_data/P041/407/tug/tug.mot
# (2012, 33) P041 407 /Users/kristensteudel/Documents/datadir/opencap_data/P041/407/toe_stand/toe_stand.mot
# (1955, 33) P041 407 /Users/kristensteudel/Documents/datadir/opencap_data/P041/407/5xsts/5xsts.mot
# (116, 33) P041 407 /Users/kristensteudel/Documents/datadir/opencap_data/P041/407/jump/jump.mot
# (722, 33) P041 407 /Users/kristensteudel/Documents/datadir/opencap_data/P041/407/run/run.mot
# (769, 33) P041 7 /Users/kristensteudel/Documents/datadir/opencap_data/P041/7/walk/walk.mot
# (1502, 33) P041 7 /Users/kristensteudel/Documents/datadir/opencap_data/P041/7/tug/tug.mot
# (2054, 33) P041 7 /Users/kristensteudel/Documents/datadir/opencap_data/P041/7/toe_stand/toe_stand.mot
# (646, 33) P041 7 /Users/kristensteudel/Documents/datadir/opencap_data/P041/7/5xsts/5xsts.mot
# (315, 33) P041 7 /Users/kristensteudel/Documents/datadir/opencap_data/P041/7/jump/jump.mot
# (380, 33) P041 7 /Users/kristensteudel/Documents/datadir/opencap_data/P041/7/run/run.mot
# (782, 33) P042 7 /Users/kristensteudel/Documents/datadir/opencap_data/P042/7/walk/walk.mot
# (879, 33) P042 7 /Users/kristensteudel/Documents/datadir/opencap_data/P042/7/tug/tug.mot
# (2067, 33) P042 7 /Users/kristensteudel/Documents/datadir/opencap_data/P042/7/toe_stand/toe_stand.mot
# (1330, 33) P042 7 /Users/kristensteudel/Documents/datadir/opencap_data/P042/7/5xsts/5xsts.mot
# (121, 33) P042 7 /Users/kristensteudel/Documents/datadir/opencap_data/P042/7/jump/jump.mot
# (265, 33) P042 7 /Users/kristensteudel/Documents/datadir/opencap_data/P042/7/run/run.mot
# (1354, 33) P043 406 /Users/kristensteudel/Documents/datadir/opencap_data/P043/406/walk/walk.mot
# (1764, 33) P043 406 /Users/kristensteudel/Documents/datadir/opencap_data/P043/406/tug/tug.mot
# (2094, 33) P043 406 /Users/kristensteudel/Documents/datadir/opencap_data/P043/406/toe_stand/toe_stand.mot
# (2496, 33) P043 406 /Users/kristensteudel/Documents/datadir/opencap_data/P043/406/5xsts/5xsts.mot
# (280, 33) P043 406 /Users/kristensteudel/Documents/datadir/opencap_data/P043/406/jump/jump.mot
# (1109, 33) P043 406 /Users/kristensteudel/Documents/datadir/opencap_data/P043/406/run/run.mot
# (269, 33) P043 7 /Users/kristensteudel/Documents/datadir/opencap_data/P043/7/walk/walk.mot
# (755, 33) P043 7 /Users/kristensteudel/Documents/datadir/opencap_data/P043/7/tug/tug.mot
# (1894, 33) P043 7 /Users/kristensteudel/Documents/datadir/opencap_data/P043/7/toe_stand/toe_stand.mot
# (1344, 33) P043 7 /Users/kristensteudel/Documents/datadir/opencap_data/P043/7/5xsts/5xsts.mot
# (39, 33) P043 7 /Users/kristensteudel/Documents/datadir/opencap_data/P043/7/jump/jump.mot
# (181, 33) P043 7 /Users/kristensteudel/Documents/datadir/opencap_data/P043/7/run/run.mot
# (1104, 33) P044 406 /Users/kristensteudel/Documents/datadir/opencap_data/P044/406/walk/walk.mot
# (1219, 33) P044 406 /Users/kristensteudel/Documents/datadir/opencap_data/P044/406/tug/tug.mot
# (2133, 33) P044 406 /Users/kristensteudel/Documents/datadir/opencap_data/P044/406/toe_stand/toe_stand.mot
# (1231, 33) P044 406 /Users/kristensteudel/Documents/datadir/opencap_data/P044/406/5xsts/5xsts.mot
# (536, 33) P060 8 /Users/kristensteudel/Documents/datadir/opencap_data/P060/8/5xsts/5xsts.mot
# (119, 33) P060 8 /Users/kristensteudel/Documents/datadir/opencap_data/P060/8/jump/jump.mot
# (496, 33) P060 8 /Users/kristensteudel/Documents/datadir/opencap_data/P060/8/run/run.mot
# (491, 33) P061 8 /Users/kristensteudel/Documents/datadir/opencap_data/P061/8/walk/walk.mot
# (989, 33) P061 8 /Users/kristensteudel/Documents/datadir/opencap_data/P061/8/tug/tug.mot
# (1959, 33) P061 8 /Users/kristensteudel/Documents/datadir/opencap_data/P061/8/toe_stand/toe_stand.mot
# (459, 33) P061 8 /Users/kristensteudel/Documents/datadir/opencap_data/P061/8/5xsts/5xsts.mot
# (246, 33) P061 8 /Users/kristensteudel/Documents/datadir/opencap_data/P061/8/jump/jump.mot
# (876, 33) P061 8 /Users/kristensteudel/Documents/datadir/opencap_data/P061/8/run/run.mot
# (831, 33) P062 8 /Users/kristensteudel/Documents/datadir/opencap_data/P062/8/walk/walk.mot
# (540, 33) P062 8 /Users/kristensteudel/Documents/datadir/opencap_data/P062/8/tug/tug.mot
# (1793, 33) P062 8 /Users/kristensteudel/Documents/datadir/opencap_data/P062/8/toe_stand/toe_stand.mot
# (545, 33) P062 8 /Users/kristensteudel/Documents/datadir/opencap_data/P062/8/5xsts/5xsts.mot
# (221, 33) P062 8 /Users/kristensteudel/Documents/datadir/opencap_data/P062/8/jump/jump.mot
# (250, 33) P062 8 /Users/kristensteudel/Documents/datadir/opencap_data/P062/8/run/run.mot
# (1291, 33) P063 8 /Users/kristensteudel/Documents/datadir/opencap_data/P063/8/walk/walk.mot
# (1650, 33) P063 8 /Users/kristensteudel/Documents/datadir/opencap_data/P063/8/tug/tug.mot
# (1861, 33) P063 8 /Users/kristensteudel/Documents/datadir/opencap_data/P063/8/toe_stand/toe_stand.mot
# (649, 33) P063 8 /Users/kristensteudel/Documents/datadir/opencap_data/P063/8/5xsts/5xsts.mot
# (400, 33) P063 8 /Users/kristensteudel/Documents/datadir/opencap_data/P063/8/jump/jump.mot
# (187, 33) P063 8 /Users/kristensteudel/Documents/datadir/opencap_data/P063/8/run/run.mot
# (675, 33) P064 406 /Users/kristensteudel/Documents/datadir/opencap_data/P064/406/walk/walk.mot
# (976, 33) P064 406 /Users/kristensteudel/Documents/datadir/opencap_data/P064/406/tug/tug.mot
# (2006, 33) P064 406 /Users/kristensteudel/Documents/datadir/opencap_data/P064/406/toe_stand/toe_stand.mot
# (1462, 33) P064 406 /Users/kristensteudel/Documents/datadir/opencap_data/P064/406/5xsts/5xsts.mot
# (206, 33) P064 406 /Users/kristensteudel/Documents/datadir/opencap_data/P064/406/jump/jump.mot
# (618, 33) P064 406 /Users/kristensteudel/Documents/datadir/opencap_data/P064/406/run/run.mot
# (527, 33) P064 8 /Users/kristensteudel/Documents/datadir/opencap_data/P064/8/walk/walk.mot
# (927, 33) P064 8 /Users/kristensteudel/Documents/datadir/opencap_data/P064/8/tug/tug.mot
# (1815, 33) P064 8 /Users/kristensteudel/Documents/datadir/opencap_data/P064/8/toe_stand/toe_stand.mot
# (531, 33) P064 8 /Users/kristensteudel/Documents/datadir/opencap_data/P064/8/5xsts/5xsts.mot
# (120, 33) P064 8 /Users/kristensteudel/Documents/datadir/opencap_data/P064/8/jump/jump.mot
# (317, 33) P064 8 /Users/kristensteudel/Documents/datadir/opencap_data/P064/8/run/run.mot
# (812, 33) P065 8 /Users/kristensteudel/Documents/datadir/opencap_data/P065/8/walk/walk.mot
# (1004, 33) P065 8 /Users/kristensteudel/Documents/datadir/opencap_data/P065/8/tug/tug.mot
# (1899, 33) P065 8 /Users/kristensteudel/Documents/datadir/opencap_data/P065/8/toe_stand/toe_stand.mot
# (552, 33) P065 8 /Users/kristensteudel/Documents/datadir/opencap_data/P065/8/5xsts/5xsts.mot
# (158, 33) P065 8 /Users/kristensteudel/Documents/datadir/opencap_data/P065/8/jump/jump.mot
# (443, 33) P065 8 /Users/kristensteudel/Documents/datadir/opencap_data/P065/8/run/run.mot
# (383, 33) P066 8 /Users/kristensteudel/Documents/datadir/opencap_data/P066/8/walk/walk.mot
# (814, 33) P066 8 /Users/kristensteudel/Documents/datadir/opencap_data/P066/8/tug/tug.mot
# (1848, 33) P066 8 /Users/kristensteudel/Documents/datadir/opencap_data/P066/8/toe_stand/toe_stand.mot
# (320, 33) P066 8 /Users/kristensteudel/Documents/datadir/opencap_data/P066/8/5xsts/5xsts.mot
# (36, 33) P066 8 /Users/kristensteudel/Documents/datadir/opencap_data/P066/8/jump/jump.mot
# (296, 33) P066 8 /Users/kristensteudel/Documents/datadir/opencap_data/P066/8/run/run.mot
# (824, 33) P067 8 /Users/kristensteudel/Documents/datadir/opencap_data/P067/8/walk/walk.mot
# (1106, 33) P067 8 /Users/kristensteudel/Documents/datadir/opencap_data/P067/8/tug/tug.mot
# (1776, 33) P067 8 /Users/kristensteudel/Documents/datadir/opencap_data/P067/8/toe_stand/toe_stand.mot
# (2764, 33) P067 8 /Users/kristensteudel/Documents/datadir/opencap_data/P067/8/5xsts/5xsts.mot
# (305, 33) P067 8 /Users/kristensteudel/Documents/datadir/opencap_data/P067/8/jump/jump.mot
# (675, 33) P067 8 /Users/kristensteudel/Documents/datadir/opencap_data/P067/8/run/run.mot
# (644, 33) P068 8 /Users/kristensteudel/Documents/datadir/opencap_data/P068/8/walk/walk.mot
# (792, 33) P068 8 /Users/kristensteudel/Documents/datadir/opencap_data/P068/8/tug/tug.mot
# (1881, 33) P068 8 /Users/kristensteudel/Documents/datadir/opencap_data/P068/8/toe_stand/toe_stand.mot
# (441, 33) P068 8 /Users/kristensteudel/Documents/datadir/opencap_data/P068/8/5xsts/5xsts.mot
# (158, 33) P068 8 /Users/kristensteudel/Documents/datadir/opencap_data/P068/8/jump/jump.mot
# (230, 33) P068 8 /Users/kristensteudel/Documents/datadir/opencap_data/P068/8/run/run.mot
# (1127, 33) P069 8 /Users/kristensteudel/Documents/datadir/opencap_data/P069/8/walk/walk.mot
# (1178, 33) P069 8 /Users/kristensteudel/Documents/datadir/opencap_data/P069/8/tug/tug.mot
# (1927, 33) P069 8 /Users/kristensteudel/Documents/datadir/opencap_data/P069/8/toe_stand/toe_stand.mot
# (539, 33) P069 8 /Users/kristensteudel/Documents/datadir/opencap_data/P069/8/5xsts/5xsts.mot
# (363, 33) P069 8 /Users/kristensteudel/Documents/datadir/opencap_data/P069/8/jump/jump.mot
# (202, 33) P069 8 /Users/kristensteudel/Documents/datadir/opencap_data/P069/8/run/run.mot
# (1052, 33) P070 407 /Users/kristensteudel/Documents/datadir/opencap_data/P070/407/walk/walk.mot
# (1612, 33) P070 407 /Users/kristensteudel/Documents/datadir/opencap_data/P070/407/tug/tug.mot
# (2287, 33) P070 407 /Users/kristensteudel/Documents/datadir/opencap_data/P070/407/toe_stand/toe_stand.mot
# ...
# (648, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/walk/walk.mot
# (658, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/tug/tug.mot
# (2024, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/toe_stand/toe_stand.mot
# (968, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/5xsts/5xsts.mot
# (83, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/jump/jump.mot
# (290, 33) P099 119 /Users/scovitz/datadir/opencap_data/P099/119/run/run.mot
# (951, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/walk/walk.mot
# (1238, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/tug/tug.mot
# (1673, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/toe_stand/toe_stand.mot
# (2696, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/5xsts/5xsts.mot
# (156, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/jump/jump.mot
# (464, 33) P100 118 /Users/scovitz/datadir/opencap_data/P100/118/run/run.mot
# (623, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/walk/walk.mot
# (1574, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/tug/tug.mot
# (2319, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/toe_stand/toe_stand.mot
# (2787, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/5xsts/5xsts.mot
# (18, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/jump/jump.mot
# (577, 33) P100 119 /Users/scovitz/datadir/opencap_data/P100/119/run/run.mot
# (518, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/walk/walk.mot
# (852, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/tug/tug.mot
# (1920, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/toe_stand/toe_stand.mot
# (1237, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/5xsts/5xsts.mot
# (102, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/jump/jump.mot
# (54, 33) P101 118 /Users/scovitz/datadir/opencap_data/P101/118/run/run.mot
# (638, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/walk/walk.mot
# (1040, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/tug/tug.mot
# (2007, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/toe_stand/toe_stand.mot
# (1703, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/5xsts/5xsts.mot
# (42, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/jump/jump.mot
# (233, 33) P102 118 /Users/scovitz/datadir/opencap_data/P102/118/run/run.mot
# (778, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/walk/walk.mot
# (1233, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/tug/tug.mot
# (1828, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/toe_stand/toe_stand.mot
# (1818, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/5xsts/5xsts.mot
# (22, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/jump/jump.mot
# (53, 33) P102 119 /Users/scovitz/datadir/opencap_data/P102/119/run/run.mot
# (800, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/walk/walk.mot
# (996, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/tug/tug.mot
# (1883, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/toe_stand/toe_stand.mot
# (1336, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/5xsts/5xsts.mot
# (34, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/jump/jump.mot
# (282, 33) P103 118 /Users/scovitz/datadir/opencap_data/P103/118/run/run.mot
# (740, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/walk/walk.mot
# (1668, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/tug/tug.mot
# (2019, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/toe_stand/toe_stand.mot
# (1798, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/5xsts/5xsts.mot
# (40, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/jump/jump.mot
# (108, 33) P103 119 /Users/scovitz/datadir/opencap_data/P103/119/run/run.mot
# (877, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/walk/walk.mot
# (1609, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/tug/tug.mot
# (2400, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/5xsts/5xsts.mot
# (71, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/jump/jump.mot
# (692, 33) P104 119 /Users/scovitz/datadir/opencap_data/P104/119/run/run.mot
# (655, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/walk/walk.mot
# (697, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/tug/tug.mot
# (1932, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/toe_stand/toe_stand.mot
# (1567, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/5xsts/5xsts.mot
# (69, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/jump/jump.mot
# (125, 33) P105 119 /Users/scovitz/datadir/opencap_data/P105/119/run/run.mot
# (652, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/walk/walk.mot
# (780, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/tug/tug.mot
# (2090, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/toe_stand/toe_stand.mot
# (841, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/5xsts/5xsts.mot
# (0, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/jump/jump.mot
# (291, 33) P106 119 /Users/scovitz/datadir/opencap_data/P106/119/run/run.mot
# (636, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/walk/walk.mot
# (1114, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/tug/tug.mot
# (2026, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/toe_stand/toe_stand.mot
# (1816, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/5xsts/5xsts.mot
# (46, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/jump/jump.mot
# (279, 33) P107 119 /Users/scovitz/datadir/opencap_data/P107/119/run/run.mot
# (486, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/walk/walk.mot
# (983, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/tug/tug.mot
# (1748, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/toe_stand/toe_stand.mot
# (2182, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/5xsts/5xsts.mot
# (9, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/jump/jump.mot
# (330, 33) P108 119 /Users/scovitz/datadir/opencap_data/P108/119/run/run.mot
# (704, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/walk/walk.mot
# (877, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/tug/tug.mot
# (1932, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/toe_stand/toe_stand.mot
# (1204, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/5xsts/5xsts.mot
# (0, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/jump/jump.mot
# (332, 33) P109 119 /Users/scovitz/datadir/opencap_data/P109/119/run/run.mot
# (383, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/walk/walk.mot
# (976, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/tug/tug.mot
# (1847, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/toe_stand/toe_stand.mot
# (1353, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/5xsts/5xsts.mot
# (12, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/jump/jump.mot
# (602, 33) P110 119 /Users/scovitz/datadir/opencap_data/P110/119/run/run.mot
# (810, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/walk/walk.mot
# (980, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/tug/tug.mot
# (974, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/5xsts/5xsts.mot
# (9, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/jump/jump.mot
# (504, 33) P111 119 /Users/scovitz/datadir/opencap_data/P111/119/run/run.mot
# (532, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/walk/walk.mot
# (997, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/tug/tug.mot
# (1926, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/toe_stand/toe_stand.mot
# (1438, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/5xsts/5xsts.mot
# (0, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/jump/jump.mot
# (225, 33) P112 119 /Users/scovitz/datadir/opencap_data/P112/119/run/run.mot
# (555, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/walk/walk.mot
# (868, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/tug/tug.mot
# (2176, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/toe_stand/toe_stand.mot
# (1707, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/5xsts/5xsts.mot
# (258, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/jump/jump.mot
# (392, 33) P113 406 /Users/scovitz/datadir/opencap_data/P113/406/run/run.mot
# (1119, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/walk/walk.mot
# (1697, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/tug/tug.mot
# (2054, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/toe_stand/toe_stand.mot
# (2297, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/5xsts/5xsts.mot
# (331, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/jump/jump.mot
# (952, 33) P114 406 /Users/scovitz/datadir/opencap_data/P114/406/run/run.mot
# (1633, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/walk/walk.mot
# (1648, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/tug/tug.mot
# (2196, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/toe_stand/toe_stand.mot
# (2486, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/5xsts/5xsts.mot
# (361, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/jump/jump.mot
# (611, 33) P115 406 /Users/scovitz/datadir/opencap_data/P115/406/run/run.mot
# (465, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/walk/walk.mot
# (781, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/tug/tug.mot
# (2101, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/toe_stand/toe_stand.mot
# (1337, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/5xsts/5xsts.mot
# (335, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/jump/jump.mot
# (329, 33) P116 406 /Users/scovitz/datadir/opencap_data/P116/406/run/run.mot
# (1142, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/walk/walk.mot
# (1343, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/tug/tug.mot
# (1984, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/toe_stand/toe_stand.mot
# (2068, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/5xsts/5xsts.mot
# (277, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/jump/jump.mot
# (622, 33) P117 407 /Users/scovitz/datadir/opencap_data/P117/407/run/run.mot
# (902, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/walk/walk.mot
# (1178, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/tug/tug.mot
# (2019, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/toe_stand/toe_stand.mot
# (1280, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/5xsts/5xsts.mot
# (204, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/jump/jump.mot
# (557, 33) P118 407 /Users/scovitz/datadir/opencap_data/P118/407/run/run.mot
# (1032, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/walk/walk.mot
# (1341, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/tug/tug.mot
# (2070, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/toe_stand/toe_stand.mot
# (1614, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/5xsts/5xsts.mot
# (184, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/jump/jump.mot
# (697, 33) P119 407 /Users/scovitz/datadir/opencap_data/P119/407/run/run.mot
# (971, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/walk/walk.mot
# (1340, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/tug/tug.mot
# (2020, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/toe_stand/toe_stand.mot
# (1836, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/5xsts/5xsts.mot
# (217, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/jump/jump.mot
# (605, 33) P120 407 /Users/scovitz/datadir/opencap_data/P120/407/run/run.mot
# (1974, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/walk/walk.mot
# (2042, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/tug/tug.mot
# (2111, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/toe_stand/toe_stand.mot
# (1483, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/5xsts/5xsts.mot
# (385, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/jump/jump.mot
# (1547, 33) P121 407 /Users/scovitz/datadir/opencap_data/P121/407/run/run.mot
# (381, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/walk/walk.mot
# (668, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/tug/tug.mot
# (2198, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/toe_stand/toe_stand.mot
# (882, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/5xsts/5xsts.mot
# (279, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/jump/jump.mot
# (247, 33) P122 413 /Users/scovitz/datadir/opencap_data/P122/413/run/run.mot
# (199, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/walk/walk.mot
# (397, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/tug/tug.mot
# (2006, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/toe_stand/toe_stand.mot
# (517, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/5xsts/5xsts.mot
# (321, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/jump/jump.mot
# (149, 33) P123 413 /Users/scovitz/datadir/opencap_data/P123/413/run/run.mot
# (1548, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/walk/walk.mot
# (1798, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/tug/tug.mot
# (3331, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/5xsts/5xsts.mot
# (153, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/jump/jump.mot
# (1176, 33) P124 455 /Users/scovitz/datadir/opencap_data/P124/455/run/run.mot
# (853, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/walk/walk.mot
# (994, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/tug/tug.mot
# (1951, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/toe_stand/toe_stand.mot
# (969, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/5xsts/5xsts.mot
# (206, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/jump/jump.mot
# (365, 33) P125 455 /Users/scovitz/datadir/opencap_data/P125/455/run/run.mot
# (802, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/walk/walk.mot
# (776, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/tug/tug.mot
# (2000, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/toe_stand/toe_stand.mot
# (960, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/5xsts/5xsts.mot
# (265, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/jump/jump.mot
# (287, 33) P126 455 /Users/scovitz/datadir/opencap_data/P126/455/run/run.mot
# (792, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/walk/walk.mot
# (999, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/tug/tug.mot
# (1840, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/toe_stand/toe_stand.mot
# (1229, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/5xsts/5xsts.mot
# (39, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/jump/jump.mot
# (279, 33) P127 455 /Users/scovitz/datadir/opencap_data/P127/455/run/run.mot
# (630, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/walk/walk.mot
# (1462, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/tug/tug.mot
# (1886, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/toe_stand/toe_stand.mot
# (1162, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/5xsts/5xsts.mot
# (83, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/jump/jump.mot
# (477, 33) P128 455 /Users/scovitz/datadir/opencap_data/P128/455/run/run.mot
# (610, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/walk/walk.mot
# (760, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/tug/tug.mot
# (1815, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/toe_stand/toe_stand.mot
# (1178, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/5xsts/5xsts.mot
# (21, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/jump/jump.mot
# (284, 33) P129 455 /Users/scovitz/datadir/opencap_data/P129/455/run/run.mot

# %%
len(time_series_data)
time_series_data
# Out:
# {'P001_0': [array([[-8.41674111e+00, -5.36989500e-02,  6.74817750e-01, ...,
#            3.57219160e-01,  3.57652344e+01,  8.65524132e+01],
#          [-8.56087247e+00, -5.40101900e-02,  6.62702120e-01, ...,
#            3.43349590e-01,  3.58212283e+01,  8.59402011e+01],
#          [-8.65040376e+00, -7.57082800e-02,  6.52256250e-01, ...,
#            3.84685270e-01,  3.59091455e+01,  8.50973890e+01],
#          ...,
#          [-7.56221325e+00, -9.83212329e+00,  1.06174662e+01, ...,
#            2.04324328e+01,  1.42464356e+02,  7.81752410e+01],
#          [-8.09925863e+00, -8.31543582e+00,  1.06973183e+01, ...,
#            2.10076678e+01,  1.42711158e+02,  7.77646670e+01],
#          [-7.61171718e+00, -7.54957620e+00,  1.16061718e+01, ...,
#            1.83882929e+01,  1.44172865e+02,  7.75729338e+01]])],
#  'P002_0': [array([[ 2.31795787e+00, -2.65813102e+00, -3.42544660e-01, ...,
#            9.22476249e+00,  2.04611901e+01,  6.72007539e+01],
#          [ 2.29637651e+00, -2.66664889e+00, -2.55141860e-01, ...,
#            9.56655483e+00,  2.05404455e+01,  6.72957139e+01],
#          [ 2.42171028e+00, -2.67694470e+00, -2.90172820e-01, ...,
#            9.51753322e+00,  2.04895007e+01,  6.71295935e+01],
#          ...,
#          [-3.21702765e+00, -5.88675450e-01,  7.14509330e-01, ...,
#            5.58314810e-01,  1.31347928e+02,  1.01606273e+02],
#          [-2.88158324e+00, -5.38704640e-01,  1.45173616e+00, ...,
#            7.53597878e+00,  1.28765487e+02,  1.02334710e+02],
#          [-2.43835003e+00, -1.14106450e-01,  2.45968335e+00, ...,
#            1.39947365e+01,  1.25849498e+02,  1.02860135e+02]])],
#  'P003_0': [array([[ 1.81009922e+00,  8.84283800e-01, -1.01121808e+01, ...,
#            2.16179796e+01,  3.27935631e+01,  8.40546218e+01],
#          [ 1.78665288e+00,  8.64182690e-01, -1.00914477e+01, ...,
#            2.23118891e+01,  3.28029537e+01,  8.16944912e+01],
#          [ 1.72630337e+00,  8.84514490e-01, -1.00031164e+01, ...,
#            1.51699838e+01,  1.51055456e+01,  6.77075835e+01],
#          ...,
#          [-1.47205721e+01, -1.52246971e+00,  3.62597589e+00, ...,
#           -6.49590969e+00,  1.07053227e+02,  8.96820010e+01],
#          [-1.45451462e+01, -1.31219851e+00,  3.41335731e+00, ...,
#           -4.23902001e+00,  1.00526872e+02,  8.94548958e+01],
#          [-1.50108370e+01, -1.12709071e+00,  3.56573259e+00, ...,
#           -7.46382780e-01,  9.32701442e+01,  8.89797047e+01]])],
#  'P007_0': [array([[-1.74920776,  1.9685182 , -8.74275432, ...,  2.3036154 ,
#           30.53573653, 82.90231345],
#          [-1.69536098,  1.96643767, -8.67816894, ...,  3.04900327,
#           29.0788907 , 85.35642401],
#          [-1.54531825,  1.95050776, -8.60808518, ...,  3.01990268,
#           28.20519066, 84.87520644],
#          ...,
#          [-1.42231461, -0.50944148,  9.96408973, ..., 27.75941539,
#           99.21659115, 84.14963316],
#          [-1.70095715, -0.17064834,  7.98434156, ..., 20.00479504,
#           90.04510451, 88.84436457],
#          [-3.12709541, -2.51766541,  9.53017831, ..., 33.36712487,
#           74.97142573, 79.37633148]])],
#  'P008_0': [array([[  5.89796639,   1.31995646,   3.12327677, ...,  41.07630212,
#            26.32984281,  89.47556586],
#          [  5.80604403,   1.33513446,   2.98424827, ...,  40.27778749,
#            26.97996626,  88.48010275],
#          [  5.59266007,   1.34800704,   2.88007252, ...,  38.3056664 ,
#            27.93848606,  90.84622486],
#          ...,
#          [-15.06462412,   2.5788649 ,  10.89309441, ...,  10.13142873,
#            71.15548481,  79.07860832],
#          [-14.71908672,   2.8023449 ,  11.35899581, ...,  15.56438985,
#            72.46879339,  79.42446853],
#          [-13.94679945,   2.56836857,  11.64003775, ...,  16.83321092,
#            76.92460347,  79.5445504 ]])],
#  'P009_453': [array([[ 2.85613251,  2.73332582, -3.32880387, ..., 15.71101266,
#           23.58682033, 80.65457562],
#          [ 2.82114318,  2.71649275, -3.444339  , ..., 15.73980704,
#           23.69339923, 80.6665129 ],
#          [ 2.80656294,  2.69966952, -3.48505666, ..., 15.77693494,
#           23.82288433, 80.6821075 ],
#          ...,
#          [-6.40916398,  5.69375651, -7.13468073, ...,  7.3437949 ,
#           64.67779198, 68.47262455],
#          [-6.98734635,  6.73127501, -6.90400089, ...,  9.41170195,
#           62.79505441, 68.37228991],
#          [-7.18354537,  4.78036084, -4.90215911, ...,  9.7060899 ,
#           62.60339683, 68.32754082]])],
#  'P009_0': [array([[-0.18948406, -0.43600749,  1.39636496, ..., 26.65133522,
#           25.6107616 , 84.58881194],
#          [-0.14251931, -0.44761794,  1.37969038, ..., 26.43054338,
#           25.64181457, 84.4155314 ],
#          [-0.09365459, -0.4691491 ,  1.43280215, ..., 26.49345758,
#           25.69002932, 84.60902981],
#          ...,
#          [-3.07824732,  5.92786414, -2.81853285, ...,  4.39651592,
#           79.51973192, 70.42411446],
#          [-2.46153498,  6.10856492, -5.5155956 , ...,  0.77292633,
#           79.35720674, 70.02210852],
#          [-1.90439864,  6.47435453, -8.02812625, ..., -3.55783892,
#           78.72490778, 69.89624629]])],
#  'P010_407': [array([[ -3.12220904,   0.86237887,   7.38711373, ...,  59.45849501,
#            49.92270308, 114.3540658 ],
#          [ -3.06713399,   0.86585411,   7.39221151, ...,  60.14826905,
#            49.62933836, 114.08122601],
#          [ -2.89551442,   0.88336043,   7.36143211, ...,  60.62166273,
#            49.21369833, 111.25785368],
#          ...,
#          [-13.29275441,  18.38867448,  12.89850226, ...,  24.41619739,
#            59.30741476,  72.66502401],
#          [-12.63228059,  18.13978129,  15.6808236 , ...,  18.39503929,
#            66.29343643,  67.81734992],
#          [-10.8443246 ,  14.98235557,  16.74066404, ...,  16.18341598,
#            73.91099638,  66.31684699]])],
#  'P010_0': [array([[ -3.65387855,  -3.06987796,   5.62806685, ...,   8.43892191,
#            21.6217683 ,  75.62728366],
#          [ -3.825999  ,  -2.93780905,   5.28751275, ...,   7.92973799,
#            21.70071857,  75.7578741 ],
#          [ -4.1033975 ,  -2.65163247,   5.25255656, ...,   7.60754818,
#            21.78635183,  75.83020601],
#          ...,
#          [-16.46955659,   4.58481871,   4.03856738, ...,   1.2315284 ,
#            66.71521924,  81.33551054],
#          [-18.79999651,   0.74905424,   3.30097296, ...,   3.60662814,
#            60.70872488,  81.20364282],
#          [-20.08761072,  -5.90116623,  12.21337513, ...,   2.23621553,
#            56.21337576,  82.01465159]])],
#  'P011_0': [array([[11.83996233,  0.40198804,  0.81022676, ..., 39.57431739,
#           18.33857418, 73.22241196],
#          [11.88149626,  0.35198945,  0.72239762, ..., 39.56053101,
#           18.34325536, 72.98581171],
#          [11.96022464,  0.29519327,  0.61535735, ..., 39.63953627,
#           18.38286473, 73.03308959],
#          ...,
#          [-8.3708445 ,  6.32976764, -3.58517809, ..., 24.60613128,
#           78.39174783, 84.23918561],
#          [-8.32177416,  7.27305451, -3.89012148, ..., 24.04562744,
#           80.48678266, 84.06491699],
#          [-8.24025087,  8.03877807, -4.13190696, ..., 22.26796471,
#           83.02283056, 83.86206109]])],
#  'P012_0': [array([[ -0.93069963,   0.59801857,  -5.53590134, ...,  25.34947633,
#            21.32103884,  59.7488731 ],
#          [ -0.95784389,   0.62285562,  -5.58410567, ...,  25.30372075,
#            21.27077452,  59.73087114],
#          [ -1.00457623,   0.63631822,  -5.59053946, ...,  25.50833749,
#            21.22391067,  59.77051213],
#          ...,
#          [-15.91917996,  14.36839706, -14.45858498, ...,  -5.05979232,
#            69.73229548,  78.55913229],
#          [-14.09071465,  11.67542224, -13.44821702, ...,  -6.10741427,
#            71.21841747,  77.92484002],
#          [-11.77550927,   8.80292728, -12.80178259, ...,  -6.97115523,
#            72.7959084 ,  77.3672488 ]])],
#  'P013_0': [array([[ -1.99760616,  -3.95719491,  -8.25150823, ...,  -0.63534978,
#            24.8184906 ,  72.13194044],
#          [ -1.97413016,  -3.9252639 ,  -8.3670022 , ...,  -0.83027418,
#            25.25396035,  71.53574769],
#          [ -1.90867245,  -3.94688245,  -8.38301842, ...,  -1.00006216,
#            25.13689603,  70.63153252],
#          ...,
#          [  3.77552279,  -3.98163787,  16.85718493, ..., -36.97046705,
#            17.56606918,  81.7636799 ],
#          [  3.85465566,  -3.61141529,  18.63061109, ..., -30.66732796,
#            16.0278305 ,  82.47234407],
#          [  3.765243  ,  -3.25423225,  20.46352997, ...,   4.88736412,
#             6.80454342,  55.00344811]])],
#  'P014_0': [array([[ -1.53578195,   0.55834759,   1.22949476, ...,  26.42664868,
#            20.03488181,  75.00990589],
#          [ -1.56425942,   0.55552932,   1.19687589, ...,  26.18988756,
#            19.90908189,  74.22492233],
#          [ -1.53895543,   0.56958185,   1.1344118 , ...,  26.93561836,
#            19.94995193,  75.71393408],
#          ...,
#          [-10.54371879,  -4.15137528,  -7.12129227, ...,  14.38887364,
#            63.90323538,  80.48417882],
#          [-11.77830326,  -3.41951023, -10.54729772, ...,   6.73445924,
#            62.01545377,  81.56013447],
#          [-14.14697183,  -2.55081327, -14.1285209 , ...,   0.68879049,
#            59.22878861,  81.12474109]])],
#  'P015_0': [array([[ 4.81371686e+00,  2.27505350e-01,  1.39953400e-02, ...,
#            4.20581296e+01,  1.59781651e+01,  6.65738597e+01],
#          [ 4.80717904e+00,  2.23650690e-01,  4.47241200e-02, ...,
#            4.24806880e+01,  1.59666036e+01,  6.64031932e+01],
#          [ 4.74376053e+00,  2.28723100e-01,  9.53903900e-02, ...,
#            4.25624963e+01,  1.59049940e+01,  6.62802545e+01],
#          ...,
#          [-7.99877421e+00,  6.28241880e-01, -3.99899001e+00, ...,
#            2.06961398e+01,  1.13932368e+02,  8.26608993e+01],
#          [-7.67378196e+00,  3.37985950e-01, -3.56796097e+00, ...,
#            2.20458658e+01,  1.15765060e+02,  8.21937869e+01],
#          [-7.96432004e+00,  1.06138155e+00, -3.37440410e+00, ...,
#            2.78449970e+01,  1.16638177e+02,  8.44505636e+01]])],
#  'P016_0': [array([[   7.81943313,   -2.0247064 ,   -6.43526983, ...,   30.5028787 ,
#             19.22665905,   81.30036998],
#          [   7.7843582 ,   -2.04456138,   -6.42966417, ...,   30.58998931,
#             19.18279625,   80.7333283 ],
#          [   7.88004186,   -2.12007652,   -6.44364347, ...,   30.90775166,
#             19.34372444,   80.3822363 ],
#          ...,
#          [  -1.814037  ,   11.73006426,  -25.09840743, ..., -113.27399779,
#             44.56161827,   63.58807143],
#          [  -2.17926462,    9.96897831,  -28.47268393, ..., -117.92817204,
#             47.07592901,   63.76801996],
#          [  -3.07062176,    8.37944413,  -30.23218926, ..., -124.67601491,
#             50.71043644,   65.4932501 ]])],
#  'P017_455': [array([[ -6.92845506,   0.21805361,   4.79626422, ...,  15.74419282,
#            39.63892797,  87.39697399],
#          [ -6.95694248,   0.20577907,   4.74795539, ...,  15.747799  ,
#            39.60434503,  87.40241933],
#          [ -6.97584436,   0.20706016,   4.75219296, ...,  15.74716678,
#            39.59888785,  87.40305034],
#          ...,
#          [ -7.9906761 ,  -9.15464951,   4.87990822, ...,  57.35783945,
#           125.20142412,  99.08243154],
#          [-10.20133414,  -9.39213345,   3.2946015 , ...,  63.06399673,
#           129.4541213 , 100.55638101],
#          [-11.52024188,  -6.89249743,   4.12807686, ...,  71.94408283,
#           132.23575557, 106.91148455]])],
#  'P017_0': [array([[ -4.03647235,   3.24094364,  -7.82354785, ...,  27.11752136,
#            43.9339177 ,  91.15422759],
#          [ -4.02597744,   3.28564348,  -7.56705693, ...,  26.53168558,
#            44.89090732,  90.35688886],
#          [ -4.65921529,   3.45267938,  -7.3881005 , ...,  26.0567758 ,
#            45.95426895,  87.52831736],
#          ...,
#          [  0.50023124,  -5.40240198,   0.57079609, ...,  28.43546044,
#           117.15801806,  88.69110942],
#          [  0.13678724,  -6.66389529,   1.13538741, ...,  28.30985849,
#           118.30311718,  88.34902747],
#          [ -0.31748694,  -7.87343898,   1.90845759, ...,  28.17563749,
#           119.31673229,  87.94066425]])],
#  'P018_0': [array([[ -3.73315834,   8.77366861,  -4.31818266, ...,  -6.01440402,
#           104.97455296,  94.39684972],
#          [ -3.16609865,   7.85278633,  -3.51352582, ...,  -6.03994044,
#           104.63481127,  94.36861723],
#          [ -2.36778078,   6.89957867,  -2.87217996, ...,  -6.21748104,
#           104.43659134,  93.20030333],
#          ...,
#          [  4.19132334,   2.16517091,   3.07400438, ...,  11.71046962,
#            99.91869365,  96.71930221],
#          [  3.94799252,   2.66510565,   2.82819215, ...,  12.37846567,
#           100.13725822,  96.65209736],
#          [  3.61358497,   3.26513128,   2.5000027 , ...,  12.94110011,
#           100.09717154,  96.4187409 ]])],
#  'P019_7': [array([[  2.43047142,  -2.94472589,  -4.14072591, ...,  23.31836271,
#            21.01805012,  80.87274931],
#          [  2.53373038,  -2.94145167,  -4.05152542, ...,  22.56492391,
#            21.24042795,  78.13599776],
#          [  2.60778562,  -2.93624711,  -4.02826282, ...,  22.62166774,
#            21.44852294,  75.37869234],
#          ...,
#          [  0.45841476,  -5.93015783,  35.65441344, ...,  58.54247567,
#            92.42052154,  83.90073922],
#          [  2.0449209 ,  -9.36651586,  36.5658835 , ...,  63.01131628,
#            91.09511478,  79.04787231],
#          [  4.47403267, -16.72560863,  36.73447846, ...,  67.6266864 ,
#            87.23891609,  78.82627703]])],
#  'P019_118': [array([[-5.74129207, -1.81729902,  3.29829956, ..., 27.63803877,
#           24.12734176, 78.84534321],
#          [-5.77057281, -1.82055291,  3.19266086, ..., 27.4345454 ,
#           23.97768885, 78.21031767],
#          [-5.81338786, -1.78200714,  3.04892058, ..., 27.39068356,
#           24.12227983, 78.14539572],
#          ...,
#          [-8.12089073,  0.10168716,  2.48807946, ...,  4.0745543 ,
#           82.4750482 , 81.34407974],
#          [-8.12740176, -0.39284958,  1.7772407 , ...,  5.85004239,
#           76.4922591 , 80.82687081],
#          [-8.18541151, -0.87537504,  1.12145457, ...,  7.686936  ,
#           71.3559036 , 80.2988391 ]])],
#  'P019_119': [array([[-33.95241035,  -2.80151307,  -1.6807509 , ...,  36.09596017,
#            87.16963644,  86.15080979],
#          [-33.74496892,  -3.06357922,  -2.29600225, ...,  36.32537782,
#            87.25886483,  86.16896791],
#          [-33.51589614,  -3.59540059,  -2.93162738, ...,  36.28781782,
#          [ -5.32757988,   3.84347072,   6.28268258, ...,  37.63989488,
#            59.96822431,  78.9237844 ]])],
#  'P031_7': [array([[  3.15823972,  -1.92995795,  -7.46138764, ...,  18.6185138 ,
#            28.98156126,  81.77237087],
#          [  3.05823781,  -1.90860186,  -7.49758862, ...,  18.73026225,
#            29.00003198,  81.05496865],
#          [  2.73482581,  -1.85155378,  -7.51951305, ...,  19.98359664,
#            28.4621554 ,  80.83221476],
#          ...,
#          [ -5.69403218,   2.95541158,  -4.0053739 , ...,   5.80219189,
#           105.27351143,  96.60226308],
#          [ -6.15141372,   3.09985901,  -3.53625353, ...,   7.50480405,
#           107.04915516,  97.07329282],
#          [ -6.57085231,   3.12074632,  -3.02048095, ...,   9.3007101 ,
#           109.90641161,  97.77799501]])],
#  'P032_7': [array([[  4.14916894,   0.57135611,  -1.20120965, ...,  26.61390199,
#            29.16630719,  89.5802704 ],
#          [  4.10309509,   0.62859646,  -1.19649182, ...,  27.05032874,
#            28.86918419,  86.62495726],
#          [  4.11014738,   0.66122469,  -1.10896915, ...,  25.64012126,
#            29.067016  ,  93.09399437],
#          ...,
#          [-12.64232041,  -7.20319486,  11.31086327, ...,  24.59512134,
#            53.52681816,  98.33123841],
#          [-12.76426353,  -7.18232351,  10.94869394, ...,  24.49280614,
#            53.21090367,  98.43312787],
#          [-12.54219432,  -7.15897862,  10.55329451, ...,  24.39569799,
#            53.0358499 ,  98.48734938]])],
#  'P033_7': [array([[  1.27234765,   0.36409039,  -0.4654278 , ...,  21.66781417,
#            20.51861545,  70.45271113],
#          [  0.92376534,   0.38350996,  -0.51970471, ...,  21.39754969,
#            20.0696361 ,  69.26169714],
#          [  0.89232775,   0.36559964,  -0.53152661, ...,  21.39797917,
#            20.07098387,  69.26208233],
#          ...,
#          [-12.73887252,  -3.67311482,   1.20465525, ...,  23.59024322,
#           102.05001687,  85.30389373],
#          [-13.28801775,  -3.43945321,   0.96435651, ...,  23.59135922,
#           101.58629244,  85.21475972],
#          [-14.02351174,  -3.13576042,   0.65935351, ...,  22.85279254,
#           101.54135169,  86.12964687]])],
#  'P034_7': [array([[  5.48369576,   0.31934106,   0.89300675, ..., -14.4040367 ,
#            37.89845892,  99.05358065],
#          [  5.35743211,   0.33172473,   1.02977767, ..., -12.02798785,
#            37.18848002,  92.79547192],
#          [  5.46994477,   0.35060876,   1.20816308, ..., -14.17111676,
#            37.50290818,  99.13646084],
#          ...,
#          [-10.22712235,  -0.35471994,  13.80134206, ..., -45.57106631,
#            23.69743065,  69.76424025],
#          [ -9.42650684,  -0.2049768 ,  14.56767136, ..., -47.54649488,
#            24.91243952,  68.21686411],
#          [ -8.49843199,  -0.63106574,  15.27989413, ..., -50.49060052,
#            26.43063154,  67.03010359]])],
#  'P035_406': [array([[-6.45296570e+00,  1.36168418e+00,  4.39812594e+00, ...,
#            1.80531812e+01,  1.82806331e+01,  6.74939582e+01],
#          [-6.47110218e+00,  1.36943913e+00,  4.26311803e+00, ...,
#            1.80550727e+01,  1.83303046e+01,  6.74985717e+01],
#          [-6.43175357e+00,  1.38794083e+00,  4.23107194e+00, ...,
#            25.95929469,  52.5731602 ],
#          [  1.0000834 ,  -0.78755289,   5.69331594, ...,  44.61592387,
#            26.03153815,  53.41207639],
#          ...,
#          [ -8.61795606,  -2.57939808,   8.78565035, ...,  39.59866425,
#           109.48139925,  92.27206667],
#          [ -8.42922001,  -2.94930706,   8.43690975, ...,  40.18258587,
#           106.89331641,  93.9385017 ],
#          [ -8.22943054,  -3.18966605,   7.97202811, ...,  41.39882972,
#           103.635502  ,  92.90211122]])],
#  'P038_7': [array([[ 11.97151694,  -1.9203877 , -17.97478093, ...,  32.14705958,
#            31.0618193 ,  96.00204484],
#          [ 12.19820234,  -1.66166415, -17.92203483, ...,  31.97877251,
#            30.88572959,  96.05634249],
#          [ 12.31119559,  -1.40139461, -17.80366912, ...,  32.00344748,
#            30.86715471,  94.6018144 ],
#          ...,
#          [-10.76981765,  -4.12337025,   6.26281783, ...,  30.54442667,
#           105.48811837,  86.3762137 ],
#          [-10.61365983,  -4.28862318,   6.26518978, ...,  29.28787457,
#           106.13630154,  89.24138361],
#          [-10.47095353,  -4.57921134,   6.24065194, ...,  29.33297814,
#           105.52414963,  88.36022555]])],
#  'P039_7': [array([[-4.81956672,  2.17365495, -7.02582785, ..., 28.24099765,
#           46.0513983 , 86.59085727],
#          [-4.80344095,  2.15242096, -6.98447396, ..., 28.42432482,
#           46.17600983, 86.90459759],
#          [-4.80292102,  2.14690782, -7.02212631, ..., 28.32218618,
#           46.22566067, 86.67391929],
#          ...,
#          [ 8.06204207, -3.05225329, 36.328433  , ..., 55.09508597,
#           58.64071611, 75.59323894],
#          [ 7.15875863, -2.40857329, 36.24868186, ..., 57.56963046,
#           58.88927027, 75.98880032],
#          [ 6.26653761, -1.90876228, 36.17145317, ..., 57.89339046,
#           59.14425119, 76.05579271]])],
#  'P040_7': [array([[  2.00530075,  -3.67573414,  -6.56862781, ...,   4.51354378,
#            33.73600152,  79.99899012],
#          [  2.064751  ,  -3.84173148,  -6.77452219, ...,   4.82656034,
#            34.06996886,  80.1208219 ],
#          [  2.35120414,  -4.00021571,  -6.97945632, ...,   5.5970046 ,
#            34.90338584,  80.46230105],
#          ...,
#          [ -4.80659741,  -9.93666601,  21.8250574 , ..., -26.10703248,
#            18.86841734,  78.96690186],
#          [ -4.72706815,  -9.77330608,  22.65554414, ..., -26.84325391,
#            18.92341716,  77.97634876],
#          [ -4.5488829 ,  -9.77699548,  23.30687686, ..., -27.41601854,
#            18.7677093 ,  77.62883527]])],
#  'P041_407': [array([[ -3.0522168 ,  -0.43938165,  -1.05143191, ..., 117.1622817 ,
#            14.10475646,  41.05640904],
#          [ -2.99595494,  -0.4572849 ,  -1.19228905, ..., 119.43739796,
#            14.31419776,  36.73177717],
#          [ -2.97300951,  -0.47734513,  -1.32908429, ..., 114.43278579,
#            14.07639965,  42.63576075],
#          ...,
#          [-10.24475636,  -4.08068309,  -5.13129006, ...,  54.91780322,
#            56.52674798,  66.08338045],
#          [-11.3594767 ,  -3.29437976,  -6.30047962, ...,  54.01806414,
#          [ 1.33764573e+00, -3.37014912e+00, -1.65973525e+01, ...,
#            1.03370483e+02,  1.82259212e+01,  2.29813822e+01]])],
#  'P044_406': [array([[ 2.36996648e+00, -3.34276960e-01,  3.33992890e-01, ...,
#            3.77734321e+01,  1.67034702e+01,  5.90522337e+01],
#          [ 2.15884981e+00, -5.15526320e-01,  2.06155900e-02, ...,
#            3.77916320e+01,  1.69162401e+01,  5.89790359e+01],
#          [ 1.89052768e+00, -6.24778640e-01, -2.32818100e-01, ...,
#            3.76686476e+01,  1.71859429e+01,  5.88435877e+01],
#          ...,
#          [-1.09317240e+01,  6.63034850e-01,  3.58190731e+00, ...,
#           -2.96870992e+01,  7.11850872e+01,  6.30583717e+01],
#          [-5.56398934e+00,  4.94637153e+00,  2.19074750e-01, ...,
#           -3.78630860e+01,  7.45036004e+01,  6.38346338e+01],
#          [-6.72427597e+00,  6.43376777e+00,  4.14318448e+00, ...,
#           -4.28947819e+01,  7.67594351e+01,  7.33709303e+01]])],
#  'P044_7': [array([[  6.74090238,  -0.50859372,  -5.80368198, ..., -34.50631833,
#            25.51494229,  98.5408177 ],
#          [  6.79211721,  -0.53326147,  -5.78995787, ..., -32.39582712,
#            25.58201501,  95.67468256],
#          [  6.90932938,  -0.55880535,  -5.80231171, ..., -31.71234699,
#            26.05078069,  91.17451571],
#          ...,
#          [ -7.47643704,  -7.66329694,  10.46467123, ...,  65.55457096,
#            67.47682345,  99.59971865],
#          [ -6.109915  ,  -7.36129518,  13.88779612, ...,  78.19609947,
#            58.17403287,  83.29358034],
#          [ -4.44855725,  -7.14904284,  17.10528287, ...,  90.75748551,
#            52.71150873,  71.51584311]])],
#  'P045_7': [array([[ -2.38868015,  -0.8051513 ,  -2.2213034 , ...,  41.54493427,
#           102.39293148,  96.97934634],
#          [ -2.32741693,  -0.88458031,  -2.41002124, ...,  42.32220061,
#           102.65561308,  96.63775195],
#          [ -2.09893516,  -0.92649668,  -2.1974882 , ...,  44.03816111,
#           102.24933241,  97.40170329],
#          ...,
#          [ -6.05153205,  -8.45588877,  19.18862119, ...,  98.87327087,
#            99.90389867,  84.31861629],
#          [ -4.82948997,  -8.74551543,  20.76806582, ..., 104.46572313,
#           101.72368664,  82.83238689],
#          [ -5.60819636,  -7.65344759,  23.25981875, ..., 103.72912472,
#           101.94111463,  80.60228924]])],
#  'P046_406': [array([[ 9.12094300e-02,  2.91425680e-01,  1.81647482e+00, ...,
#            3.82251268e+01,  3.42948594e+01,  7.93827613e+01],
#          [ 1.28082300e-01,  3.68474230e-01,  1.80479670e+00, ...,
#            3.81362100e+01,  3.42772444e+01,  7.94231941e+01],
#          [ 1.82016940e-01,  3.62745460e-01,  1.83914529e+00, ...,
#            3.80111205e+01,  3.42369375e+01,  7.94879469e+01],
#          ...,
#          [-1.62658737e+01,  2.55520318e+01, -4.61604435e+00, ...,
#            9.87739394e+01,  4.90994976e+01,  3.84078722e+01],
#          [-1.59799963e+01,  2.56812096e+01, -5.86635610e+00, ...,
#            1.03657513e+02,  4.35923828e+01,  3.79689706e+01],
#            2.10135366e+01,  1.26512754e+02,  1.11425688e+02],
#          [ 1.51422769e+00, -5.18875877e+00,  7.96243493e+00, ...,
# ...
#          [-3.28548074, -1.49446165,  5.53332704, ...,  8.0389895 ,
#           32.87192859, 85.37442884],
#          ...,
#          [-3.21584985, -5.37631758, 27.60686749, ..., 62.20907942,
#           53.49746822, 51.01383407],
#          [-2.45206906, -6.48685222, 30.51889926, ..., 66.45379514,
#           59.23237075, 52.24516171],
#          [-1.74622864, -7.52387319, 32.98554122, ..., 76.12343128,
#           63.69646874, 55.68515186]])],
#  'P108_119': [array([[-13.99630561,  -5.68420085,   1.8241671 , ...,  11.44778374,
#            42.74685911,  88.22813638],
#          [-12.99211837,  -5.13368603,   1.10872645, ...,  11.8651268 ,
#            40.05159579,  87.52202317],
#          [-11.84757281,  -4.57968477,   0.33786704, ...,  11.89290933,
#            37.61983432,  86.5705912 ],
#          ...,
#          [ -1.30308404,   7.6244009 , -38.77721272, ...,  16.10150946,
#            75.66784929,  67.64530448],
#          [ -1.33235037,   8.96476207, -41.21867779, ...,  14.82712783,
#            75.46038927,  67.08391057],
#          [ -1.28760192,  10.08650212, -43.34061799, ...,  13.10513186,
#            75.95475145,  65.36422641]])],
#  'P109_119': [array([[-13.65860296,  -0.55006048,  14.30309677, ...,  63.28245126,
#            24.80900253,  66.39112193],
#          [-13.30908834,  -0.59688619,  14.39059059, ...,  64.63290016,
#            25.21045552,  66.11131954],
#          [-13.16254847,  -0.66935411,  14.46365968, ...,  65.09572298,
#            25.46613557,  66.24791674],
#          ...,
#          [ -9.06425109,  12.04079754, -31.6753428 , ...,  26.49329192,
#            28.19412676,  70.68689607],
#          [-10.39089725,  15.70949563, -32.85928971, ...,  16.08533094,
#            27.37654577,  72.81340687],
#          [-12.22721671,  20.05406163, -32.55584733, ...,  11.77300947,
#            25.53679509,  72.97185187]])],
#  'P110_119': [array([[-2.46815981, -2.99883857, -0.12833219, ..., 16.1142141 ,
#           24.60171844, 68.93543498],
#          [-2.42744776, -3.03105272, -0.16644677, ..., 15.98221848,
#           24.72732169, 68.52037048],
#          [-2.50062163, -2.99854638, -0.26546879, ..., 15.64021425,
#           24.77439763, 67.52117709],
#          ...,
#          [-1.90206759, -2.41263473,  2.98983996, ..., 37.6536497 ,
#           68.93297071, 90.20024667],
#          [-2.35327511, -3.20079094,  3.56164262, ..., 37.87951213,
#           70.70552197, 89.99386091],
#          [-3.13945163, -4.06710626,  4.17747377, ..., 39.06366104,
#           71.46337702, 97.47556842]])],
#  'P111_119': [array([[ -3.38693727,   1.84407355,   1.65031575, ...,  34.57188317,
#            19.18063153,  54.70292296],
#          [ -3.5476885 ,   1.77565452,   1.68536204, ...,  34.48613054,
#            18.59399348,  54.7783548 ],
#          [ -3.51143317,   1.70234551,   1.7345713 , ...,  36.91253996,
#            17.44377603,  51.75868309],
#          ...,
#          [-21.21411338,  15.49821137,  21.30965706, ...,  18.96810269,
#            48.26633122,  47.09635948],
#          [-14.7097966 ,  14.93057293,  19.01749546, ...,  19.45935285,
#            49.7656346 ,  47.36080571],
#          [ -9.71470455,  12.64279414,  17.92817514, ...,  20.16222804,
#            51.50318667,  48.11214319]])],
#  'P112_119': [array([[-22.42131997,   5.67601807,   2.75519101, ..., -12.34416564,
#           104.41081179, 101.64488174],
#          [-21.63142752,   4.30088867,   3.60000538, ..., -12.95837828,
#           108.81167279, 101.54608277],
#          [-20.75157155,   2.90162696,   4.84816891, ..., -13.03363031,
#           112.68199743, 101.74109497],
#          ...,
#          [  0.60624733,  -7.69554675,   5.59797217, ...,   7.59156947,
#           138.04076958, 102.02276109],
#          [  1.58377038,  -7.19600193,   5.14931376, ...,   8.89975477,
#           136.8375728 , 103.9762894 ],
#          [  2.54004786,  -6.94399438,   5.05640192, ...,  10.934407  ,
#           134.34098215, 100.86295626]])],
#  'P113_406': [array([[ -8.96650524,  -1.15346976,  -3.0164074 , ...,  37.83373627,
#            19.09100352,  74.42027829],
#          [ -8.76079983,  -1.17363723,  -2.97893492, ...,  35.77364194,
#            19.61978231,  75.10120428],
#          [ -8.51354058,  -1.17218419,  -2.93886498, ...,  35.18696836,
#            19.84490414,  75.42241427],
#          ...,
#          [-13.11619124,   3.73666208,  -4.06804346, ...,  32.07162304,
#            35.46185044,  93.68288129],
#          [-13.80468051,   4.58425529,  -3.81592122, ...,  39.39147339,
#            34.08050018,  89.65852358],
#          [-14.19354612,   5.6351875 ,  -3.25102107, ...,  42.18578509,
#            35.28647145,  83.02998497]])],
#  'P114_406': [array([[ -7.89784272,   0.58329422,  -5.46549368, ...,  37.42884137,
#            32.22420438,  91.05039378],
#          [ -8.33682647,   0.67598143,  -5.52443964, ...,  35.85448905,
#            32.62468656,  92.96250841],
#          [ -8.74054145,   0.7689837 ,  -5.61503591, ...,  35.24867425,
#            32.70625191,  92.39456043],
#          ...,
#          [-12.45766943,   3.88674273,  -6.07450983, ...,  35.01256628,
#            41.91263501,  87.26731176],
#          [-13.11865313,   4.02541873,  -6.81694398, ...,  34.63310028,
#            42.45568188,  86.17545356],
#          [-13.54530845,   3.87717264,  -7.67474281, ...,  34.28395729,
#            42.80695693,  84.52669921]])],
#  'P115_406': [array([[-6.84786474e+00,  1.23325771e+00, -1.76560326e+00, ...,
#            9.71075561e+01,  3.59772638e+00,  3.86051600e-02],
#          [-6.82808613e+00,  1.20163733e+00, -1.70241945e+00, ...,
#            9.70937812e+01,  3.60319822e+00,  3.70163000e-02],
#          [-6.71097491e+00,  1.21291802e+00, -1.43215106e+00, ...,
#            7.23910158e+01,  1.19004506e+01,  3.80518330e-01],
#          ...,
#          [-6.60416543e+00,  7.81972169e+00, -1.14003712e+01, ...,
#           -4.07608584e+00,  1.12464613e+02,  9.37986833e+01],
#          [-6.64833756e+00,  6.57357202e+00, -1.02280800e+01, ...,
#           -1.70361982e+00,  1.10977169e+02,  9.57539585e+01],
#          [-7.75928538e+00,  5.13879043e+00, -5.15956426e+00, ...,
#            2.04157716e+00,  1.10571372e+02,  9.70507380e+01]])],
#  'P116_406': [array([[ 2.32404840e-01,  1.05165178e+00,  2.46750795e+00, ...,
#          [-3.76454648e+00, -8.37147200e-02, -1.54862552e+00, ...,
#            3.60015417e+01,  1.57052128e+01,  5.70013997e+01],
#          ...,
#          [-1.18681765e+01, -1.50986553e+00,  8.08284923e+00, ...,
#            9.03479463e+01,  1.05354941e+02,  9.14658837e+01],
#          [-1.33423797e+01,  1.21639727e+00,  5.32020118e+00, ...,
#            9.79876879e+01,  1.02261961e+02,  9.20402662e+01],
#          [-1.38077995e+01,  3.47745883e+00,  2.07750642e+00, ...,
#            9.41343387e+01,  9.37672291e+01,  9.25401862e+01]])],
#  'P121_407': [array([[  1.5116835 ,   3.1648786 ,   9.40838349, ..., -20.86108007,
#           136.89782601,  93.19041402],
#          [  1.19822488,   3.18279368,   9.33128845, ..., -21.66371268,
#           138.87337722,  93.14944864],
#          [  0.91940738,   3.09233387,   9.32967914, ..., -23.51556669,
#           141.66602725,  93.01720238],
#          ...,
#          [  3.15237985,  -3.23003921,  21.46304148, ...,  42.91832088,
#            41.14080814,  94.70416047],
#          [  3.18569873,  -3.2455753 ,  22.02828784, ...,  42.16310178,
#            40.97949777,  94.59258414],
#          [  3.0819562 ,  -3.10447987,  22.45739679, ...,  41.43226678,
#            40.64966094,  94.48460547]])],
#  'P122_413': [array([[ -7.21253424,  -2.25011054,  -2.67508639, ...,   5.43252748,
#            29.61677504,  59.14507111],
#          [ -7.04930627,  -2.23500832,  -2.41053707, ...,   5.11015779,
#            29.49713723,  59.42770033],
#          [ -7.32071524,  -2.20293698,  -2.1494003 , ...,   4.59970274,
#            29.6784058 ,  60.17450389],
#          ...,
#          [ -0.5631683 , -25.95762811,  48.6043375 , ...,   1.5086506 ,
#            92.72271053,  93.54934357],
#          [ -4.19168278, -33.39564081,  43.89587693, ...,   3.62707788,
#            86.98961664,  98.24339725],
#          [-15.97874434, -33.94272209,  24.70963935, ...,  11.46174038,
#            80.42126253, 100.40419701]])],
#  'P123_413': [array([[ -3.25311724,  -2.2154129 ,   1.10068234, ...,  15.20952064,
#            22.24969625,  65.81548679],
#          [ -3.24415269,  -2.16871363,   1.29413051, ...,  14.76898571,
#            21.93118592,  70.15051373],
#          [ -3.28387079,  -2.12212828,   1.53646097, ...,  15.07397741,
#            21.74940514,  66.18356493],
#          ...,
#          [-11.2418406 ,  -0.13376991,  -8.40753795, ...,  -3.41678509,
#            89.4103384 ,  93.90532464],
#          [-11.2770977 ,   0.10623861,  -7.18622966, ...,  -3.817775  ,
#            87.16378369,  92.4056866 ],
#          [-11.88254284,   1.1435028 ,  -6.47730045, ...,  -3.50081164,
#            83.86325554,  91.41595643]])],
#  'P124_455': [array([[ -6.40684811,   1.26700735,   3.59832169, ...,  18.05987757,
#            31.43709912,  84.90635866],
#          [ -6.38716311,   1.28844836,   3.71605433, ...,  18.03805776,
#            31.41008191,  84.90001621],
#          [ -6.3809419 ,   1.31465627,   3.7217883 , ...,  18.03705365,
#            31.41189406,  84.89969559],
#          ...,
#          [-15.28716728,  -9.63347406,  23.72728075, ...,   8.52117753,
#            19.7060076 ,  99.16256865],
#          [-13.93657202, -13.23854877,  25.46498356, ...,   8.21865697,
#            72.43827862, 112.88387633],
#          [-20.41320121,   7.2675728 ,   4.32700638, ...,  20.03257328,
#            74.37939499, 112.8794028 ],
#          [-20.98121705,   7.15151355,   4.56348972, ...,  20.47134332,
#            76.41414748, 112.83392146],
#          ...,
#          [-10.65692647,   0.60281937,   0.46647462, ...,  37.6509668 ,
#           106.26906571,  86.95489095],
#          [-15.57954922,  -1.38912493,  -0.11788648, ...,  43.12591863,
#           100.31062395,  89.04539077],
#          [-18.63663489,   1.26190136,   0.77137037, ...,  46.77017224,
#            92.00743029,  92.14537147]])]}

# %%
# Prepare the LSTM input
lstm_input, subject_ids, mean, std = prepare_lstm_input(time_series_data)

# Check the results
print("LSTM Input Shape:", lstm_input.shape)  # (162, max_timesteps, 35)
print("Subject IDs:", subject_ids[:5])  # subject ID ordering, should be in order! 
print("Mean Shape:", mean.shape)  # shape of mean: (35,)
print("Std Shape:", std.shape)  # shape of std: (35,)
# Out:
# LSTM Input Shape: (162, 1547, 33)
# Subject IDs: ['P001_0', 'P002_0', 'P003_0', 'P004_0', 'P005_0']
# Mean Shape: (33,)
# Std Shape: (33,)

# %%
# Convert labels to a numpy array
labels = []
for sid in subject_ids:
    pid = sid.split('_')[0]
    trial = sid.split('_')[1]
    label = get_label_for_participant_trial(class_df, pid, trial)
    labels.append(label)

# %%
# convert to numpy array
labels = np.array(labels)

# %%
# data loader
def data_generator(X, y, batch_size):
    num_samples = len(X)
    while True:
        for offset in range(0, num_samples, batch_size):
            X_batch = X[offset:offset+batch_size]
            y_batch = y[offset:offset+batch_size]
            yield np.array(X_batch), np.array(y_batch)

# %%
# Split data into train, validation, and test sets - 80, 10, 10
def split_data(X, y, test_size=0.1, val_size=0.1):
    """
    Splits the data into training, validation, and testing sets.
    Arguments:
        X: Input features (numpy array).
        y: Labels (numpy array).
        test_size: Proportion of data for the test set.
        val_size: Proportion of data for the validation set from the training set.
    Returns:
        X_train, X_val, X_test, y_train, y_val, y_test3
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_size, random_state=42)
    return X_train, X_val, X_test, y_train, y_val, y_test


# Split data
X_train, X_val, X_test, y_train, y_val, y_test = split_data(lstm_input, labels)

# %%
# QUESTIONS
# - scope of project/priorities? one model? multiple? for 3 ppl?
# - AWS GPU credits? need? way to do local or sherlock? 
# - can we do 80/20 split with data we have train/test? do we need dev? 
#

# %%
# ADVICE
# spend a lot of time on analysis portion - why did this occur if we were moving forward what would we change 
# try predicting TFT time

# %%
#### TRANSFORMER ARCHITECTURE!!!!! 

class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, regularizer=None):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.projection_dim = embed_dim // num_heads
        self.query_dense = Dense(embed_dim, kernel_regularizer=regularizer)
        self.key_dense = Dense(embed_dim, kernel_regularizer=regularizer)
        self.value_dense = Dense(embed_dim, kernel_regularizer=regularizer)
        self.combine_heads = Dense(embed_dim, kernel_regularizer=regularizer)

    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b=True) / tf.sqrt(tf.cast(self.projection_dim, query.dtype))
        weights = tf.nn.softmax(score, axis=-1)
        return tf.matmul(weights, value), weights

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)

        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)

        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        attention, _ = self.attention(query, key, value)
        attention = tf.transpose(attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        return self.combine_heads(concat_attention)

class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, regularizer=None):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadSelfAttention(embed_dim, num_heads, regularizer)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation='relu', kernel_regularizer=regularizer),
            Dense(embed_dim, kernel_regularizer=regularizer)
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def build_transformer_model(input_shape, num_heads=4, embed_dim=64, ff_dim=128, num_blocks=2, l2_reg=1e-3):
    inputs = Input(shape=input_shape)
    
    # Embedding layer with regularization
    x = Dense(embed_dim, kernel_regularizer=l2(l2_reg))(inputs)
    
    # Add Transformer blocks with regularization
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, rate=0.3, regularizer=l2(l2_reg))(x, training=True)

    # Global pooling and output layer
    x = GlobalAveragePooling1D()(x)
    x = Dropout(0.5)(x) # INCREASED FROM 0.3
    outputs = Dense(1, activation="sigmoid", kernel_regularizer=l2(l2_reg))(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Build the Transformer model
input_shape = (lstm_input.shape[1], lstm_input.shape[2])  # timesteps, features
transformer_model = build_transformer_model(input_shape)

# Summary of the model
transformer_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1547, 33)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast (Cast)                     │ (None, 1547, 33)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1547, 64)       │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 1547, 64)       │        33,472 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_1             │ (None, 1547, 64)       │        33,472 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69,185 (270.25 KB)
#  Trainable params: 69,185 (270.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the Transformer model
# from tensorflow.keras.callbacks import EarlyStopping

#early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

## MAYBE TRY BRINGING BACK EARLY STOPPING BUT WITH A DIFFERENT PATIENCE 
## MAYBE TRY CLASS WEIGHTS 

# Compute class weights to balance the dataset
class_weights = compute_class_weight(
    class_weight='balanced', 
    classes=np.unique(y_train), 
    y=y_train
)
class_weight_dict = dict(enumerate(class_weights))

history = transformer_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=1000,
    batch_size=16,
    #callbacks=[early_stopping],
    class_weight=class_weight_dict,
    verbose=1
)

train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Print final training and validation accuracy
print(f"Final Training Accuracy: {train_accuracy[-1]:.4f}")
print(f"Final Validation Accuracy: {val_accuracy[-1]:.4f}")

# Evaluate the model on test data
test_loss, test_accuracy = transformer_model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7057 - loss: 1.5739 - val_accuracy: 0.6000 - val_loss: 1.6853
# Epoch 2/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5478 - loss: 1.6710 - val_accuracy: 0.6000 - val_loss: 1.5837
# Epoch 3/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8528 - val_accuracy: 0.9333 - val_loss: 1.0110
# Epoch 102/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8480 - val_accuracy: 0.9333 - val_loss: 1.0033
# Epoch 103/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8430 - val_accuracy: 0.9333 - val_loss: 0.9983
# Epoch 104/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8512 - val_accuracy: 0.9333 - val_loss: 1.0000
# Epoch 105/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8553 - val_accuracy: 0.9333 - val_loss: 1.0202
# Epoch 106/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8376 - val_accuracy: 0.9333 - val_loss: 1.0371
# Epoch 107/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8401 - val_accuracy: 0.8667 - val_loss: 1.0709
# Epoch 108/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8378 - val_accuracy: 0.8667 - val_loss: 1.0840
# Epoch 109/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8461 - val_accuracy: 0.9333 - val_loss: 1.0727
# Epoch 110/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8366 - val_accuracy: 0.9333 - val_loss: 1.0652
# Epoch 111/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8389 - val_accuracy: 0.9333 - val_loss: 1.0684
# Epoch 112/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8356 - val_accuracy: 0.9333 - val_loss: 1.0390
# Epoch 113/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8344 - val_accuracy: 0.9333 - val_loss: 1.0234
# Epoch 114/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8278 - val_accuracy: 0.9333 - val_loss: 1.0234
# Epoch 115/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8291 - val_accuracy: 0.8667 - val_loss: 1.0490
# Epoch 116/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8377 - val_accuracy: 0.8667 - val_loss: 1.1041
# Epoch 117/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8291 - val_accuracy: 0.8667 - val_loss: 1.0920
# Epoch 118/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8267 - val_accuracy: 0.8667 - val_loss: 1.0888
# Epoch 119/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8249 - val_accuracy: 0.8667 - val_loss: 1.0799
# Epoch 120/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8251 - val_accuracy: 0.8667 - val_loss: 1.0737
# Epoch 121/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8238 - val_accuracy: 0.9333 - val_loss: 1.0459
# Epoch 122/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8245 - val_accuracy: 0.9333 - val_loss: 1.0696
# Epoch 123/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8229 - val_accuracy: 0.8667 - val_loss: 1.1042
# Epoch 124/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8149 - val_accuracy: 0.8667 - val_loss: 1.0933
# Epoch 125/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8180 - val_accuracy: 0.8667 - val_loss: 1.0715
# Epoch 126/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8164 - val_accuracy: 0.8667 - val_loss: 1.0672
# Epoch 127/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8158 - val_accuracy: 0.9333 - val_loss: 1.0541
# Epoch 128/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8195 - val_accuracy: 0.8667 - val_loss: 1.0744
# Epoch 129/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8152 - val_accuracy: 0.8667 - val_loss: 1.0975
# Epoch 130/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8108 - val_accuracy: 0.8667 - val_loss: 1.1121
# Epoch 131/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8121 - val_accuracy: 0.8667 - val_loss: 1.1354
# Epoch 132/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8083 - val_accuracy: 0.8667 - val_loss: 1.0923
# Epoch 133/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8085 - val_accuracy: 0.9333 - val_loss: 1.0382
# Epoch 134/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8096 - val_accuracy: 0.9333 - val_loss: 1.0438
# Epoch 135/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.8061 - val_accuracy: 0.8667 - val_loss: 1.0660
# Epoch 136/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8027 - val_accuracy: 0.8667 - val_loss: 1.0888
# Epoch 137/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8050 - val_accuracy: 0.9333 - val_loss: 1.0678
# Epoch 138/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8027 - val_accuracy: 0.8667 - val_loss: 1.0781
# Epoch 139/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7991 - val_accuracy: 0.8667 - val_loss: 1.0969
# Epoch 140/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7997 - val_accuracy: 0.8667 - val_loss: 1.1137
# Epoch 141/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7997 - val_accuracy: 0.8667 - val_loss: 1.1063
# Epoch 142/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7971 - val_accuracy: 0.9333 - val_loss: 1.0634
# Epoch 143/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.8035 - val_accuracy: 0.9333 - val_loss: 1.0479
# Epoch 144/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7933 - val_accuracy: 0.9333 - val_loss: 1.0423
# Epoch 145/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7936 - val_accuracy: 0.9333 - val_loss: 1.0371
# Epoch 146/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7952 - val_accuracy: 0.9333 - val_loss: 1.0490
# Epoch 147/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7951 - val_accuracy: 0.8667 - val_loss: 1.0777
# Epoch 148/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7914 - val_accuracy: 0.8667 - val_loss: 1.0778
# Epoch 149/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7864 - val_accuracy: 0.8667 - val_loss: 1.0801
# Epoch 150/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7902 - val_accuracy: 0.9333 - val_loss: 1.0582
# Epoch 151/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7884 - val_accuracy: 0.9333 - val_loss: 1.0499
# Epoch 152/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7859 - val_accuracy: 0.9333 - val_loss: 1.0507
# Epoch 153/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7870 - val_accuracy: 0.9333 - val_loss: 1.0779
# Epoch 154/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7856 - val_accuracy: 0.8667 - val_loss: 1.0902
# Epoch 155/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7851 - val_accuracy: 0.8667 - val_loss: 1.0810
# Epoch 156/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7872 - val_accuracy: 0.9333 - val_loss: 1.0821
# Epoch 157/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7818 - val_accuracy: 0.9333 - val_loss: 1.0713
# Epoch 158/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7793 - val_accuracy: 0.9333 - val_loss: 1.0713
# Epoch 159/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7777 - val_accuracy: 0.8667 - val_loss: 1.0950
# Epoch 160/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7759 - val_accuracy: 0.8667 - val_loss: 1.0994
# Epoch 161/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7760 - val_accuracy: 0.8667 - val_loss: 1.0995
# Epoch 162/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7768 - val_accuracy: 0.9333 - val_loss: 1.0729
# Epoch 163/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7739 - val_accuracy: 0.9333 - val_loss: 1.0684
# Epoch 164/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7735 - val_accuracy: 0.9333 - val_loss: 1.0667
# Epoch 165/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7698 - val_accuracy: 0.9333 - val_loss: 1.0648
# Epoch 166/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7700 - val_accuracy: 0.9333 - val_loss: 1.0674
# Epoch 167/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7698 - val_accuracy: 0.9333 - val_loss: 1.0565
# Epoch 168/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7691 - val_accuracy: 0.9333 - val_loss: 1.0484
# Epoch 169/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7656 - val_accuracy: 0.9333 - val_loss: 1.0364
# Epoch 170/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7690 - val_accuracy: 0.9333 - val_loss: 1.0323
# Epoch 171/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7694 - val_accuracy: 0.9333 - val_loss: 1.0245
# Epoch 172/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7632 - val_accuracy: 0.9333 - val_loss: 1.0202
# Epoch 173/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7632 - val_accuracy: 0.9333 - val_loss: 1.0243
# Epoch 174/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7612 - val_accuracy: 0.9333 - val_loss: 1.0389
# Epoch 175/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7608 - val_accuracy: 0.8667 - val_loss: 1.0782
# Epoch 176/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7601 - val_accuracy: 0.9333 - val_loss: 1.0648
# Epoch 177/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7572 - val_accuracy: 0.9333 - val_loss: 1.0678
# Epoch 178/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7604 - val_accuracy: 0.8667 - val_loss: 1.0981
# Epoch 179/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7582 - val_accuracy: 0.8667 - val_loss: 1.0955
# Epoch 180/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7553 - val_accuracy: 0.8667 - val_loss: 1.0893
# Epoch 181/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7563 - val_accuracy: 0.8667 - val_loss: 1.0904
# Epoch 182/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7533 - val_accuracy: 0.9333 - val_loss: 1.0851
# Epoch 183/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7517 - val_accuracy: 0.9333 - val_loss: 1.0786
# Epoch 184/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7546 - val_accuracy: 0.9333 - val_loss: 1.0594
# Epoch 185/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7486 - val_accuracy: 0.9333 - val_loss: 1.0513
# Epoch 186/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7494 - val_accuracy: 0.9333 - val_loss: 1.0456
# Epoch 187/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7471 - val_accuracy: 0.9333 - val_loss: 1.0388
# Epoch 188/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7458 - val_accuracy: 0.9333 - val_loss: 1.0415
# Epoch 189/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7453 - val_accuracy: 0.9333 - val_loss: 1.0461
# Epoch 190/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7440 - val_accuracy: 0.8667 - val_loss: 1.0877
# Epoch 191/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7468 - val_accuracy: 0.8667 - val_loss: 1.0785
# Epoch 192/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7411 - val_accuracy: 0.9333 - val_loss: 1.0677
# Epoch 193/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7426 - val_accuracy: 0.9333 - val_loss: 1.0733
# Epoch 194/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7390 - val_accuracy: 0.9333 - val_loss: 1.0677
# Epoch 195/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7398 - val_accuracy: 0.8667 - val_loss: 1.0701
# Epoch 196/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7382 - val_accuracy: 0.8667 - val_loss: 1.0745
# Epoch 197/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7381 - val_accuracy: 0.9333 - val_loss: 1.0518
# Epoch 198/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7358 - val_accuracy: 0.9333 - val_loss: 1.0377
# Epoch 199/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7356 - val_accuracy: 0.9333 - val_loss: 1.0135
# Epoch 200/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7326 - val_accuracy: 0.9333 - val_loss: 1.0187
# Epoch 201/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7330 - val_accuracy: 0.9333 - val_loss: 1.0142
# Epoch 202/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7303 - val_accuracy: 0.9333 - val_loss: 1.0047
# Epoch 203/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7315 - val_accuracy: 0.9333 - val_loss: 1.0069
# Epoch 204/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7284 - val_accuracy: 0.9333 - val_loss: 1.0152
# Epoch 205/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7265 - val_accuracy: 0.9333 - val_loss: 1.0250
# Epoch 206/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7266 - val_accuracy: 0.9333 - val_loss: 1.0276
# Epoch 207/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7274 - val_accuracy: 0.8667 - val_loss: 1.0584
# Epoch 208/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7249 - val_accuracy: 0.8667 - val_loss: 1.0634
# Epoch 209/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7267 - val_accuracy: 0.8667 - val_loss: 1.0686
# Epoch 210/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7223 - val_accuracy: 0.9333 - val_loss: 1.0519
# Epoch 211/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7212 - val_accuracy: 0.9333 - val_loss: 1.0434
# Epoch 212/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.7209 - val_accuracy: 0.9333 - val_loss: 1.0521
# Epoch 213/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7211 - val_accuracy: 0.8667 - val_loss: 1.0679
# Epoch 214/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7168 - val_accuracy: 0.9333 - val_loss: 1.0310
# Epoch 215/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 51s 6s/step - accuracy: 1.0000 - loss: 0.7173 - val_accuracy: 0.8667 - val_loss: 1.0472
# Epoch 216/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7149 - val_accuracy: 0.8667 - val_loss: 1.0411
# Epoch 217/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7137 - val_accuracy: 0.8667 - val_loss: 1.0403
# Epoch 218/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7133 - val_accuracy: 0.9333 - val_loss: 1.0187
# Epoch 219/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.7108 - val_accuracy: 0.9333 - val_loss: 0.9828
# Epoch 220/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 114s 14s/step - accuracy: 1.0000 - loss: 0.7106 - val_accuracy: 0.9333 - val_loss: 0.9770
# Epoch 221/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4599 - val_accuracy: 1.0000 - val_loss: 0.5024
# Epoch 432/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4581 - val_accuracy: 1.0000 - val_loss: 0.4982
# Epoch 433/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4575 - val_accuracy: 1.0000 - val_loss: 0.4895
# Epoch 434/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4578 - val_accuracy: 1.0000 - val_loss: 0.4922
# Epoch 435/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4546 - val_accuracy: 1.0000 - val_loss: 0.4913
# Epoch 436/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4550 - val_accuracy: 1.0000 - val_loss: 0.4958
# Epoch 437/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4528 - val_accuracy: 1.0000 - val_loss: 0.4978
# Epoch 438/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4532 - val_accuracy: 0.9333 - val_loss: 0.4999
# Epoch 439/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4508 - val_accuracy: 1.0000 - val_loss: 0.4936
# Epoch 440/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4500 - val_accuracy: 1.0000 - val_loss: 0.4852
# Epoch 441/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4481 - val_accuracy: 1.0000 - val_loss: 0.4860
# Epoch 442/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4466 - val_accuracy: 1.0000 - val_loss: 0.4881
# Epoch 443/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4454 - val_accuracy: 0.9333 - val_loss: 0.5018
# Epoch 444/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4445 - val_accuracy: 0.9333 - val_loss: 0.5021
# Epoch 445/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4432 - val_accuracy: 1.0000 - val_loss: 0.4867
# Epoch 446/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4422 - val_accuracy: 1.0000 - val_loss: 0.4808
# Epoch 447/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4402 - val_accuracy: 1.0000 - val_loss: 0.4773
# Epoch 448/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4391 - val_accuracy: 1.0000 - val_loss: 0.4762
# Epoch 449/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4383 - val_accuracy: 0.9333 - val_loss: 0.4862
# Epoch 450/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4384 - val_accuracy: 0.9333 - val_loss: 0.5008
# Epoch 451/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4362 - val_accuracy: 0.9333 - val_loss: 0.5001
# Epoch 452/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.4347 - val_accuracy: 0.9333 - val_loss: 0.4884
# Epoch 453/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4335 - val_accuracy: 1.0000 - val_loss: 0.4758
# Epoch 454/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4325 - val_accuracy: 1.0000 - val_loss: 0.4718
# Epoch 455/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4315 - val_accuracy: 1.0000 - val_loss: 0.4698
# Epoch 456/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4300 - val_accuracy: 1.0000 - val_loss: 0.4739
# Epoch 457/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4292 - val_accuracy: 1.0000 - val_loss: 0.4652
# Epoch 458/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.4275 - val_accuracy: 1.0000 - val_loss: 0.4603
# Epoch 459/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4271 - val_accuracy: 0.9333 - val_loss: 0.4767
# Epoch 460/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4255 - val_accuracy: 0.9333 - val_loss: 0.5346
# Epoch 461/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4244 - val_accuracy: 0.9333 - val_loss: 0.5007
# Epoch 462/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4231 - val_accuracy: 0.9333 - val_loss: 0.4949
# Epoch 463/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4224 - val_accuracy: 0.9333 - val_loss: 0.4948
# Epoch 464/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4203 - val_accuracy: 0.9333 - val_loss: 0.4817
# Epoch 465/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4203 - val_accuracy: 0.9333 - val_loss: 0.4694
# Epoch 466/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4184 - val_accuracy: 0.9333 - val_loss: 0.4744
# Epoch 467/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.4175 - val_accuracy: 0.9333 - val_loss: 0.4727
# Epoch 468/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.3550 - val_accuracy: 0.9333 - val_loss: 0.4160
# Epoch 549/1000
# 3/9 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 1.0000 - loss: 0.3553

# %%
import matplotlib.pyplot as plt

# Plot Training Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
### LSTM attempts - did not work

# %%
# # Define function to normalize joint angles across all data
# def normalize_data(data_list):
#     """
#     Normalizes a list of numpy arrays using MinMax scaling across all features.
#     Arguments:
#         data_list: List of numpy arrays where each array corresponds to one time series.
#     Returns:
#         normalized_data: List of normalized numpy arrays.
#     """
#     # Flatten all data for joint normalization across the dataset
#     all_data = np.array(data_list)
    
#     # Apply MinMaxScaler
#     scaler = MinMaxScaler()
#     scaler.fit(all_data)  # Fit scaler on all joint angles across the dataset
    
#     # Normalize each time series
#     normalized_data = [scaler.transform(data) for data in data_list]
#     return normalized_data, scaler

# # Define function to pad time series to the same length
# def pad_time_series(data_list, max_length=None):
#     """
#     Pads all time series in data_list to the same length.
#     Arguments:
#         data_list: List of numpy arrays where each array corresponds to one time series.
#         max_length: If None, pad to the longest time series. Otherwise, pad to max_length.
#     Returns:
#         padded_data: Numpy array of shape (num_samples, max_length, num_features).
#     """
#     if max_length is None:
#         max_length = max(len(data) for data in data_list)  # Find the longest time series
#     padded_data = pad_sequences(data_list, maxlen=max_length, padding="post", dtype="float32")
#     return padded_data

# %%
# def build_lstm_model_2(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking for padded values
#         LSTM(128, return_sequences=True),  # First LSTM layer with increased units
#         BatchNormalization(),  # Batch normalization to stabilize training
#         Dropout(0.2),  # Reduced dropout rate
#         LSTM(64, return_sequences=False),  # Second LSTM layer
#         BatchNormalization(),  # Batch normalization after second LSTM layer
#         Dropout(0.2),
#         Dense(32, activation='relu'),  # Increased fully connected layer size
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# %%
# # Ensure consistent shuffling for reproducibility
# np.random.seed(42)

# def manual_train_val_test_split(data, labels, train_ratio=0.8, val_ratio=0.1):
#     """
#     Manually splits data and labels into training, validation, and testing sets with the given ratios.
#     Arguments:
#         data: Preprocessed time series data (numpy array).
#         labels: Corresponding labels (numpy array).
#         train_ratio: Proportion of data to use for training (default 0.7).
#         val_ratio: Proportion of data to use for validation (default 0.2).
#     Returns:
#         X_train, X_val, X_test, y_train, y_val, y_test: Split data and labels.
#     """
#     # Ensure train_ratio + val_ratio < 1
#     assert train_ratio + val_ratio < 1, "Train and validation ratios must sum to less than 1."
    
#     # Shuffle the indices
#     indices = np.arange(len(data))
#     np.random.shuffle(indices)
    
#     # Calculate the split points
#     train_split = int(len(data) * train_ratio)
#     val_split = int(len(data) * (train_ratio + val_ratio))
    
#     # Split the data and labels
#     train_indices = indices[:train_split]
#     val_indices = indices[train_split:val_split]
#     test_indices = indices[val_split:]
    
#     X_train = data[train_indices]
#     X_val = data[val_indices]
#     X_test = data[test_indices]
#     y_train = labels[train_indices]
#     y_val = labels[val_indices]
#     y_test = labels[test_indices]
    
#     return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# Define LSTM model
# def build_lstm_model_1(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking for padded values
#         LSTM(64, return_sequences=True),  # First LSTM layer
#         Dropout(0.3),  # Dropout for regularization
#         LSTM(32),  # Second LSTM layer
#         Dropout(0.3),
#         Dense(16, activation='relu'),  # Fully connected layer
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# %%
# ### Perform the manual train-test split
# # Call the function
# X_train, X_val, X_test, y_train, y_val, y_test = manual_train_val_test_split(
#     np.array(lstm_input), np.array(labels), train_ratio=0.8, val_ratio=0.1)
# # Check the shapes of the resulting datasets
# print("Training data shape:", X_train.shape)
# print("Training labels shape:", y_train.shape)
# print("Testing data shape:", X_test.shape)
# print("Testing labels shape:", y_test.shape)


# # Convert to numpy arrays
# X_train = np.array(X_train)
# X_val = np.array(X_val)
# X_test = np.array(X_test)
# y_train = np.array(y_train)
# y_val = np.array(y_val)
# y_test = np.array(y_test)

# # Define input shape (timepoints, features)
# input_shape = (X_train.shape[1], X_train.shape[2])

# # # Build model
# # model = build_lstm_model(input_shape)

# # # Train the model
# # history = model.fit(
# #     X_train, y_train,
# #     validation_data=(X_val, y_val),
# #     epochs=50,
# #     batch_size=16,
# #     verbose=1
# # )

# %%
# TRY 3 
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Masking, LSTM, Dropout, Dense, BatchNormalization
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping
# from sklearn.utils.class_weight import compute_class_weight
# import numpy as np

# # Define LSTM model with improvements
# def build_lstm_model(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking for padded values
#         LSTM(128, return_sequences=True),  # Increased units in the first LSTM layer
#         BatchNormalization(),  # Batch Normalization
#         Dropout(0.4),  # Increased Dropout for regularization
#         LSTM(64),  # Second LSTM layer with reduced units
#         BatchNormalization(),  # Batch Normalization
#         Dropout(0.4),
#         Dense(32, activation='relu'),  # Increased units in fully connected layer
#         Dropout(0.4),  # Additional dropout
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# # Build the model
# input_shape = (X_train.shape[1], X_train.shape[2])  # Define input shape based on your data
# model = build_lstm_model(input_shape)

# # Compute class weights for handling class imbalance
# class_weights = compute_class_weight(
#     'balanced',
#     classes=np.unique(y_train),
#     y=y_train
# )
# class_weights = dict(enumerate(class_weights))

# # Add EarlyStopping for regularization
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # Train the model with validation and early stopping
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_val, y_val),
#     epochs=50,
#     batch_size=16,
#     class_weight=class_weights,
#     callbacks=[early_stopping],
#     verbose=1
# )

# # Evaluate the model on test data
# test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
# print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# %%
# # THE LATEST LSTM

# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Masking, LSTM, Dense, Dropout, BatchNormalization, Input
#from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

# # Define the LSTM model
# def build_lstm_model(input_shape):
#     model = Sequential([
#         Input(shape=input_shape),
#         LSTM(256, return_sequences=True),  # Increase units
#         Dense(128, activation='relu'),  # Add a dense layer
#         LSTM(128, return_sequences=True),  # Second LSTM layer
#         Dense(64, activation='relu'),  # Add another dense layer
#         LSTM(64),  # Final LSTM layer
#         Dense(32, activation='relu'),  # Fully connected layer
#         Dense(1, activation='sigmoid')  # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Higher LR
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# %%
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Masking, LSTM, Dense, Dropout, BatchNormalization
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

# # Build an LSTM model optimized for overfitting to the training set
# def build_overfitting_lstm(input_shape):
#     model = Sequential([
#         Masking(mask_value=0.0, input_shape=input_shape),  # Masking padded values
#         LSTM(128, return_sequences=True, activation='relu'),  # First LSTM layer
#         LSTM(64, return_sequences=True, activation='relu'),   # Second LSTM layer
#         LSTM(32, activation='relu'),                         # Third LSTM layer
#         Dense(1, activation='sigmoid')                       # Output layer for binary classification
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.001),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# # Train the model on training data only
# input_shape = (X_train.shape[1], X_train.shape[2])  # Define input shape from the training data
# model = build_overfitting_lstm(input_shape)

# # Train the model for an extended number of epochs
# history = model.fit(
#     X_train, y_train,
#     epochs=100,  # Increase epochs for training
#     batch_size=16,
#     verbose=1
# )

# # Plot training loss over epochs
# plt.plot(history.history['loss'], label='Train Loss')
# plt.title('Training Loss Over Epochs')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Input
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import LearningRateScheduler

# def build_lstm_model(input_shape):
#     model = Sequential([
#         Input(shape=input_shape),
#         LSTM(256, return_sequences=True),  # Larger capacity
#         LSTM(128, return_sequences=True),
#         LSTM(128, return_sequences=True),
#         LSTM(64),
#         Dense(32, activation='relu'),
#         Dense(1, activation='sigmoid')
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=0.0001),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model


# # Build model
# input_shape = (X_train.shape[1], X_train.shape[2])  # Define input shape from the training data
# model = build_lstm_model(input_shape)


# # Train the model with class weights
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_test, y_test),
#     epochs=500,
#     batch_size=16,
#     verbose=1
# )

# %%
# import matplotlib.pyplot as plt

# # Extract the loss values from the history object
# train_loss = history.history['loss']
# val_loss = history.history['val_loss']

# # Print loss values for each epoch
# print("Training Loss per Epoch:")
# for epoch, loss in enumerate(train_loss):
#     print(f"Epoch {epoch+1}: Training Loss = {loss:.4f}, Validation Loss = {val_loss[epoch]:.4f}")

# # Plot the training and validation loss
# plt.figure(figsize=(8, 6))
# plt.plot(train_loss, label='Training Loss', marker='o')
# plt.plot(val_loss, label='Validation Loss', marker='o')
# plt.title('Training and Validation Loss Over Epochs')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.grid()
# plt.show()
